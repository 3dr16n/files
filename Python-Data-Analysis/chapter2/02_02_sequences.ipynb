# %% [markdown]
# # 02_02: Lists, Tuples, and the Slicing Syntax

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
nephews = ["Huey", "Dewey", "Louie"]

# %%
nephews
# Out:
# ['Huey', 'Dewey', 'Louie']

# %%
len(nephews)
# Out:
# 3

# %%
nephews[0]
# Out:
# 'Huey'

# %%
nephews[2]
# Out:
# 'Louie'

# %%
nephews[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-400cc41c62fc> in <cell line: 1>()
# ----> 1 nephews[3]
#
# IndexError: list index out of range

# %%
nephews[-1], nephews[-2]

# %%
for i in range(3):
    nephews[i] = nephews[i] + ' Duck'

# %%
nephews

# %%
mix_it_up = [1, [2,3], 'alpha']

# %%
mix_it_up

# %%
nephews.append('April Duck')

# %%
nephews

# %%
nephews.extend(['May Duck','June Duck'])

# %%
nephews

# %%
ducks = nephews + ['Donald Duck','Daisy Duck']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf89fb5feeae> in <cell line: 1>()
# ----> 1 ducks = nephews + ['Donald Duck','Daisy Duck']
#
# NameError: name 'nephews' is not defined

# %%
ducks

# %%
ducks.insert(0, 'Scrooge McDuck')

# %%
ducks

# %%
del ducks[0]

# %%
ducks

# %%
ducks.remove('Donald Duck')

# %%
ducks

# %%
ducks.sort()

# %%
ducks

# %%
reverse_ducks = sorted(ducks, reverse=True)

# %%
reverse_ducks

# %%
squares = [1,4,9,16,25,36,49]

# %%
squares[0:2]
# Out:
# [1, 4]

# %%
squares[:4]
# Out:
# [1, 4, 9, 16]

# %%
squares[3:]
# Out:
# [16, 25, 36, 49]

# %%
squares[:]
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
squares[0:7:2]
# Out:
# [1, 9, 25, 49]

# %%
squares[-3:-1]
# Out:
# [25, 36]

# %%
squares[2:4] = ['four', 'nine']

# %%
squares
# Out:
# [1, 4, 'four', 'nine', 25, 36, 49]

# %%
del squares[4:6]

# %%
squares
# Out:
# [1, 4, 'four', 'nine']

# %%
len([])
# Out:
# 0

# %%
integers = ('one', 'two', 'three', 'four')

# %%
integers

# %%
integers[-1], integers[1:3]

# %%
integers[0] = 1

# %%
(a, b) = (1, 2)

# %%
c, d = 3, 4

# %%
for i, duck in enumerate(ducks):
    print(i, duck)

# %%
def three_args(a, b, c):
    print(a, b, c)

# %%
my_args = (1,2,3)

# %%
three_args(*my_args)
