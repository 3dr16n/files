# %% [markdown]
# # 03_03: Finding Anagrams

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
words = sorted({line.strip().lower() for line in open('/content/drive/My Drive/Colab Notebooks/words.txt', 'r')})

# %%
words = sorted({line.strip().lower() for line in open( '/content/drive/My Drive/Colab Notebooks/words.txt', 'r')})

# %%
sorted("aaron")
# Out:
# ['a', 'a', 'n', 'o', 'r']

# %%
sorted("elvis") == sorted("lives")
# Out:
# True

# %%
sorted("elvis") == sorted("sings")
# Out:
# False

# %%
'-'.join(sorted("aaron"))
# Out:
# 'a-a-n-o-r'

# %%
''.join(sorted("aaron"))
# Out:
# 'aanor'

# %%
# compute the signature string for a word

def signature(word):
    return ''.join(sorted(word))

# %%
# brute-force anagram search: compare myword's signature
# with the signatures of all words in the dictionary

def find_anagram(myword):
    mysig = signature(myword)

    for word in words:
        if mysig == signature(word):
            print(word)

# %%
find_anagram('dictionary')
# Out:
# dictionary
# indicatory

# %%
find_anagram('bianca')
# Out:
# abanic
# bianca

# %%
def signature(word):
    return ''.join(sorted(word))

def find_anagram(myword):
    mysig = signature(myword)

    for word in words:
      if mysig == signature(word):
          print(word)

find_anagram('dictionary')
# Out:
# dictionary
# indicatory

# %%
# %time find_anagram('dictionary')
# Out:
# dictionary
# indicatory
# CPU times: user 230 ms, sys: 0 ns, total: 230 ms
# Wall time: 233 ms

# %%
# make a dict that maps each signature to the set of words with that signature;
# each signature will map to at least one word

words_by_sig = collections.defaultdict(set)

for word in words:
    words_by_sig[signature(word)].add(word)

# %%
words_by_sig
# Out:
# defaultdict(set,
#             {'a': {'a'},
#              'aa': {'aa'},
#              'aal': {'aal', 'ala'},
#              'aaiil': {'aalii'},
#              'aam': {'aam', 'ama'},
#              'aain': {'aani'},
#              'aaadkrrv': {'aardvark'},
#              'aadflorw': {'aardwolf'},
#              'aanor': {'aaron'},
#              'aacinor': {'aaronic', 'nicarao', 'ocarina'},
#              'aaacilnor': {'aaronical'},
#              'aaeinort': {'aaronite', 'aeration'},
#              'aaciinort': {'aaronitic'},
#              'aaru': {'aaru', 'aura'},
#              'ab': {'ab', 'ba'},
#              'aab': {'aba', 'baa'},
#              'aabbdeh': {'ababdeh'},
#              'aaabbu': {'ababua'},
#              'aabc': {'abac', 'caba'},
#              'aaabc': {'abaca'},
#              'aaabcet': {'abacate'},
#              'aaabcy': {'abacay'},
#              'aaabceint': {'abacinate'},
#              'aaabciinnot': {'abacination'},
#              'aabccissu': {'abaciscus'},
#              'aabcist': {'abacist'},
#              'aabck': {'aback'},
#              'aaabcilnt': {'abactinal'},
#              'aaabcillnty': {'abactinally'},
#              'aabcinot': {'abaction'},
#              'aabcort': {'abactor', 'acrobat'},
#              'aabclsuu': {'abaculus'},
#              'aabcsu': {'abacus'},
#              'aabdeit': {'abadite'},
#              'aabff': {'abaff'},
#              'aabft': {'abaft', 'bafta'},
#              'aaabceins': {'abaisance'},
#              'aabeirs': {'abaiser'},
#              'aabdeiss': {'abaissed'},
#              'aaabeeilnt': {'abalienate'},
#              'aaabeiilnnot': {'abalienation'},
#              'aabelno': {'abalone', 'balonea'},
#              'aaabm': {'abama'},
#              'aabeempr': {'abampere'},
#              'aabdnno': {'abandon'},
#              'aaabbdelnno': {'abandonable'},
#              'aabddenno': {'abandoned'},
#              'aabddelnnoy': {'abandonedly'},
#              'aabdeenno': {'abandonee'},
#              'aabdennor': {'abandoner', 'reabandon'},
#              'aabdemnnnot': {'abandonment'},
#              'aabcin': {'abanic', 'bianca'},
#              'aabenst': {'abantes'},
#              'aabinopstt': {'abaptiston'},
#              'aaabbmor': {'abarambo'},
#              'aabirs': {'abaris', 'arabis'},
#              'aabhiorrsst': {'abarthrosis'},
#              'aaabcilrrtu': {'abarticular'},
#              'aaabciilnorttu': {'abarticulation'},
#              'aabs': {'abas', 'saba'},
#              'aabes': {'abase'},
#              'aabdes': {'abased'},
#              'aabdelsy': {'abasedly'},
#              'aabdeensss': {'abasedness'},
#              'aabeemnst': {'abasement'},
#              'aabers': {'abaser', 'abrase'},
#              'aabgis': {'abasgi'},
#              'aabhs': {'abash'},
#              'aabdehs': {'abashed'},
#              'aabdehlsy': {'abashedly'},
#              'aabdeehnsss': {'abashedness'},
#              'aabehlsss': {'abashless'},
#              'aabehllsssy': {'abashlessly'},
#              'aabehmnst': {'abashment'},
#              'aaabis': {'abasia'},
#              'aabcis': {'abasic'},
#              'aabks': {'abask'},
#              'aabinss': {'abassin'},
#              'aaabdeirstz': {'abastardize'},
#              'aaabbelt': {'abatable'},
#              'aabet': {'abate', 'ateba', 'batea', 'beata'},
#              'aabeemntt': {'abatement'},
#              'aabert': {'abater', 'artabe', 'eartab', 'trabea'},
#              'aabist': {'abatis'},
#              'aabdeist': {'abatised'},
#              'aabnot': {'abaton'},
#              'aabort': {'abator'},
#              'aabiortt': {'abattoir'},
#              'aaabtu': {'abatua'},
#              'aabertu': {'abature'},
#              'aabev': {'abave'},
#              'aaabilx': {'abaxial'},
#              'aabeilx': {'abaxile'},
#              'aabez': {'abaze'},
#              'abb': {'abb', 'bab'},
#              'aabb': {'abba', 'baba'},
#              'aabbcemos': {'abbacomes'},
#              'aabbcy': {'abbacy'},
#              'aabbddei': {'abbadide'},
#              'aabbs': {'abbas'},
#              'aabbis': {'abbasi'},
#              'aabbiss': {'abbassi'},
#              'aabbdeiss': {'abbasside'},
#              'aaabbilt': {'abbatial'},
#              'aaabbcilt': {'abbatical'},
#              'abbess': {'abbess'},
#              'abbey': {'abbey', 'bebay'},
#              'abbdeeesty': {'abbeystede'},
#              'abbei': {'abbie'},
#              'abbot': {'abbot'},
#              'abbcoty': {'abbotcy'},
#              'abbillnostuu': {'abbotnullius'},
#              'abbhiopst': {'abbotship'},
#              'aabbeeirtv': {'abbreviate'},
#              'aabbeeilrtvy': {'abbreviately'},
#              'aabbeiinortv': {'abbreviation'},
#              'aabbeiorrtv': {'abbreviator'},
#              'aabbeiorrtvy': {'abbreviatory'},
#              'aabbeeirrtuv': {'abbreviature'},
#              'abby': {'abby', 'baby'},
#              'abbclmoou': {'abcoulomb'},
#              'aabdl': {'abdal'},
#              'aabdt': {'abdat', 'batad'},
#              'aabdeinr': {'abderian'},
#              'abdeeirt': {'abderite'},
#              'abdest': {'abdest'},
#              'aabbcdeil': {'abdicable'},
#              'aabcdint': {'abdicant'},
#              'aabcdeit': {'abdicate'},
#              'aabcdiinot': {'abdication'},
#              'aabcdeiitv': {'abdicative'},
#              'aabcdiort': {'abdicator'},
#              'abdeil': {'abdiel', 'baldie'},
#              'abdeiitv': {'abditive'},
#              'abdiorty': {'abditory'},
#              'abdemno': {'abdomen'},
#              'aabdilmno': {'abdominal'},
#              'aabdeilmnos': {'abdominales'},
#              'aaabdiilmnno': {'abdominalian'},
#              'aabdillmnoy': {'abdominally'},
#              'aabdeiimnnooorrt': {'abdominoanterior'},
#              'aaabccddiimnoor': {'abdominocardiac'},
#              'abcdeeiimnnoosst': {'abdominocentesis'},
#              'abccdiimnoosty': {'abdominocystic'},
#              'aabdegiilmnnoot': {'abdominogenital'},
#              'abcdeehimmnooorsttyy': {'abdominohysterectomy'},
#              'abdehimmnoooorsttyy': {'abdominohysterotomy'},
#              'abdeiimnooooprrst': {'abdominoposterior'},
#              'abcdeimnooops': {'abdominoscope'},
#              'abcdimnooopsy': {'abdominoscopy'},
#              'aabccdhiimnooort': {'abdominothoracic'},
#              'abdimnoosu': {'abdominous'},
#              'aaabdgiilmnnoov': {'abdominovaginal', 'vaginoabdominal'},
#              'aabcdeiilmnoosv': {'abdominovesical', 'vesicoabdominal'},
#              'abcdeu': {'abduce'},
#              'abcdensu': {'abducens'},
#              'abcdentu': {'abducent'},
#              'abcdtu': {'abduct'},
#              'abcdinotu': {'abduction'},
#              'abcdortu': {'abductor'},
#              'abe': {'abe', 'bae', 'bea'},
#              'aabem': {'abeam'},
#              'aaber': {'abear'},
#              'aaabceenr': {'abearance'},
#              'aaabcdeeinr': {'abecedarian'},
#              'aabcdeeimru': {'abecedarium'},
#              'aabcdeery': {'abecedary'},
#              'abde': {'abed', 'bade', 'bead'},
#              'abeghi': {'abeigh'},
#              'abel': {'abel', 'able', 'albe', 'bale', 'beal', 'bela', 'blae'},
#              'abeel': {'abele', 'albee'},
#              'aabeil': {'abelia'},
#              'aabeiln': {'abelian', 'nebalia'},
#              'aabceeil': {'abelicea'},
#              'abeeilt': {'abelite'},
#              'abcehlmossu': {'abelmoschus'},
#              'abeklmos': {'abelmosk'},
#              'aabeilnno': {'abelonian'},
#              'abeeelrt': {'abeltree'},
#              'aabceeegnrrs': {'abencerrages'},
#              'abceeinrt': {'abenteric', 'bicrenate'},
#              'aabehiimpty': {'abepithymia'},
#              'abdeeenr': {'aberdeen'},
#              'abdeeeinrv': {'aberdevine'},
#              'aabdeinnor': {'aberdonian'},
#              'aabeir': {'aberia', 'baeria', 'baiera'},
#              'aabceenrr': {'aberrance'},
#              'aabcenrry': {'aberrancy'},
#              'aabenrrt': {'aberrant'},
#              'aabeerrt': {'aberrate'},
#              'aabeinorrt': {'aberration'},
#              'aaabeilnorrt': {'aberrational'},
#              'aabeorrrt': {'aberrator'},
#              'abeeemorrrt': {'aberrometer'},
#              'abceeooprrs': {'aberroscope'},
#              'aabcenorrtu': {'aberuncator'},
#              'abet': {'abet', 'bate', 'beat', 'beta'},
#              'abeemntt': {'abetment', 'batement'},
#              'aabeltt': {'abettal'},
#              'abeortt': {'abettor', 'taboret'},
#              'aaabceinotuv': {'abevacuation'},
#              'abey': {'abey'},
#              'aabceeny': {'abeyance'},
#              'aabcenyy': {'abeyancy'},
#              'aabenty': {'abeyant'},
#              'aaabdfr': {'abfarad'},
#              'abehnry': {'abhenry'},
#              'aabehiks': {'abhiseka'},
#              'aabbehilmno': {'abhominable'},
#              'abhor': {'abhor'},
#              'abceehnorr': {'abhorrence'},
#              'abcehnorry': {'abhorrency'},
#              'abehnorrt': {'abhorrent', 'earthborn'},
#              'abehlnorrty': {'abhorrently'},
#              'abehorrr': {'abhorrer', 'harborer'},
#              'abbehilorr': {'abhorrible'},
#              'abghinorr': {'abhorring'},
#              'abhnoors': {'abhorson'},
#              'aabdil': {'abidal'},
#              'aabcdein': {'abidance'},
#              'abdei': {'abide'},
#              'abdeir': {'abider', 'bardie'},
#              'abdii': {'abidi'},
#              'abdgiin': {'abiding'},
#              'abdgiilny': {'abidingly'},
#              'abdegiinnss': {'abidingness'},
#              'abei': {'abie'},
#              'abeis': {'abies', 'beisa'},
#              'aabeeitt': {'abietate'},
#              'abeeeint': {'abietene'},
#              'abceiit': {'abietic'},
#              'abeiint': {'abietin'},
#              'aabeeeiint': {'abietineae'},
#              'abeeiinostu': {'abietineous'},
#              'abceiiint': {'abietinic'},
#              'abeeirz': {'abiezer'},
#              'aabgiil': {'abigail'},
#              'aabghiiilps': {'abigailship'},
#              'aabegit': {'abigeat'},
#              'abegisu': {'abigeus'},
#              'aabilo': {'abilao'},
#              'abiilty': {'ability'},
#              'aabill': {'abilla', 'labial'},
#              'abilo': {'abilo', 'aboil'},
#              'aabeeinsttt': {'abintestate'},
#              'abeegiinoss': {'abiogenesis'},
#              'abeegiinosst': {'abiogenesist'},
#              'abceegiinot': {'abiogenetic'},
#              'aabceegiilnot': {'abiogenetical'},
#              'aabceegiillnoty': {'abiogenetically'},
#              'abegiinost': {'abiogenist'},
#              'abeginoosu': {'abiogenous'},
#              'abeginoy': {'abiogeny'},
#              'aabcgiilloo': {'abiological'},
#              'aabcgiilllooy': {'abiologically'},
#              'abgilooy': {'abiology'},
#              'abiioss': {'abiosis'},
#              'abciiot': {'abiotic'},
#              'abchiiooprt': {'abiotrophic'},
#              'abhiooprty': {'abiotrophy'},
#              'abinop': {'abipon'},
#              'abir': {'abir', 'bari', 'rabi'},
#              'aabiinrrtt': {'abirritant'},
#              'aabeiirrtt': {'abirritate'},
#              'aabiiinorrtt': {'abirritation'},
#              'aabeiiirrttv': {'abirritative'},
#              'abinost': {'abiston', 'bastion'},
#              'abbiiit': {'abitibi'},
#              'abeirtu': {'abiuret', 'aubrite', 'biurate', 'rubiate'},
#              'abcejt': {'abject'},
#              'abcdeeejnsst': {'abjectedness'},
#              'abceijnot': {'abjection'},
#              'abceeijtv': {'abjective'},
#              'abcejlty': {'abjectly'},
#              'abceejnsst': {'abjectness'},
#              'abijnot': {'abjoint'},
#              'abdegju': {'abjudge'},
#              'aabcdeijtu': {'abjudicate'},
#              'aabcdiijnotu': {'abjudication'},
#              'abcijnnotu': {'abjunction'},
#              'abceijntuv': {'abjunctive'},
#              'aabijnortu': {'abjuration'},
#              'aabjorrtuy': {'abjuratory'},
#              'abejru': {'abjure'},
#              'abeejmnrtu': {'abjurement'},
#              'abejrru': {'abjurer'},
#              'aabkr': {'abkar', 'arkab'},
#              'aabikr': {'abkari'},
#              'aabhks': {'abkhas', 'kasbah'},
#              'aaabhikns': {'abkhasian'},
#              'aabchl': {'ablach'},
#              'aaabceltt': {'ablactate', 'cabaletta'},
#              'aaabcilnott': {'ablactation'},
#              'aabelr': {'ablare', 'arable', 'arbela'},
#              'aabceilmst': {'ablastemic', 'masticable'},
#              'aablosstu': {'ablastous'},
#              'aabelt': {'ablate'},
#              'aabilnot': {'ablation', 'obtainal'},
#              'aabiilosttu': {'ablatitious'},
#              'aaabilltv': {'ablatival'},
#              'aabeiltv': {'ablative'},
#              'aablort': {'ablator'},
#              'aabltu': {'ablaut', 'tabula'},
#              'aabelz': {'ablaze'},
#              'abeeelz': {'ableeze'},
#              'aabeeglt': {'ablegate'},
#              'abeelnss': {'ableness', 'blaeness', 'sensable'},
#              'aaabehilpr': {'ablepharia'},
#              'aabehlnopr': {'ablepharon'},
#              'aabehloprsu': {'ablepharous'},
#              'aabehlprsu': {'ablepharus'},
#              'aabeilps': {'ablepsia', 'epibasal'},
#              'aabceillpt': {'ableptical'},
#              'aabceilllpty': {'ableptically'},
#              'abelr': {'abler', 'baler', 'belar', 'blare', 'blear'},
#              'abelst': {'ablest', 'stable', 'tables'},
#              'aabceehklstw': {'ablewhackets'},
#              'abilns': {'ablins'},
#              'ablmoo': {'abloom', 'mabolo'},
#              'ablow': {'ablow', 'balow', 'bowla'},
#              'abdelu': {'ablude', 'belaud'},
#              'abelntu': {'abluent', 'tunable'},
#              'abhlsu': {'ablush'},
#              'abilnotu': {'ablution', 'abutilon'},
#              'aabilnortuy': {'ablutionary'},
#              'abilnouv': {'abluvion'},
#              'ably': {'ably', 'blay', 'yalb'},
#              'abhmo': {'abmho', 'abohm'},
#              'aabikn': {'abnaki'},
#              'aabeegnt': {'abnegate'},
#              'aabeginnot': {'abnegation'},
#              'aabeegintv': {'abnegative'},
#              'aabegnort': {'abnegator'},
#              'abenr': {'abner', 'arneb', 'reban'},
#              'aabelnrv': {'abnerval'},
#              'abent': {'abnet', 'beant'},
#              'aabelnru': {'abneural'},
#              'aablmnor': {'abnormal'},
#              'aabilmmnors': {'abnormalism'},
#              'aabilmnorst': {'abnormalist'},
#              'aabilmnorty': {'abnormality'},
#              'aabeilmnorz': {'abnormalize'},
#              'aabllmnory': {'abnormally'},
#              'aabelmnnorss': {'abnormalness'},
#              'abimnorty': {'abnormity'},
#              'abmnoorsu': {'abnormous'},
#              'aabbeelmnru': {'abnumerable'},
#              'abo': {'abo', 'boa'},
#              'aabdor': {'aboard', 'aborad', 'abroad'},
#              'aabbor': {'abobra'},
#              'abdeo': {'abode', 'adobe'},
#              'abdeemnot': {'abodement'},
#              'abdoy': {'abody'},
#              'abhilos': {'abolish'},
#              'abehilors': {'abolisher', 'reabolish'},
#              'abehilmnost': {'abolishment'},
#              'abiilnoot': {'abolition'},
#              'aabiilnoorty': {'abolitionary'},
#              'abiiilmnoost': {'abolitionism'},
#              'abiiilnoostt': {'abolitionist'},
#              'abeiiilnootz': {'abolitionize'},
#              'aabllo': {'abolla'},
#              'aabmo': {'aboma'},
#              'aabmmosu': {'abomasum'},
#              'aabmossu': {'abomasus'},
#              'aabbeilmno': {'abominable'},
#              'aabbeeilmnnoss': {'abominableness'},
#              'aabbilmnoy': {'abominably'},
#              'aabeimnot': {'abominate'},
#              'aabiimnnoot': {'abomination'},
#              'aabimnoort': {'abominator'},
#              'abeimno': {'abomine'},
#              'abgnoo': {'abongo', 'gaboon'},
#              'abnoo': {'aboon'},
#              'aablor': {'aboral', 'arbalo'},
#              'aabllory': {'aborally'},
#              'abdor': {'abord', 'bardo', 'board', 'broad', 'dobra', 'dorab'},
#              'aabgiilnor': {'aboriginal'},
#              'aabgiiilnorty': {'aboriginality'},
#              'aabgiillnory': {'aboriginally'},
#              'aabgiinorry': {'aboriginary'},
#              'abegiinor': {'aborigine'},
#              'abort': {'abort', 'tabor'},
#              'abdeort': {'aborted'},
#              'abcdeiiort': {'aborticide', 'bacterioid'},
#              'abeinortt': {'abortient', 'torbanite'},
#              'aabcefiinortt': {'abortifacient'},
#              'abinort': {'abortin', 'taborin'},
#              'abinoort': {'abortion', 'robotian'},
#              'aabilnoort': {'abortional'},
#              'abiinoorstt': {'abortionist'},
#              'abeiortv': {'abortive', 'bravoite'},
#              'abeilortvy': {'abortively'},
#              'abeeinorsstv': {'abortiveness'},
#              'aborstu': {'abortus'},
#              'abceehmnotu': {'abouchement'},
#              'abdnou': {'abound'},
#              'abdenoru': {'abounder'},
#              'abdginnou': {'abounding'},
#              'abdgilnnouy': {'aboundingly'},
#              'abotu': {'about'},
#              'abostu': {'abouts', 'basuto'},
#              'abeov': {'above'},
#              'aabbdeoorv': {'aboveboard'},
#              'abcdeekov': {'abovedeck'},
#              'abdegnooruv': {'aboveground'},
#              'abefoooprv': {'aboveproof'},
#              'aabeiorsstv': {'abovestairs'},
#              'abox': {'abox'},
#              'aaaaabbcdrr': {'abracadabra'},
#              'aaabchir': {'abrachia'},
#              'aaabdnrt': {'abradant'},
#              'aabder': {'abrade'},
#              'aabderr': {'abrader'},
#              'aaabhmr': {'abraham'},
#              'aaabchimr': {'abrahamic'},
#              'aaaabdehimr': {'abrahamidae'},
#              'aaabehimrt': {'abrahamite'},
#              'aaabchiimrt': {'abrahamitic'},
#              'aabdir': {'abraid'},
#              'aabmr': {'abram', 'ambar'},
#              'aabimrs': {'abramis', 'arabism'},
#              'aaabchilnr': {'abranchial'},
#              'aaabchiilmnrs': {'abranchialism'},
#              'aaabchinnr': {'abranchian'},
#              'aaaabchinrt': {'abranchiata'},
#              'aaabcehinrt': {'abranchiate'},
#              'aabchinorsu': {'abranchious'},
#              'aaabrsx': {'abrasax', 'abraxas'},
#              'aabhrs': {'abrash'},
#              'aabeeimorrst': {'abrasiometer'},
#              'aabinors': {'abrasion', 'sorabian'},
#              'aabeirsv': {'abrasive'},
#              'aablorst': {'abrastol', 'albatros'},
#              'aabmru': {'abraum'},
#              'aabcert': {'abreact', 'bractea', 'cabaret'},
#              'aabceinort': {'abreaction'},
#              'aaberst': {'abreast'},
#              'abceennoru': {'abrenounce'},
#              'abert': {'abret', 'bater', 'berat'},
#              'abcior': {'abrico'},
#              'abdegir': {'abridge', 'brigade'},
#              'aabbdeegilr': {'abridgeable'},
#              'abddegir': {'abridged'},
#              'abddegilry': {'abridgedly'},
#              'abdegirr': {'abridger'},
#              'abdegimnrt': {'abridgment'},
#              'abimr': {'abrim', 'birma'},
#              'abinr': {'abrin', 'bairn', 'brain', 'brian', 'rabin'},
#              'abeilrst': {'abristle', 'libertas'},
#              'aabchor': {'abroach'},
#              'aabcmoor': {'abrocoma'},
#              'abcemoor': {'abrocome'},
#              'aabbeglor': {'abrogable'},
#              'aabegort': {'abrogate'},
#              'aabginoort': {'abrogation'},
#              'aabegiortv': {'abrogative'},
#              'aabgoorrt': {'abrogator'},
#              'aabmor': {'abroma'},
#              'aabinor': {'abronia'},
#              'abkoor': {'abrook'},
#              'aabmnortu': {'abrotanum'},
#              'abeinort': {'abrotine', 'baritone', 'obtainer', 'reobtain'},
#              'abprtu': {'abrupt'},
#              'abdelprtuy': {'abruptedly'},
#              'abinoprtu': {'abruption'},
#              'ablprtuy': {'abruptly'},
#              'abenprsstu': {'abruptness'},
#              'abrsu': {'abrus', 'bursa', 'subra'},
#              'aablmos': {'absalom', 'balsamo'},
#              'aabeemprs': {'absampere'},
#              'aaabkors': {'absaroka'},
#              'aabeikorst': {'absarokite'},
#              'abcesss': {'abscess'},
#              'abcdeesss': {'abscessed'},
#              'abceinosss': {'abscession'},
#              'abceoorssst': {'abscessroot'},
#              'abcdins': {'abscind'},
#              'abceiss': {'abscise', 'scabies'},
#              'abciinoss': {'abscision'},
#              'abcisss': {'absciss'},
#              'aabcisss': {'abscissa'},
#              'aabceisss': {'abscissae'},
#              'abceisss': {'abscisse'},
#              'abciinosss': {'abscission'},
#              'abccenos': {'absconce'},
#              'abcdnos': {'abscond'},
#              'abcddenos': {'absconded'},
#              'abcddelnosy': {'abscondedly'},
#              'abccdeennos': {'abscondence'},
#              'abcdenors': {'absconder'},
#              'aabcnoss': {'absconsa'},
#              'abbclmoosu': {'abscoulomb'},
#              'abceens': {'absence'},
#              'abenst': {'absent', 'basten'},
#              'aabeinnostt': {'absentation'},
#              'abeeenst': {'absentee'},
#              'abeeeimnsst': {'absenteeism'},
#              'abeeehinpsst': {'absenteeship'},
#              'abeenrst': {'absenter', 'reabsent'},
#              'abelnsty': {'absently'},
#              'abeemnnstt': {'absentment'},
#              'abddeeilmnnsty': {'absentmindedly'},
#              'abeennssst': {'absentness'},
#              'aaabdfrs': {'absfarad'},
#              'abehnrsy': {'abshenry'},
#              'abis': {'absi', 'bais', 'bias', 'isba'},
#              'abehinst': {'absinthe'},
#              'aabhiilnst': {'absinthial'},
#              'aabhiinnst': {'absinthian'},
#              'aabehiinstt': {'absinthiate'},
#              'abchiinst': {'absinthic'},
#              'abhiinnst': {'absinthin'},
#              'abehiinnst': {'absinthine'},
#              'abhiimnsst': {'absinthism'},
#              'abchiiimnsst': {'absinthismic'},
#              'abhiimnstu': {'absinthium'},
#              'abhilnost': {'absinthol'},
#              'abist': {'absit', 'batis'},
#              'abhmos': {'absmho', 'absohm'},
#              'abelostu': {'absolute'},
#              'abellostuy': {'absolutely'},
#              'abeelnossstu': {'absoluteness'},
#              'abilnoostu': {'absolution'},
#              'abilmosstu': {'absolutism'},
#              'abilossttu': {'absolutist'},
#              'abciilossttu': {'absolutistic'},
#              'aabciilllossttuy': {'absolutistically'},
#              'abeilostuv': {'absolutive'},
#              'aabiilnoosttuz': {'absolutization'},
#              'abeilostuz': {'absolutize'},
#              'abloorstuy': {'absolutory'},
#              'aabbellosv': {'absolvable'},
#              'aabloorstvy': {'absolvatory'},
#              'abelosv': {'absolve'},
#              'abelnostv': {'absolvent'},
#              'abelorsv': {'absolver'},
#              'abiloorstv': {'absolvitor'},
#              'abiloorstvy': {'absolvitory'},
#              'aabnnost': {'absonant'},
#              'abnoossu': {'absonous'},
#              'abbors': {'absorb'},
#              'aabbbiilorsty': {'absorbability'},
#              'aabbbelors': {'absorbable'},
#              'abbdeors': {'absorbed'},
#              'abbdelorsy': {'absorbedly'},
#              'abbdeenorsss': {'absorbedness'},
#              'aabbceefinorst': {'absorbefacient'},
#              'abbcenorsy': {'absorbency'},
#              'abbenorst': {'absorbent'},
#              'abbeorrs': {'absorber', 'reabsorb'},
#              'abbginors': {'absorbing'},
#              'abbgilnorsy': {'absorbingly'},
#              'abbiinoorst': {'absorbition'},
#              'aboprst': {'absorpt', 'barpost'},
#              'aabcenoprst': {'absorptance'},
#              'abeeimooprrstt': {'absorptiometer'},
#              'abceiimooprrstt': {'absorptiometric'},
#              'abinooprst': {'absorption'},
#              'abeioprstv': {'absorptive'},
#              'abeiloprstvy': {'absorptively'},
#              'abeeinoprssstv': {'absorptiveness'},
#              'abiioprsttvy': {'absorptivity'},
#              'aaabelqsttuu': {'absquatulate'},
#              'aabinst': {'abstain'},
#              'aabeinrst': {'abstainer'},
#              'aabeimnnstt': {'abstainment'},
#              'abeimosstu': {'abstemious'},
#              'abeilmosstuy': {'abstemiously'},
#              'abeeimnosssstu': {'abstemiousness'},
#              'abeinnostt': {'abstention'},
#              'abeiinnossttt': {'abstentionist'},
#              'abeinossttu': {'abstentious'},
#              'abeegrst': {'absterge'},
#              'abeegnrstt': {'abstergent'},
#              'abeinorsst': {'abstersion'},
#              'abeeirsstv': {'abstersive'},
#              'abeeeinrsssstv': {'abstersiveness'},
#              'abceeinnst': {'abstinence'},
#              'abceinnsty': {'abstinency'},
#              'abeinnstt': {'abstinent'},
#              'aabeiilnnstt': {'abstinential'},
#              'abeilnnstty': {'abstinently'},
#              'aabcrstt': {'abstract'},
#              'aabcderstt': {'abstracted'},
#              'aabcdelrstty': {'abstractedly'},
#              'aabcdeenrssstt': {'abstractedness'},
#              'aabcerrstt': {'abstracter'},
#              'aabcinorstt': {'abstraction'},
#              'aaabcilnorstt': {'abstractional'},
#              'aabciimnorsstt': {'abstractionism'},
#              'aabciinorssttt': {'abstractionist'},
#              'aabciiorsstttu': {'abstractitious'},
#              'aabceirsttv': {'abstractive'},
#              'aabceilrsttvy': {'abstractively'},
#              'aabceeinrsssttv': {'abstractiveness'},
#              'aabclrstty': {'abstractly'},
#              'aabcenrssstt': {'abstractness'},
#              'aabcorrstt': {'abstractor'},
#              'aabehnrstt': {'abstrahent'},
#              'abcdeirstt': {'abstricted'},
#              'abciinorstt': {'abstriction'},
#              'abersstu': {'abstruse'},
#              'abelrsstuy': {'abstrusely'},
#              'abeenrsssstu': {'abstruseness'},
#              'abinorsstu': {'abstrusion'},
#              'abirssttuy': {'abstrusity'},
#              'abemsu': {'absume'},
#              'abimnopstu': {'absumption'},
#              'abdrsu': {'absurd'},
#              'abdirstuy': {'absurdity'},
#              'abdlrsuy': {'absurdly'},
#              'abdenrsssu': {'absurdness'},
#              'ablostv': {'absvolt'},
#              'abrsstuy': {'absyrtus'},
#              'aabeilmnrt': {'abterminal'},
#              'aabhint': {'abthain', 'habitan'},
#              'aabehiinrt': {'abthainrie'},
#              'aabhinrty': {'abthainry'},
#              'aaabeghnt': {'abthanage'},
#              'abu': {'abu'},
#              'abccou': {'abucco'},
#              'aabilu': {'abulia'},
#              'abcilu': {'abulic', 'baculi'},
#              'aaabilmnou': {'abulomania'},
#              'aabnu': {'abuna'},
#              'aabcdennu': {'abundance'},
#              'aabcdnnuy': {'abundancy'},
#              'aabdnntu': {'abundant'},
#              'aaabdinntu': {'abundantia'},
#              'aabdlnntuy': {'abundantly'},
#              'aabru': {'abura'},
#              'aabboruuz': {'aburabozu'},
#              'aabbnru': {'aburban'},
#              'abrstu': {'aburst'},
#              'abnortu': {'aburton'},
#              'aabbelsu': {'abusable'},
#              'abesu': {'abuse'},
#              'abdelsuy': {'abusedly'},
#              'abeesu': {'abusee'},
#              'abeflsuu': {'abuseful'},
#              'abefllsuuy': {'abusefully'},
#              'abeeflnsssuu': {'abusefulness'},
#              'abersu': {'abuser'},
#              'abinosu': {'abusion'},
#              'abiossuu': {'abusious'},
#              'abeisuv': {'abusive'},
#              'abeilsuvy': {'abusively'},
#              'abeeinsssuv': {'abusiveness'},
#              'abtu': {'abut', 'tabu', 'tuba'},
#              'aabtu': {'abuta', 'bauta'},
#              'abemnttu': {'abutment'},
#              'aablttu': {'abuttal'},
#              'aberttu': {'abutter'},
#              'abginttu': {'abutting'},
#              'abuzz': {'abuzz'},
#              'ablotv': {'abvolt'},
#              'aabbw': {'abwab'},
#              'aby': {'aby', 'bay'},
#              'abmsy': {'abysm'},
#              'aablmsy': {'abysmal', 'balsamy'},
#              'aabllmsyy': {'abysmally'},
#              'abssy': {'abyss'},
#              'aablssy': {'abyssal'},
#              'aabiinnssy': {'abyssinian'},
#              'abbcehinnoossty': {'abyssobenthonic'},
#              'abhilossty': {'abyssolith'},
#              'aabcegilopssy': {'abyssopelagic'},
#              'aaacccehint': {'acacatechin'},
#              'aaacccehlot': {'acacatechol'},
#              'aacceint': {'acacetin'},
#              'aaacci': {'acacia'},
#              'aaaccin': {'acacian'},
#              'aacciin': {'acaciin'},
#              'aaccin': {'acacin'},
#              'aacdeem': {'academe'},
#              'aaacdeilm': {'academial'},
#              'aaacdeimn': {'academian'},
#              'aaccdeim': {'academic'},
#              'aaaccdeilm': {'academical'},
#              'aaaccdeillmy': {'academically'},
#              'aaaccdeilms': {'academicals'},
#              'aaaccdeiimn': {'academician'},
#              'aaccdeiimms': {'academicism'},
#              'aacdeimms': {'academism'},
#              'aacdeimst': {'academist'},
#              'aacdeeimt': {'academite', 'acetamide'},
#              'aaacdeiimnotz': {'academization'},
#              'aacdeeimz': {'academize'},
#              'aacdemsu': {'academus'},
#              'aacdemy': {'academy'},
#              'aaacdi': {'acadia'},
#              'aaacdeiilt': {'acadialite'},
#              'aaacdin': {'acadian'},
#              'aacdei': {'acadie', 'acedia', 'adicea'},
#              'aaacen': {'acaena'},
#              'aacjou': {'acajou'},
#              'aacehlp': {'acaleph', 'acephal'},
#              'aaacehlp': {'acalepha', 'acephala'},
#              'aaaceehlp': {'acalephae', 'apalachee'},
#              'aaacehlnp': {'acalephan', 'acephalan'},
#              'aacdehilop': {'acalephoid'},
#              'aaacclly': {'acalycal'},
#              'aacceilny': {'acalycine'},
#              'aaccilnosuy': {'acalycinous'},
#              'aaaccelltuy': {'acalyculate'},
#              'aaachlpy': {'acalypha'},
#              'aaaceelprty': {'acalypterae'},
#              'aaaaclprtty': {'acalyptrata'},
#              'aaaacelprtty': {'acalyptratae'},
#              'aaacelprtty': {'acalyptrate', 'calyptratae'},
#              'aaacmr': {'acamar', 'camara', 'maraca'},
#              'aaacimps': {'acampsia'},
#              'aaacn': {'acana'},
#              'aaaccenosu': {'acanaceous'},
#              'aaaccilnno': {'acanonical'},
#              'aachnt': {'acanth', 'anchat', 'tanach'},
#              'aaachnt': {'acantha'},
#              'aaaacceehnt': {'acanthaceae'},
#              'aaaccehnostu': {'acanthaceous'},
#              'aaacdhnt': {'acanthad'},
#              'aaaachinrt': {'acantharia'},
#              'aaachint': {'acanthia', 'achatina'},
#              'aaachilnt': {'acanthial', 'calathian'},
#              'aachinnt': {'acanthin', 'chinanta'},
#              'aacehinnt': {'acanthine'},
#              'aachinnot': {'acanthion'},
#              'aacehintt': {'acanthite'},
#              'aaacchnooprstu': {'acanthocarpous'},
#              'aaaaccehhlnopt': {'acanthocephala'},
#              'aaaaccehhlnnopt': {'acanthocephalan'},
#              'aaaccehhilnopt': {'acanthocephali'},
#              'aaaccehhlnoopstu': {'acanthocephalous'},
#              'aacceehnorstu': {'acanthocereus'},
#              'aaaccdhlnoostu': {'acanthocladous'},
#              'aaacdehnot': {'acanthodea'},
#              'aaacdehnnot': {'acanthodean'},
#              'aacdehinot': {'acanthodei'},
#              'aacdehnost': {'acanthodes'},
#              'aaacdhinnot': {'acanthodian'},
#              'aaacddehinot': {'acanthodidae'},
#              'aacdhiinot': {'acanthodii'},
#              'aacdhiinnot': {'acanthodini'},
#              'aacdhinot': {'acanthoid'},
#              'aachilmnnoot': {'acantholimon'},
#              'aaaccghillnoot': {'acanthological'},
#              'aacghlnooty': {'acanthology'},
#              'aachilnossty': {'acantholysis'},
#              'aaachmnot': {'acanthoma'},
#              'aaacdeehimnort': {'acanthomeridae'},
#              'aachnnot': {'acanthon'},
#              'aaaachnnoptx': {'acanthopanax'},
#              'aachhinopst': {'acanthophis'},
#              'aachhnoooprstu': {'acanthophorous'},
#              'aacdhnoopt': {'acanthopod'},
#              'aacdhnooopstu': {'acanthopodous'},
#              'aaachmnooopsttu': {'acanthopomatous'},
#              'aacehnooprt': {'acanthopore'},
#              'aaacehnnoprtt': {'acanthopteran'},
#              'aacehinoprtt': {'acanthopteri'},
#              'aacehnooprsttu': {'acanthopterous'},
#              'aaaceghinnoprtty': {'acanthopterygian'},
#              'aaceghiinoprtty': {'acanthopterygii'},
#              'aachinosst': {'acanthosis'},
#              'aachnostu': {'acanthous'},
#              'aaacdehinrtu': {'acanthuridae'},
#              'aachnrstuu': {'acanthurus'},
#              'aachnstu': {'acanthus'},
#              'aaacinp': {'acapnia'},
#              'aaacilnp': {'acapnial'},
#              'aaaclprsu': {'acapsular'},
#              'aacpu': {'acapu'},
#              'aacclopu': {'acapulco'},
#              'aaacr': {'acara', 'araca'},
#              'aaaciprs': {'acarapis'},
#              'aaacdir': {'acardia', 'acarida', 'arcadia'},
#              'aaaccdir': {'acardiac'},
#              'aacir': {'acari'},
#              'aaacinr': {'acarian', 'acarina', 'acrania'},
#              'aaaciirss': {'acariasis'},
#              'aaaccdiilr': {'acaricidal'},
#              'aaccdeiir': {'acaricide'},
#              'aacdir': {'acarid', 'cardia', 'carida'},
#              'aaacdeir': {'acaridea'},
#              'aaacdeinr': {'acaridean'},
#              'aaacdiimmortu': {'acaridomatium'},
#              'aacfimorr': {'acariform'},
#              'aaceinr': {'acarine', 'acraein', 'arecain'},
#              'aaciinorss': {'acarinosis'},
#              'aacccdeiimoru': {'acarocecidium'},
#              'aaacdeiimorrstt': {'acarodermatitis'},
#              'aacdior': {'acaroid'},
#              'aaclor': {'acarol'},
#              'aacgiloorst': {'acarologist'},
#              'aacgloory': {'acarology'},
#              'aachilooprsu': {'acarophilous'},
#              'aaabchioopr': {'acarophobia'},
#              'aaccioortx': {'acarotoxic'},
#              'aaceloprsu': {'acarpelous'},
#              'aacoprsu': {'acarpous'},
#              'aacrsu': {'acarus'},
#              'aacsstu': {'acastus', 'astacus'},
#              'aaaccceiltt': {'acatalectic'},
#              'aaaaceilpst': {'acatalepsia'},
#              'aaacelpsty': {'acatalepsy'},
#              'aaacceilptt': {'acataleptic'},
#              'aaaacccilltt': {'acatallactic'},
#              'aaaaacehimstt': {'acatamathesia'},
#              'aaaaachipst': {'acataphasia'},
#              'aaaciopsst': {'acataposis'},
#              'aaaaacisstt': {'acatastasia'},
#              'aaaaccisttt': {'acatastatic'},
#              'aacet': {'acate'},
#              'aaaccegilort': {'acategorical'},
#              'aacerty': {'acatery'},
#              'aaaachirst': {'acatharsia'},
#              'aaachrsty': {'acatharsy'},
#              'aacchilot': {'acatholic', 'chaotical'},
#              'aaacdlu': {'acaudal'},
#              'aaacdetu': {'acaudate', 'ecaudata'},
#              'aacceelnstu': {'acaulescent'},
#              'aaceilnu': {'acauline'},
#              'aacelosu': {'acaulose'},
#              'aaclosuu': {'acaulous'},
#              'aacc': {'acca', 'caca'},
#              'accdee': {'accede'},
#              'acccdeeen': {'accedence'},
#              'accdeer': {'acceder'},
#              'aabcceeellr': {'accelerable'},
#              'aaccdeelnor': {'accelerando'},
#              'aacceelnrt': {'accelerant'},
#              'aacceeelrt': {'accelerate'},
#              'aaccdeeelrt': {'accelerated'},
#              'aaccdeeellrty': {'acceleratedly'},
#              'aacceeilnort': {'acceleration'},
#              'aacceeeilrtv': {'accelerative'},
#              'aacceelorrt': {'accelerator', 'retrocaecal'},
#              'aacceelorrty': {'acceleratory'},
#              'aacceeghloprr': {'accelerograph'},
#              'acceeeelmorrt': {'accelerometer'},
#              'accden': {'accend'},
#              'abccdeiiilnty': {'accendibility'},
#              'abccdeeiln': {'accendible'},
#              'acceinnos': {'accension'},
#              'accenors': {'accensor'},
#              'accent': {'accent'},
#              'acceelnsst': {'accentless'},
#              'accenort': {'accentor'},
#              'aabcceelntu': {'accentuable'},
#              'aaccelntu': {'accentual'},
#              'aacceilnttuy': {'accentuality'},
#              'aaccellntuy': {'accentually'},
#              'aacceenttu': {'accentuate'},
#              'aacceinnottu': {'accentuation'},
#              'aaccenorttu': {'accentuator'},
#              'accenstu': {'accentus'},
#              'accept': {'accept'},
#              'aabcceiilptty': {'acceptability'},
#              'aabcceelpt': {'acceptable'},
#              'aabcceeelnpsst': {'acceptableness'},
#              'aabccelpty': {'acceptably'},
#              'aaccceenpt': {'acceptance'},
#              'aacccenpty': {'acceptancy'},
#              'aaccenptt': {'acceptant'},
#              'aacceinoptt': {'acceptation'},
#              'accdeept': {'accepted'},
#              'accdeelpty': {'acceptedly'},
#              'acceeprt': {'accepter'},
#              'aacceeilptt': {'acceptilate'},
#              'aacceiilnoptt': {'acceptilation'},
#              'acceinopt': {'acception', 'peccation'},
#              'acceeiptv': {'acceptive'},
#              'acceoprt': {'acceptor'},
#              'acceeprsst': {'acceptress'},
#              'acceers': {'accerse'},
#              'acceiinorst': {'accersition'},
#              'acceiorrst': {'accersitor'},
#              'access': {'access'},
#              'aacceilrssy': {'accessarily'},
#              'aacceeinrssss': {'accessariness'},
#              'aaccerssy': {'accessary'},
#              'aaccehiprsssy': {'accessaryship'},
#              'abcceiiilssty': {'accessibility'},
#              'abcceeilss': {'accessible'},
#              'abcceilssy': {'accessibly'},
#              'acceinoss': {'accession'},
#              'aacceilnoss': {'accessional'},
#              'acceeinorss': {'accessioner', 'reaccession'},
#              'acceeissv': {'accessive'},
#              'acceeilssvy': {'accessively'},
#              'acceelssss': {'accessless'},
#              'aacceilorss': {'accessorial'},
#              'acceilorssy': {'accessorily'},
#              'acceeinorssss': {'accessoriness'},
#              'acceiorsssu': {'accessorius'},
#              'acceorssy': {'accessory'},
#              'acccdeein': {'accidence'},
#              'acccdeiny': {'accidency'},
#              'accdeint': {'accident'},
#              'aaccdeilnt': {'accidental'},
#              'aaccdeiilmnst': {'accidentalism'},
#              'aaccdeiilnstt': {'accidentalist'},
#              'aaccdeiilntty': {'accidentality'},
#              'aaccdeillnty': {'accidentally'},
#              'aaccdeeilnnsst': {'accidentalness'},
#              'accddeeint': {'accidented'},
#              'aaccdeiilnt': {'accidential'},
#              'aaccdeiiilntty': {'accidentiality'},
#              'accdeilnty': {'accidently'},
#              'aaccdii': {'accidia'},
#              'accdeii': {'accidie'},
#              'accegin': {'accinge'},
#              'acceiinpt': {'accipient'},
#              'acceiiprt': {'accipiter'},
#              'aacciilprt': {'accipitral'},
#              'aacciiprrty': {'accipitrary'},
#              'acceiiprst': {'accipitres', 'preascitic'},
#              'acceiiinprt': {'accipitrine'},
#              'accimssu': {'accismus'},
#              'acceit': {'accite', 'acetic'},
#              'aaccilm': {'acclaim'},
#              'aaabcceillm': {'acclaimable'},
#              'aacceilmr': {'acclaimer'},
#              'aaaccilmnot': {'acclamation'},
#              'aaacclmort': {'acclamator'},
#              'aaacclmorty': {'acclamatory'},
#              'aaabcceillmt': {'acclimatable'},
#              'aaacciilmnott': {'acclimatation'},
#              'aacceilmt': {'acclimate'},
#              'aacceeilmmntt': {'acclimatement'},
#              'aacciilmnot': {'acclimation'},
#              'aaabcceiillmtz': {'acclimatizable'},
#              'aaacciiilmnottz': {'acclimatization'},
#              'aacceiilmtz': {'acclimatize'},
#              'aacceiilmrtz': {'acclimatizer'},
#              'aacceilmrtu': {'acclimature'},
#              'aaccilln': {'acclinal'},
#              'aacceilnt': {'acclinate', 'analectic'},
#              'acciilostuv': {'acclivitous'},
#              'acciiltvy': {'acclivity'},
#              'accilosuv': {'acclivous'},
#              'accloy': {'accloy'},
#              'aaccost': {'accoast'},
#              'accilo': {'accoil', 'calico'},
#              'aaccdelo': {'accolade'},
#              'aaccddelo': {'accoladed'},
#              'aaccdelot': {'accolated'},
#              'accelnot': {'accolent'},
#              'accello': {'accolle'},
#              'aabcciimnnoot': {'accombination'},
#              'aabccdelmmoo': {'accommodable'},
#              'aabccdeelmmnooss': {'accommodableness'},
#              'aaccdemmoot': {'accommodate'},
#              'aaccdelmmooty': {'accommodately'},
#              'aaccdeemmnoosst': {'accommodateness'},
#              'aaccdgimmnoot': {'accommodating'},
#              'aaccdgilmmnooty': {'accommodatingly'},
#              'aaccdimmnooot': {'accommodation'},
#              'aaaccdilmmnooot': {'accommodational'},
#              'aaccdeimmootv': {'accommodative'},
#              'aaccdeeimmnoosstv': {'accommodativeness'},
#              'aaccdmmooort': {'accommodator'},
#              'aacceimnopr': {'accompanier'},
#              'aacceimmnnopt': {'accompaniment'},
#              'aaacceilmmnnopt': {'accompanimental'},
#              'aaccimnopst': {'accompanist'},
#              'aaccmnopy': {'accompany'},
#              'aaccimnopsty': {'accompanyist'},
#              'acceeilmoptv': {'accompletive'},
#              'accceilmop': {'accomplice'},
#              'acccehiilmopps': {'accompliceship'},
#              'accciilmopty': {'accomplicity'},
#              'acchilmops': {'accomplish'},
#              'aabccehillmops': {'accomplishable'},
#              'accdehilmops': {'accomplished'},
#              'accehilmoprs': {'accomplisher', 'reaccomplish'},
#              'accehilmmnopst': {'accomplishment'},
#              'acchilmopst': {'accomplisht'},
#              'accmopt': {'accompt', 'compact'},
#              'accdor': {'accord'},
#              'aabccdelor': {'accordable'},
#              'aacccdenor': {'accordance'},
#              'aacccdnory': {'accordancy'},
#              'aaccdnort': {'accordant'},
#              'aaccdlnorty': {'accordantly'},
#              'accdeorr': {'accorder', 'reaccord'},
#              'accdginor': {'according'},
#              'accdgilnory': {'accordingly'},
#              'accdinoor': {'accordion'},
#              'accdiinoorst': {'accordionist'},
#              'aacceooprrt': {'accorporate'},
#              'aaccinoooprrt': {'accorporation'},
#              'accost': {'accost'},
#              'aabccelost': {'accostable'},
#              'accdeost': {'accosted'},
#              'acccehou': {'accouche'},
#              'accceehmnotu': {'accouchement'},
#              'acccehoruu': {'accoucheur'},
#              'accceehosuu': {'accoucheuse'},
#              'accnotu': {'account'},
#              ...})

# %%
# keep only the key/value pairs where the set has more than one element;
# this is now a regular dict

anagrams_by_sig = {sig: wordset for sig, wordset in words_by_sig.items() if len(wordset) > 1}

# %%
anagrams_by_sig
# Out:
# {'aal': {'aal', 'ala'},
#  'aam': {'aam', 'ama'},
#  'aacinor': {'aaronic', 'nicarao', 'ocarina'},
#  'aaeinort': {'aaronite', 'aeration'},
#  'aaru': {'aaru', 'aura'},
#  'ab': {'ab', 'ba'},
#  'aab': {'aba', 'baa'},
#  'aabc': {'abac', 'caba'},
#  'aabcort': {'abactor', 'acrobat'},
#  'aabft': {'abaft', 'bafta'},
#  'aabelno': {'abalone', 'balonea'},
#  'aabdennor': {'abandoner', 'reabandon'},
#  'aabcin': {'abanic', 'bianca'},
#  'aabirs': {'abaris', 'arabis'},
#  'aabs': {'abas', 'saba'},
#  'aabers': {'abaser', 'abrase'},
#  'aabet': {'abate', 'ateba', 'batea', 'beata'},
#  'aabert': {'abater', 'artabe', 'eartab', 'trabea'},
#  'abb': {'abb', 'bab'},
#  'aabb': {'abba', 'baba'},
#  'abbey': {'abbey', 'bebay'},
#  'abby': {'abby', 'baby'},
#  'aabdt': {'abdat', 'batad'},
#  'abdeil': {'abdiel', 'baldie'},
#  'aaabdgiilmnnoov': {'abdominovaginal', 'vaginoabdominal'},
#  'aabcdeiilmnoosv': {'abdominovesical', 'vesicoabdominal'},
#  'abe': {'abe', 'bae', 'bea'},
#  'abde': {'abed', 'bade', 'bead'},
#  'abel': {'abel', 'able', 'albe', 'bale', 'beal', 'bela', 'blae'},
#  'abeel': {'abele', 'albee'},
#  'aabeiln': {'abelian', 'nebalia'},
#  'abceeinrt': {'abenteric', 'bicrenate'},
#  'aabeir': {'aberia', 'baeria', 'baiera'},
#  'abet': {'abet', 'bate', 'beat', 'beta'},
#  'abeemntt': {'abetment', 'batement'},
#  'abeortt': {'abettor', 'taboret'},
#  'abehnorrt': {'abhorrent', 'earthborn'},
#  'abehorrr': {'abhorrer', 'harborer'},
#  'abdeir': {'abider', 'bardie'},
#  'abeis': {'abies', 'beisa'},
#  'aabill': {'abilla', 'labial'},
#  'abilo': {'abilo', 'aboil'},
#  'abir': {'abir', 'bari', 'rabi'},
#  'abinost': {'abiston', 'bastion'},
#  'abeirtu': {'abiuret', 'aubrite', 'biurate', 'rubiate'},
#  'aabkr': {'abkar', 'arkab'},
#  'aabhks': {'abkhas', 'kasbah'},
#  'aaabceltt': {'ablactate', 'cabaletta'},
#  'aabelr': {'ablare', 'arable', 'arbela'},
#  'aabceilmst': {'ablastemic', 'masticable'},
#  'aabilnot': {'ablation', 'obtainal'},
#  'aabltu': {'ablaut', 'tabula'},
#  'abeelnss': {'ableness', 'blaeness', 'sensable'},
#  'aabeilps': {'ablepsia', 'epibasal'},
#  'abelr': {'abler', 'baler', 'belar', 'blare', 'blear'},
#  'abelst': {'ablest', 'stable', 'tables'},
#  'ablmoo': {'abloom', 'mabolo'},
#  'ablow': {'ablow', 'balow', 'bowla'},
#  'abdelu': {'ablude', 'belaud'},
#  'abelntu': {'abluent', 'tunable'},
#  'abilnotu': {'ablution', 'abutilon'},
#  'ably': {'ably', 'blay', 'yalb'},
#  'abhmo': {'abmho', 'abohm'},
#  'abenr': {'abner', 'arneb', 'reban'},
#  'abent': {'abnet', 'beant'},
#  'abo': {'abo', 'boa'},
#  'aabdor': {'aboard', 'aborad', 'abroad'},
#  'abdeo': {'abode', 'adobe'},
#  'abehilors': {'abolisher', 'reabolish'},
#  'abgnoo': {'abongo', 'gaboon'},
#  'aablor': {'aboral', 'arbalo'},
#  'abdor': {'abord', 'bardo', 'board', 'broad', 'dobra', 'dorab'},
#  'abort': {'abort', 'tabor'},
#  'abcdeiiort': {'aborticide', 'bacterioid'},
#  'abeinortt': {'abortient', 'torbanite'},
#  'abinort': {'abortin', 'taborin'},
#  'abinoort': {'abortion', 'robotian'},
#  'abeiortv': {'abortive', 'bravoite'},
#  'abostu': {'abouts', 'basuto'},
#  'aabmr': {'abram', 'ambar'},
#  'aabimrs': {'abramis', 'arabism'},
#  'aaabrsx': {'abrasax', 'abraxas'},
#  'aabinors': {'abrasion', 'sorabian'},
#  'aablorst': {'abrastol', 'albatros'},
#  'aabcert': {'abreact', 'bractea', 'cabaret'},
#  'abert': {'abret', 'bater', 'berat'},
#  'abdegir': {'abridge', 'brigade'},
#  'abimr': {'abrim', 'birma'},
#  'abinr': {'abrin', 'bairn', 'brain', 'brian', 'rabin'},
#  'abeilrst': {'abristle', 'libertas'},
#  'abeinort': {'abrotine', 'baritone', 'obtainer', 'reobtain'},
#  'abrsu': {'abrus', 'bursa', 'subra'},
#  'aablmos': {'absalom', 'balsamo'},
#  'abceiss': {'abscise', 'scabies'},
#  'abenst': {'absent', 'basten'},
#  'abeenrst': {'absenter', 'reabsent'},
#  'abis': {'absi', 'bais', 'bias', 'isba'},
#  'abist': {'absit', 'batis'},
#  'abhmos': {'absmho', 'absohm'},
#  'abbeorrs': {'absorber', 'reabsorb'},
#  'aboprst': {'absorpt', 'barpost'},
#  'aabhint': {'abthain', 'habitan'},
#  'abcilu': {'abulic', 'baculi'},
#  'abtu': {'abut', 'tabu', 'tuba'},
#  'aabtu': {'abuta', 'bauta'},
#  'aby': {'aby', 'bay'},
#  'aablmsy': {'abysmal', 'balsamy'},
#  'aacdeeimt': {'academite', 'acetamide'},
#  'aacdei': {'acadie', 'acedia', 'adicea'},
#  'aacehlp': {'acaleph', 'acephal'},
#  'aaacehlp': {'acalepha', 'acephala'},
#  'aaaceehlp': {'acalephae', 'apalachee'},
#  'aaacehlnp': {'acalephan', 'acephalan'},
#  'aaacelprtty': {'acalyptrate', 'calyptratae'},
#  'aaacmr': {'acamar', 'camara', 'maraca'},
#  'aachnt': {'acanth', 'anchat', 'tanach'},
#  'aaachint': {'acanthia', 'achatina'},
#  'aaachilnt': {'acanthial', 'calathian'},
#  'aachinnt': {'acanthin', 'chinanta'},
#  'aaacr': {'acara', 'araca'},
#  'aaacdir': {'acardia', 'acarida', 'arcadia'},
#  'aaacinr': {'acarian', 'acarina', 'acrania'},
#  'aacdir': {'acarid', 'cardia', 'carida'},
#  'aaceinr': {'acarine', 'acraein', 'arecain'},
#  'aacsstu': {'acastus', 'astacus'},
#  'aacchilot': {'acatholic', 'chaotical'},
#  'aaacdetu': {'acaudate', 'ecaudata'},
#  'aacc': {'acca', 'caca'},
#  'aacceelorrt': {'accelerator', 'retrocaecal'},
#  'acceinopt': {'acception', 'peccation'},
#  'acceeinorss': {'accessioner', 'reaccession'},
#  'acceiiprst': {'accipitres', 'preascitic'},
#  'acceit': {'accite', 'acetic'},
#  'aacceilnt': {'acclinate', 'analectic'},
#  'accilo': {'accoil', 'calico'},
#  'accehilmoprs': {'accomplisher', 'reaccomplish'},
#  'accmopt': {'accompt', 'compact'},
#  'accdeorr': {'accorder', 'reaccord'},
#  'accoy': {'accoy', 'ccoya'},
#  'acceinort': {'accretion', 'anorectic', 'neoarctic'},
#  'aacclru': {'accrual', 'carucal'},
#  'aaccertu': {'accurate', 'carucate'},
#  'accersu': {'accurse', 'accuser'},
#  'aabccelsu': {'accusable', 'subcaecal'},
#  'accdesu': {'accused', 'succade'},
#  'acdey': {'acedy', 'decay'},
#  'acceinrt': {'acentric', 'encratic', 'nearctic'},
#  'acenorstu': {'acentrous', 'courtesan', 'nectarous'},
#  'aacehilp': {'acephali', 'phacelia'},
#  'aaacehilnp': {'acephalina', 'phalaecian'},
#  'acer': {'acer', 'acre', 'care', 'crea', 'race'},
#  'aaacceeer': {'aceraceae', 'arecaceae'},
#  'aacceeorsu': {'aceraceous', 'arecaceous'},
#  'abcer': {'acerb', 'brace', 'caber'},
#  'abcceir': {'acerbic', 'breccia'},
#  'acdelor': {'acerdol', 'coraled'},
#  'aceinr': {'acerin', 'cearin'},
#  'aceorsu': {'acerous', 'carouse', 'euscaro'},
#  'aaceertv': {'acervate', 'revacate'},
#  'aaceinortv': {'acervation', 'vacationer'},
#  'aceeilnruv': {'acervuline', 'avirulence'},
#  'aacdeimot': {'acetamido', 'coadamite'},
#  'aacdeiilnt': {'acetanilid', 'laciniated', 'teniacidal'},
#  'aaceinnot': {'acetanion', 'antoecian'},
#  'aaceinott': {'acetation', 'itaconate'},
#  'aceint': {'acetin', 'actine', 'enatic'},
#  'aacdeeehiillmntty': {'acetmethylanilide', 'methylacetanilide'},
#  'aceinot': {'acetoin', 'aconite', 'anoetic', 'antoeci', 'cetonia'},
#  'acelot': {'acetol', 'colate', 'locate'},
#  'aceenot': {'acetone', 'oceanet'},
#  'aaceinortu': {'acetonuria', 'aeronautic'},
#  'aceinoprty': {'acetopyrin', 'capernoity'},
#  'aceostu': {'acetous', 'outcase'},
#  'acemtu': {'acetum', 'tecuma'},
#  'acceirtu': {'aceturic', 'cruciate'},
#  'ach': {'ach', 'cha'},
#  'aachr': {'achar', 'chara'},
#  'aaceht': {'achate', 'chaeta'},
#  'aceh': {'ache', 'each', 'haec'},
#  'acehirsu': {'acheirus', 'eucharis'},
#  'acehn': {'achen', 'chane', 'chena', 'hance'},
#  'acehr': {'acher', 'arche', 'chare', 'chera', 'rache', 'reach'},
#  'accehinort': {'acherontic', 'anchoretic'},
#  'aaccehilnort': {'acherontical', 'anchoretical'},
#  'aceeht': {'achete', 'hecate', 'teache', 'thecae'},
#  'aaceehlnu': {'acheulean', 'euchlaena'},
#  'achill': {'achill', 'cahill', 'chilla'},
#  'aacehill': {'achillea', 'heliacal'},
#  'aachilo': {'acholia', 'alochia'},
#  'acdehinort': {'achondrite', 'ditrochean', 'ordanchite'},
#  'achor': {'achor', 'chora', 'corah', 'orach', 'roach'},
#  'aachrs': {'achras', 'charas'},
#  'aachmort': {'achromat', 'trachoma'},
#  'aachimnort': {'achromatin', 'chariotman', 'machinator'},
#  'aacchiimnort': {'achromatinic', 'chromatician'},
#  'acehlt': {'achtel', 'chalet', 'thecal', 'thecla'},
#  'achy': {'achy', 'chay'},
#  'aaccdeiltu': {'aciculated', 'claudicate'},
#  'acdi': {'acid', 'cadi', 'caid'},
#  'aaacdehinrt': {'acidanthera', 'cantharidae'},
#  'acdeir': {'acider', 'ericad'},
#  'acdeeiimrt': {'acidimeter', 'mediatrice'},
#  'acdiity': {'acidity', 'adicity'},
#  'acdily': {'acidly', 'acidyl'},
#  'acdeimorty': {'acidometry', 'medicatory', 'radiectomy'},
#  'acdhiiloopsu': {'acidophilous', 'aphidicolous'},
#  'aceir': {'acier', 'aeric', 'ceria', 'erica'},
#  'aaceilr': {'acieral', 'aerical'},
#  'acfimor': {'aciform', 'formica'},
#  'aciilsu': {'acilius', 'iliacus'},
#  'aacinr': {'acinar',
#   'arnica',
#   'canari',
#   'carian',
#   'carina',
#   'crania',
#   'narica'},
#  'acciin': {'acinic', 'incaic'},
#  'acfiimnor': {'aciniform', 'formicina'},
#  'acdeeiinprs': {'acipenserid', 'presidencia'},
#  'acis': {'acis', 'asci', 'saic'},
#  'acekr': {'acker', 'caker', 'crake', 'creak'},
#  'aceky': {'ackey', 'cakey'},
#  'acel': {'acle', 'alec', 'lace'},
#  'aceilosstu': {'acleistous', 'ossiculate'},
#  'acelmno': {'aclemon', 'cloamen'},
#  'aacilln': {'aclinal', 'ancilla'},
#  'aclsy': {'aclys', 'scaly'},
#  'acem': {'acme', 'came', 'mace'},
#  'aceimt': {'acmite', 'micate'},
#  'acen': {'acne', 'cane', 'nace'},
#  'aaceimn': {'acnemia', 'anaemic'},
#  'aacdin': {'acnida', 'anacid', 'dacian'},
#  'aacdlno': {'acnodal', 'canadol', 'locanda'},
#  'acdeno': {'acnode', 'deacon'},
#  'acino': {'acoin', 'oncia'},
#  'aacmo': {'acoma', 'macao'},
#  'aceno': {'acone', 'canoe', 'ocean'},
#  'aacilnot': {'aconital', 'actional', 'anatolic'},
#  'acciinot': {'aconitic', 'cationic', 'itaconic'},
#  'aciinnot': {'aconitin', 'inaction', 'nicotian'},
#  'acimnotu': {'aconitum', 'acontium'},
#  'aacinost': {'acontias', 'tacsonia'},
#  'acinostu': {'acontius', 'anticous'},
#  'acnoop': {'acopon', 'poonac'},
#  'acor': {'acor', 'caro', 'cora', 'orca'},
#  'acnor': {'acorn', 'acron', 'racon'},
#  'acorsu': {'acorus', 'soucar'},
#  'acimosst': {'acosmist', 'massicot', 'somatics'},
#  'aceqstu': {'acquest', 'casquet'},
#  'aabcr': {'acrab', 'braca'},
#  'aaaceinrt': {'acraniate', 'carinatae'},
#  'aaacirt': {'acratia', 'cataria'},
#  'aacemr': {'acream', 'camera', 'mareca'},
#  'acder': {'acred', 'cader', 'cadre', 'cedar'},
#  'acdir': {'acrid', 'caird', 'carid', 'darci', 'daric', 'dirca'},
#  'aacdinr': {'acridan', 'craniad'},
#  'aacdiinr': {'acridian', 'cnidaria'},
#  'aacddeiir': {'acrididae', 'cardiidae', 'cidaridae'},
#  'acdilry': {'acridly', 'acridyl'},
#  'acdiimnoru': {'acridonium', 'dicoumarin'},
#  'aciimnoorsu': {'acrimonious', 'isocoumarin'},
#  'aciirssu': {'acrisius', 'sicarius'},
#  'aacirt': {'acrita', 'arctia'},
#  'aacinrt': {'acritan', 'arctian'},
#  'aceirt': {'acrite', 'arcite', 'tercia', 'triace', 'tricae'},
#  'aacor': {'acroa', 'caroa'},
#  'aacceorr': {'acrocera', 'caracore'},
#  'acciilmnoru': {'acroclinium', 'alcicornium'},
#  'acdorsu': {'acrodus', 'crusado'},
#  'acegnor': {'acrogen', 'cornage'},
#  'aceilnor': {'acrolein',
#   'arecolin',
#   'caroline',
#   'colinear',
#   'cornelia',
#   'creolian',
#   'lonicera'},
#  'achilort': {'acrolith', 'trochila'},
#  'aaccilnor': {'acronical', 'alcoranic'},
#  'acmnory': {'acronym', 'romancy'},
#  'aaceloprt': {'acropetal', 'cleopatra'},
#  'aceors': {'acrose', 'coarse'},
#  'acciorst': {'acrostic', 'sarcotic', 'socratic'},
#  'aaccilorst': {'acrostical', 'socratical'},
#  'aaccillorsty': {'acrostically', 'socratically'},
#  'acciimorsst': {'acrosticism', 'socraticism'},
#  'acciort': {'acrotic', 'carotic'},
#  'acimorst': {'acrotism', 'rotacism'},
#  'acchiooprrt': {'acrotrophic', 'prothoracic'},
#  'aclry': {'acryl', 'caryl', 'clary'},
#  'act': {'act', 'cat'},
#  'aaacdeeinot': {'actaeonidae', 'donatiaceae'},
#  'aacint': {'actian', 'natica', 'tanica'},
#  'acefiirt': {'actifier', 'artifice'},
#  'acint': {'actin', 'antic'},
#  'aacilnt': {'actinal', 'alantic', 'alicant', 'antical'},
#  'acfiimnort': {'actiniform', 'naticiform'},
#  'aceiinnt': {'actinine', 'naticine'},
#  'aciimnst': {'actinism', 'manistic'},
#  'aacgimnort': {'actinogram', 'morganatic'},
#  'acdiinot': {'actinoid', 'diatonic', 'naticoid'},
#  'acinnot': {'actinon', 'cantion', 'contain'},
#  'aaceinnoprtt': {'actinopteran', 'precantation'},
#  'aceiinoprtt': {'actinopteri', 'crepitation', 'precitation'},
#  'acinostt': {'actinost', 'oscitant'},
#  'aacilntu': {'actinula', 'nautical'},
#  'acinot': {'action', 'atonic', 'cation'},
#  'aceinort': {'actioner', 'anerotic', 'ceration', 'creation', 'reaction'},
#  'aabceiltv': {'activable', 'biclavate'},
#  'aaceittv': {'activate', 'cavitate'},
#  'aaciinottv': {'activation', 'cavitation'},
#  'aciintv': {'activin', 'civitan'},
#  'acimnoosty': {'actomyosin', 'inocystoma'},
#  'acnot': {'acton', 'canto', 'octan'},
#  'acort': {'actor', 'corta', 'croat', 'rocta', 'taroc', 'troca'},
#  'achioprst': {'actorship', 'strophaic'},
#  'acst': {'acts', 'cast', 'scat'},
#  'aacorttu': {'actuator', 'autocrat'},
#  'acertu': {'acture', 'cauter', 'curate'},
#  'aacnu': {'acuan', 'aucan'},
#  'abcensu': {'acubens', 'benacus'},
#  'acemnu': {'acumen', 'cueman'},
#  'aceimnosu': {'acuminose', 'mniaceous'},
#  'aaccelmntuuu': {'acutenaculum', 'unaccumulate'},
#  'aceensstu': {'acuteness', 'encaustes'},
#  'acinoorstu': {'acutorsion', 'octonarius'},
#  'acly': {'acyl', 'clay', 'lacy'},
#  'aacilnoty': {'acylation', 'claytonia'},
#  'aceglnoy': {'acylogen', 'cynogale'},
#  'ad': {'ad', 'da'},
#  'aadd': {'adad', 'adda', 'dada'},
#  'aadeg': {'adage', 'agade'},
#  'aadm': {'adam', 'dama'},
#  'aacdim': {'adamic', 'cadmia'},
#  'aadeimn': {'adamine', 'manidae'},
#  'aadeimt': {'adamite', 'amidate'},
#  'aadeimst': {'adamsite', 'diastema'},
#  'aacden': {'adance', 'ecanda'},
#  'aadeprt': {'adapter', 'predata', 'readapt'},
#  'aadinopt': {'adaption', 'adoptian'},
#  'aadiimnopst': {'adaptionism', 'adoptianism'},
#  'aadr': {'adar', 'arad', 'raad', 'rada'},
#  'aademr': {'adarme', 'adream'},
#  'aadt': {'adat', 'data'},
#  'aadnw': {'adawn', 'wadna'},
#  'aadsy': {'adays', 'dasya'},
#  'add': {'add', 'dad'},
#  'adddemnu': {'addendum', 'unmadded'},
#  'adder': {'adder', 'dread', 'readd'},
#  'acddeint': {'addicent', 'dedicant'},
#  'addgilns': {'addlings', 'saddling'},
#  'addeerrss': {'addresser', 'readdress'},
#  'addu': {'addu', 'dadu', 'daud', 'duad'},
#  'addy': {'addy', 'dyad'},
#  'ade': {'ade', 'dae'},
#  'adeem': {'adeem', 'ameed', 'edema'},
#  'aadel': {'adela', 'dalea'},
#  'adeeiln': {'adeline', 'daniele', 'delaine'},
#  'adegiln': {'adeling', 'dealing', 'leading'},
#  'adelops': {'adelops', 'deposal'},
#  'adeimnost': {'ademonist', 'demoniast', 'staminode'},
#  'adeimnopt': {'ademption', 'tampioned'},
#  'acddeinr': {'adendric', 'riddance'},
#  'accdeeinopt': {'adenectopic', 'pentadecoic'},
#  'aadein': {'adenia', 'idaean'},
#  'aacddehmnnooor': {'adenochondroma', 'chondroadenoma'},
#  'aacdemnoosty': {'adenocystoma', 'cystoadenoma'},
#  'aabdefimnoor': {'adenofibroma', 'fibroadenoma'},
#  'aadeilmnoop': {'adenolipoma', 'palaemonoid'},
#  'aaacdemnoors': {'adenosarcoma', 'sarcoadenoma'},
#  'acdeilny': {'adenylic', 'lycaenid'},
#  'adeenpsst': {'adeptness', 'pedantess'},
#  'aadeinoqtu': {'adequation', 'deaquation'},
#  'aadeimr': {'adermia', 'madeira'},
#  'adeimnr': {'adermin', 'amerind', 'dimeran'},
#  'adet': {'adet', 'date', 'tade', 'tead', 'teda'},
#  'adeimsv': {'adevism', 'vedaism'},
#  'adeehr': {'adhere', 'header', 'hedera', 'rehead'},
#  'adeehnrt': {'adherent', 'headrent', 'neatherd', 'threaden'},
#  'aadhinop': {'adiaphon', 'aphodian'},
#  'abdi': {'adib', 'ibad'},
#  'adeil': {'adiel', 'delia', 'ideal'},
#  'adeiux': {'adieux', 'exaudi'},
#  'adeghi': {'adighe', 'hidage'},
#  'adin': {'adin', 'andi', 'dain', 'dani', 'dian', 'naid'},
#  'adeilno': {'adinole', 'idoneal'},
#  'adino': {'adion', 'danio', 'doina', 'donia'},
#  'acdeeilop': {'adipocele', 'cepolidae', 'ploceidae'},
#  'acdeeiopr': {'adipocere', 'percoidea'},
#  'adilpy': {'adipyl', 'plaidy'},
#  'adit': {'adit', 'dita'},
#  'aadilt': {'adital', 'altaid'},
#  'adistu': {'aditus', 'studia'},
#  'adejrstu': {'adjuster', 'readjust'},
#  'aadil': {'adlai', 'alida'},
#  'aadly': {'adlay', 'dayal'},
#  'adelt': {'adlet', 'dealt', 'delta', 'lated', 'taled'},
#  'adeilmnu': {'adlumine', 'unmailed'},
#  'aadmn': {'adman', 'daman', 'namda'},
#  'adim': {'admi', 'amid', 'madi', 'maid'},
#  'acdeiilmn': {'adminicle', 'medicinal'},
#  'adeimr': {'admire', 'armied', 'damier', 'dimera', 'merida'},
#  'addeimr': {'admired', 'diaderm'},
#  'adeimrr': {'admirer', 'madrier', 'married'},
#  'adeiimssv': {'admissive', 'misadvise'},
#  'adimt': {'admit', 'atmid'},
#  'adeeimtt': {'admittee', 'meditate'},
#  'adehimnors': {'admonisher', 'rhamnoside'},
#  'adiimnnoot': {'admonition', 'domination'},
#  'adeiimnotv': {'admonitive', 'dominative'},
#  'adimnoort': {'admonitor', 'dominator'},
#  'aaccdeenns': {'adnascence', 'ascendance'},
#  'aacdennst': {'adnascent', 'ascendant'},
#  'aadent': {'adnate', 'entada'},
#  'ado': {'ado', 'dao', 'oda'},
#  'adhlop': {'adolph', 'pholad'},
#  'aadino': {'adonai', 'adonia'},
#  'acdino': {'adonic', 'anodic'},
#  'adinno': {'adonin', 'nanoid', 'nonaid'},
#  'aadimnor': {'adoniram', 'radioman'},
#  'adeinoz': {'adonize', 'anodize'},
#  'adeoprt': {'adopter', 'protead', 'readopt'},
#  'aadilnoopt': {'adoptional', 'aplodontia'},
#  'aabdiilorty': {'adorability', 'roadability'},
#  'aabdelor': {'adorable', 'roadable'},
#  'aadnort': {'adorant', 'ondatra'},
#  'adeor': {'adore', 'oared', 'oread'},
#  'adeorr': {'adorer', 'roader'},
#  'adnor': {'adorn', 'donar', 'drona', 'radon'},
#  'adenorr': {'adorner', 'readorn'},
#  'aadop': {'adpao', 'apoda'},
#  'adiimnooprss': {'adpromission', 'proadmission'},
#  'adeinnr': {'adrenin', 'nardine'},
#  'adeeinnr': {'adrenine', 'adrienne'},
#  'acdeilnorty': {'adrenolytic', 'declinatory'},
#  'acdeinooprrt': {'adrenotropic', 'incorporated'},
#  'aadinr': {'adrian', 'andira', 'andria', 'radian', 'randia'},
#  'adipr': {'adrip', 'rapid'},
#  'adilorty': {'adroitly', 'dilatory', 'idolatry'},
#  'adopr': {'adrop', 'pardo'},
#  'adry': {'adry', 'dray', 'yard'},
#  'acddeennst': {'adscendent', 'descendant'},
#  'adhimst': {'adsmith', 'mahdist'},
#  'aadlru': {'adular', 'aludra', 'radula'},
#  'aadilnotu': {'adulation', 'laudation'},
#  'aadlortu': {'adulator', 'laudator'},
#  'aadlortuy': {'adulatory', 'laudatory'},
#  'adltu': {'adult', 'dulat'},
#  'adeeilnrtu': {'adulterine', 'laurentide'},
#  'adelnsstu': {'adultness', 'dauntless'},
#  'adinostu': {'adustion', 'sudation'},
#  'adeenv': {'advene', 'evadne'},
#  'adeimnstv': {'adventism', 'vedantism'},
#  'adeinsttv': {'adventist', 'vedantist'},
#  'adeenrtuv': {'adventure', 'unaverted'},
#  'acdeiv': {'advice', 'vedaic'},
#  'ady': {'ady', 'day', 'yad'},
#  'adz': {'adz', 'zad'},
#  'adez': {'adze', 'daze'},
#  'aderz': {'adzer', 'zerda'},
#  'ae': {'ae', 'ea'},
#  'acdefiimoor': {'aecidioform', 'formicoidea'},
#  'aadeiiln': {'aedilian', 'laniidae'},
#  'acdeiil': {'aedilic', 'elaidic'},
#  'adeiilty': {'aedility', 'ideality'},
#  'aaeginp': {'aegipan', 'apinage'},
#  'aeegiinr': {'aegirine', 'erigenia'},
#  'aeegiirt': {'aegirite', 'ariegite'},
#  'aeegl': {'aegle', 'eagle', 'galee'},
#  'aaeenn': {'aenean', 'enaena'},
#  'aaacehilmnoor': {'aeolharmonica', 'chloroanaemia'},
#  'aaeilno': {'aeolian', 'aeolina', 'aeonial'},
#  'aceilo': {'aeolic', 'coelia'},
#  'aeilos': {'aeolis', 'laiose'},
#  'aeilost': {'aeolist', 'isolate'},
#  'aceiilost': {'aeolistic', 'socialite'},
#  'aeno': {'aeon', 'eoan'},
#  'aeinost': {'aeonist', 'asiento', 'satieno'},
#  'aer': {'aer', 'are', 'ear', 'era', 'rea'},
#  'aaeegr': {'aerage', 'graeae'},
#  'aaaeinrr': {'aerarian', 'arenaria'},
#  'aaeilr': {'aerial', 'aralie'},
#  'adeeir': {'aeried', 'dearie'},
#  'aceeginor': {'aerogenic', 'recoinage'},
#  'aaeeghoprrr': {'aerographer', 'areographer'},
#  'aaceghioprr': {'aerographic', 'areographic'},
#  'aaaceghiloprr': {'aerographical', 'areographical'},
#  'aaeghoprry': {'aerography', 'areography'},
#  'acegiloor': {'aerologic', 'areologic'},
#  'aacegilloor': {'aerological', 'areological'},
#  'aegiloorst': {'aerologist', 'areologist'},
#  'aegloory': {'aerology', 'areology'},
#  'aaceimnort': {'aeromantic', 'cameration', 'maceration', 'racemation'},
#  'aeeemorrt': {'aerometer', 'areometer'},
#  'aceeimorrt': {'aerometric', 'areometric'},
#  'aeemorrty': {'aerometry', 'areometry'},
#  'aaeimnorstu': {'aeronautism', 'measuration'},
#  'aeeopr': {'aerope', 'operae'},
#  'acehiilopr': {'aerophilic', 'epichorial'},
#  'aeloors': {'aerosol', 'roseola'},
#  'aaceiorsstt': {'aerostatics', 'aortectasis'},
#  'aery': {'aery', 'eyra', 'yare', 'year'},
#  'aes': {'aes', 'ase', 'sea'},
#  'aceehistt': {'aesthetic', 'chaetites'},
#  'aadehiilot': {'aethalioid', 'haliotidae'},
#  'aaeint': {'aetian', 'antiae', 'taenia'},
#  'aabeosttu': {'aetobatus', 'eastabout'},
#  'abeefilr': {'afebrile', 'balefire', 'fireable'},
#  'aefiln': {'afenil', 'finale'},
#  'aaffir': {'affair', 'raffia'},
#  'aceeffrt': {'affecter', 'reaffect'},
#  'aeeffr': {'affeer', 'raffee'},
#  'aaceffin': {'affiance', 'caffeina'},
#  'aeffimrr': {'affirmer', 'reaffirm'},
#  'aceffilrt': {'afflicter', 'reafflict'},
#  'affy': {'affy', 'yaff'},
#  'aafghn': {'afghan', 'hafgan'},
#  'adefil': {'afield', 'defial'},
#  'aefir': {'afire', 'feria'},
#  'aaeflr': {'aflare', 'rafael'},
#  'aaflt': {'aflat', 'fatal'},
#  'aefhrs': {'afresh', 'fasher', 'ferash'},
#  'aefrt': {'afret', 'after'},
#  'acfir': {'afric', 'firca'},
#  'aafhrs': {'afshar', 'ashraf'},
#  'aft': {'aft', 'fat'},
#  'aacefrtt': {'afteract', 'artefact', 'farcetta', 'farctate'},
#  'aaeefgrt': {'afterage', 'fregatae'},
#  'abeflortw': {'afterblow', 'batfowler'},
#  'aceefmort': {'aftercome', 'forcemeat'},
#  'acefoprrt': {'aftercrop', 'prefactor'},
#  'aefgort': {'aftergo', 'fagoter'},
#  'aefgnrstu': {'afterguns', 'transfuge'},
#  'aaefhmrtt': {'aftermath', 'hamfatter'},
#  'aaeefrsttt': {'afterstate', 'aftertaste'},
#  'aacfilnnotu': {'afunctional', 'unfactional'},
#  'aagl': {'agal', 'agla', 'alga', 'gala'},
#  'aaegilt': {'agalite', 'tailage', 'taliage'},
#  'aaaglm': {'agalma', 'malaga'},
#  'aaagm': {'agama', 'amaga'},
#  'aadgim': {'agamid', 'madiga'},
#  'aaegipt': {'agapeti', 'agpaite'},
#  'aaginoprs': {'agapornis', 'sporangia'},
#  'aagr': {'agar', 'agra', 'gara', 'raga'},
#  'aacgiinr': {'agaricin', 'garcinia'},
#  'aagu': {'agau', 'agua'},
#  'adeg': {'aged', 'egad', 'gade'},
#  'aeeglss': {'ageless', 'eagless'},
#  'aegn': {'agen', 'gaen', 'gane', 'gean', 'gena'},
#  'aceegins': {'agenesic', 'genesiac'},
#  'aeeginss': {'agenesis', 'assignee'},
#  'aaegilnt': {'agential', 'alginate'},
#  'aeegintv': {'agentive', 'negative'},
#  'aegr': {'ager', 'agre', 'gare', 'gear', 'rage'},
#  'aeggr': {'agger', 'gager', 'regga'},
#  'aaegginort': {'aggeration', 'agregation'},
#  'aggry': {'aggry', 'raggy'},
#  'aadgiil': {'agialid', 'galidia'},
#  'abgi': {'agib', 'biga', 'gabi'},
#  'aegil': {'agiel', 'agile', 'galei'},
#  'aeegilnss': {'agileness', 'signalese'},
#  'aegimnstt': {'agistment', 'magnetist'},
#  'agiorst': {'agistor', 'agrotis', 'orgiast'},
#  'aaglos': {'aglaos', 'salago'},
#  'aaeglr': {'aglare', 'alegar', 'galera', 'laager'},
#  'aeglt': {'aglet', 'galet'},
#  'aegly': {'agley', 'galey'},
#  'aaegimnt': {'agmatine', 'agminate'},
#  'aadegimnt': {'agminated', 'diamagnet'},
#  'aagiln': {'agnail', 'linaga'},
#  'aaegmn': {'agname', 'manage'},
#  'aegln': {'agnel', 'angel', 'angle', 'galen', 'genal', 'glean', 'lagen'},
#  'aegns': {'agnes', 'gesan'},
#  'aeginz': {'agnize', 'ganzie'},
#  'aginoss': {'agnosis', 'ganosis'},
#  'acginost': {'agnostic', 'coasting'},
#  'agnsu': {'agnus', 'angus', 'sugan'},
#  'ago': {'ago', 'goa'},
#  'agno': {'agon', 'ango', 'gaon', 'goan', 'gona'},
#  'aaglno': {'agonal', 'angola'},
#  'aegno': {'agone', 'genoa'},
#  'aadgiinno': {'agoniadin', 'anangioid', 'ganoidian'},
#  'acgino': {'agonic', 'angico', 'gaonic', 'goniac'},
#  'aaginost': {'agonista', 'santiago'},
#  'aeginorz': {'agonizer', 'orangize', 'organize'},
#  'aaglr': {'agral', 'argal'},
#  'aaaginr': {'agrania', 'angaria', 'niagara'},
#  'aeegr': {'agree', 'eager', 'eagre'},
#  'adeegr': {'agreed', 'geared'},
#  'aeeggr': {'agrege', 'raggee'},
#  'aaeginrst': {'agrestian', 'gerastian', 'stangeria'},
#  'acegirst': {'agrestic', 'ergastic'},
#  'aagir': {'agria', 'igara'},
#  'acgiilorst': {'agricolist', 'algoristic'},
#  'agilrsu': {'agrilus', 'gularis'},
#  'aginr': {'agrin', 'grain'},
#  'agiort': {'agrito', 'ortiga'},
#  'aagnor': {'agroan', 'angora', 'anogra', 'arango', 'argoan', 'onagra'},
#  'agmor': {'agrom', 'morga'},
#  'adgnoru': {'aground', 'durango'},
#  'aefgru': {'agrufe', 'gaufer', 'gaufre'},
#  'aaginpry': {'agrypnia', 'paginary'},
#  'aagms': {'agsam', 'magas'},
#  'aegu': {'ague', 'auge'},
#  'aghsu': {'agush', 'saugh'},
#  'agstu': {'agust', 'tsuga'},
#  'agy': {'agy', 'gay'},
#  'ah': {'ah', 'ha'},
#  'aehm': {'ahem', 'haem', 'hame'},
#  'aeht': {'ahet', 'haet', 'hate', 'heat', 'thea'},
#  'aehy': {'ahey', 'eyah', 'yeah'},
#  'adhin': {'ahind', 'dinah'},
#  'ahint': {'ahint', 'hiant', 'tahin'},
#  'ahir': {'ahir', 'hair'},
#  'adehm': {'ahmed', 'hemad'},
#  'aehmt': {'ahmet', 'thema'},
#  'aho': {'aho', 'hao'},
#  'ahmo': {'ahom', 'moha'},
#  'aghno': {'ahong', 'hogan'},
#  'aehors': {'ahorse', 'ashore', 'hoarse', 'shorea'},
#  'ahoy': {'ahoy', 'hoya'},
#  'aahimnr': {'ahriman', 'miranha'},
#  'aahns': {'ahsan', 'hansa', 'hasan'},
#  'aht': {'aht', 'hat', 'tha'},
#  'aaehnt': {'ahtena', 'aneath', 'athena'},
#  'ahu': {'ahu', 'auh', 'hau'},
#  'ahmu': {'ahum', 'huma'},
#  'ahntu': {'ahunt', 'haunt', 'thuan', 'unhat'},
#  'adi': {'aid', 'ida'},
#  'aacdein': {'aidance', 'canidae'},
#  'adei': {'aide', 'idea'},
#  'adeinn': {'aidenn', 'andine', 'dannie', 'indane'},
#  'adeir': {'aider', 'deair', 'irade', 'redia'},
#  'adeis': {'aides', 'aside', 'sadie'},
#  'aeil': {'aiel', 'aile', 'elia'},
#  'aegilt': {'aiglet', 'ligate', 'taigle', 'tailge'},
#  'ail': {'ail', 'ila', 'lai'},
#  'aaeiilnnt': {'ailantine', 'antialien'},
#  'aailnot': {'ailanto', 'alation', 'laotian', 'notalia'},
#  'aeeiln': {'aileen', 'elaine'},
#  'aeilnor': {'aileron', 'alienor'},
#  'agiiln': {'ailing', 'angili', 'nilgai'},
#  'aeilmnt': {'ailment', 'aliment'},
#  'aim': {'aim', 'ami', 'ima'},
#  'aeimr': {'aimer', 'maire', 'marie', 'ramie'},
#  'aeilmss': {'aimless', 'melissa', 'seismal'},
#  'aaehiln': {'ainaleh', 'halenia'},
#  'aint': {'aint', 'anti', 'tain', 'tina'},
#  'aino': {'aion', 'naio'},
#  'air': {'air', 'ira', 'ria'},
#  'aair': {'aira', 'aria', 'raia'},
#  'aainr': {'airan', 'arain', 'arian'},
#  'adeimorr': {'airdrome', 'armoried'},
#  'aeir': {'aire', 'eria'},
#  'aeirr': {'airer', 'arrie'},
#  'aeiiklr': {'airlike', 'kiliare'},
#  'aaimnr': {'airman', 'amarin', 'marian', 'marina', 'mirana'},
#  'aaeilnpr': {'airplane', 'perianal'},
#  'aaiilnprst': {'airplanist', 'triplasian'},
#  'airt': {'airt', 'rita', 'tari', 'tiar'},
#  'airy': {'airy', 'yair'},
#  'aeils': {'aisle', 'elias'},
#  'adeils': {'aisled', 'deasil', 'ladies', 'sailed'},
#  'agiilns': {'aisling', 'sailing'},
#  'aiorss': {'aissor', 'rissoa'},
#  'ait': {'ait', 'ati', 'ita', 'tai'},
#  'achit': {'aitch', 'chait', 'chati', 'chita', 'taich', 'tchai'},
#  'aiinot': {'aition', 'itonia'},
#  'aeilz': {'aizle', 'eliza'},
#  'aajr': {'ajar', 'jara', 'raja'},
#  'aahjr': {'ajhar', 'rajah'},
#  'aagju': {'ajuga', 'jagua'},
#  'ak': {'ak', 'ka'},
#  'aakl': {'akal', 'kala'},
#  'aaikl': {'akali', 'alaki'},
#  'aakn': {'akan', 'kana'},
#  'aek': {'ake', 'kea'},
#  'abeik': {'akebi', 'bakie'},
#  'aahk': {'akha', 'kaha'},
#  'aikm': {'akim', 'maki'},
#  'aikn': {'akin', 'kina', 'naik'},
#  'aakk': {'akka', 'kaka'},
#  'aeekn': {'aknee', 'ankee', 'keena'},
#  'ako': {'ako', 'koa', 'oak', 'oka'},
#  'aaakmos': {'akoasma', 'amakosa'},
#  'aku': {'aku', 'auk', 'kua'},
#  'al': {'al', 'la'},
#  'aacilorstu': {'alacritous', 'lactarious', 'lactosuria'},
#  'aailn': {'alain', 'alani', 'liana'},
#  'aaeillt': {'alalite', 'tillaea'},
#  'aalmo': {'alamo', 'aloma'},
#  'aaln': {'alan', 'anal', 'lana'},
#  'aagilnn': {'alangin', 'anginal', 'anglian', 'nagnail'},
#  'aaegilnn': {'alangine', 'angelina', 'galenian'},
#  'aaeilnn': {'alanine', 'linnaea'},
#  'aalns': {'alans', 'lanas', 'nasal'},
#  'aacillnot': {'alantolic', 'allantoic'},
#  'aallny': {'alanyl', 'anally'},
#  'aaelrs': {'alares', 'arales'},
#  'aaailr': {'alaria', 'aralia'},
#  'aacilr': {'alaric', 'racial'},
#  'aalmr': {'alarm', 'malar', 'maral', 'marla', 'ramal'},
#  'aaabellmr': {'alarmable', 'ambarella'},
#  'aadellmry': {'alarmedly', 'medallary'},
#  'aagilmnr': {'alarming', 'marginal'},
#  'aagillmnry': {'alarmingly', 'marginally'},
#  'aailmrst': {'alarmist', 'alastrim'},
#  'aals': {'alas', 'lasa'},
#  'aaailrst': {'alastair', 'salariat'},
#  'aaelrst': {'alaster', 'tarsale'},
#  'aaelnrt': {'alatern', 'lateran'},
#  'aaelnrstu': {'alaternus', 'saturnale'},
#  'abl': {'alb', 'bal', 'lab'},
#  'aabl': {'alba', 'baal', 'bala'},
#  'aabln': {'alban', 'balan', 'banal', 'laban', 'nabal', 'nabla'},
#  'aabeilnt': {'albanite', 'balanite', 'nabalite'},
#  'aabdeilnr': {'albardine', 'drainable'},
#  'aabilmru': {'albarium', 'brumalia'},
#  'aaablt': {'albata', 'atabal', 'balata'},
#  'abdelo': {'albedo', 'doable'},
#  'abeilt': {'albeit',
#   'albite',
#   'baltei',
#   'belait',
#   'betail',
#   'bletia',
#   'libate'},
#  'abelrt': {'albert', 'balter', 'labret', 'tabler'},
#  'aabelrt': {'alberta', 'latebra', 'ratable'},
#  'aabeilnrt': {'albertina', 'trainable'},
#  'abelort': {'alberto', 'bloater', 'latrobe'},
#  'aabdelt': {'albetad', 'datable'},
#  'abil': {'albi', 'bail', 'bali'},
#  'aabiln': {'albian', 'bilaan'},
#  'abiln': {'albin', 'binal', 'blain'},
#  'abilno': {'albino', 'albion', 'alboin', 'oliban'},
#  'aabeilnort': {'alboranite', 'rationable'},
#  'abelnorz': {'albronze', 'blazoner'},
#  'aabclu': {'albuca', 'bacula'},
#  'aabeilmntu': {'albuminate', 'antelabium'},
#  'ablmnruu': {'alburnum', 'laburnum'},
#  'aaccil': {'alcaic', 'cicala'},
#  'aacdeil': {'alcaide', 'alcidae'},
#  'aaceilmn': {'alcamine', 'analcime', 'calamine', 'camelina'},
#  'aaaceilnnrst': {'alcantarines', 'lancasterian'},
#  'acdelo': {'alcedo', 'dacelo'},
#  'acels': {'alces', 'casel', 'scale'},
#  'accehilm': {'alchemic', 'chemical'},
#  'accehiilmst': {'alchemistic', 'hemiclastic'},
#  'aacehlr': {'alchera', 'archeal'},
#  'aachilnrt': {'alchitran', 'clathrina'},
#  'acdeiiln': {'alcidine', 'danielic', 'lecaniid'},
#  'aceiln': {'alcine', 'ancile'},
#  'aclo': {'alco', 'coal', 'cola', 'loca'},
#  'aacelot': {'alcoate', 'coelata'},
#  'acegllo': {'alcogel', 'collage'},
#  'aclor': {'alcor', 'calor', 'carlo', 'carol', 'claro', 'coral'},
#  'aaclnor': {'alcoran', 'ancoral', 'carolan'},
#  'acelov': {'alcove', 'coeval', 'volcae'},
#  'aclnoy': {'alcyon', 'cyanol'},
#  'acelnoy': {'alcyone', 'cyanole'},
#  'aadeilmn': {'aldamine', 'lamnidae'},
#  'aadeelmnt': {'aldeament', 'mandelate'},
#  'adelr': {'alder', 'daler', 'lader'},
#  'aadelmnrry': {'aldermanry', 'marylander'},
#  'adelnr': {'aldern',
#   'darnel',
#   'enlard',
#   'lander',
#   'lenard',
#   'randle',
#   'reland'},
#  'adeilm': {'aldime', 'mailed', 'medial'},
#  'adeiln': {'aldine', 'daniel', 'delian', 'denial', 'enalid', 'leadin'},
#  'adlsu': {'aldus', 'sauld'},
#  'ael': {'ale', 'lea'},
#  'aceelnnor': {'aleconner', 'noncereal'},
#  'acelost': {'alecost', 'lactose', 'scotale', 'talcose'},
#  'aceilorst': {'alectoris', 'sarcolite', 'sclerotia', 'sectorial'},
#  'aceilnort': {'alectrion', 'clarionet', 'crotaline', 'locarnite'},
#  'acelnorty': {'alectryon', 'tolerancy'},
#  'acelpu': {'alecup', 'clupea'},
#  'aefl': {'alef', 'feal', 'flea', 'leaf'},
#  'aeflt': {'aleft', 'alfet', 'fetal', 'fleta'},
#  'aelm': {'alem', 'alme', 'lame', 'leam', 'male', 'meal', 'mela'},
#  'aaeilmnn': {'alemanni', 'melanian'},
#  'aeeilmt': {'alemite', 'elamite'},
#  'aeln': {'alen', 'lane', 'lean', 'lena', 'nael', 'neal'},
#  'aehlp': {'aleph', 'pheal'},
#  'aelopt': {'alepot', 'pelota'},
#  'aceelr': {'alerce', 'cereal', 'relace'},
#  'aeelrs': {'alerse', 'leaser', 'reales', 'resale', 'reseal', 'sealer'},
#  'aelrt': {'alert', 'alter', 'artel', 'later', 'ratel', 'taler', 'telar'},
#  'aellrty': {'alertly', 'elytral'},
#  'aaeeklst': {'alestake', 'eastlake'},
#  'aaelpt': {'aletap', 'palate', 'platea'},
#  'aeilrst': {'aletris', 'alister', 'listera', 'realist', 'saltier'},
#  'aceilnoru': {'aleuronic', 'urceolina'},
#  'aeltu': {'aleut', 'atule'},
#  'aceiltu': {'aleutic', 'auletic', 'caulite', 'lutecia'},
#  'aeilnv': {'alevin', 'alvine', 'valine', 'veinal', 'venial', 'vineal'},
#  'aelx': {'alex', 'axel', 'axle'},
#  'aaadeilnnrx': {'alexandrian', 'alexandrina'},
#  'aeilnx': {'alexin', 'xenial'},
#  'aadelry': {'aleyard', 'already'},
#  'adeefiln': {'alfenide', 'enfilade'},
#  'adeflr': {'alfred', 'fardel'},
#  'aflru': {'alfur', 'fural'},
#  'aaegl': {'algae', 'galea'},
#  'aagll': {'algal', 'galla'},
#  'aabeglr': {'algebar', 'algebra'},
#  'adegil': {'algedi', 'galeid'},
#  'adeglo': {'algedo', 'geodal'},
#  'acdegilno': {'algedonic', 'genocidal'},
#  'abegiln': {'algenib', 'bealing', 'belgian', 'bengali'},
#  'aaegilnr': {'algerian', 'geranial', 'regalian'},
#  'aeglnnor': {'algernon', 'nonglare'},
#  'aaegils': {'algesia', 'sailage'},
#  'aegilss': {'algesis', 'glassie'},
#  'aabegil': {'algieba', 'bailage'},
#  'agiln': {'algin', 'align', 'langi', 'liang', 'linga'},
#  'aegiln': {'algine', 'genial', 'linage'},
#  'agilst': {'algist', 'gaslit'},
#  'aeeglmort': {'algometer', 'glomerate'},
#  'acegilmort': {'algometric', 'melotragic'},
#  'aagilmno': {'algomian', 'magnolia'},
#  'aglor': {'algor', 'argol', 'goral', 'largo'},
#  'aghilmort': {'algorithm', 'logarithm'},
#  'acghiilmort': {'algorithmic', 'logarithmic'},
#  'aacghilpr': {'algraphic', 'graphical'},
#  'aglmu': {'algum', 'almug', 'glaum', 'gluma', 'mulga'},
#  'abiiillty': {'alibility', 'liability'},
#  'abeill': {'alible', 'belial', 'labile', 'liable'},
#  'aceil': {'alice', 'celia', 'ileac'},
#  'acehill': {'alichel', 'challie', 'helical'},
#  'aeiln': {'alien', 'aline', 'anile', 'elain', 'elian', 'laine', 'linea'},
#  'aaeiilnnot': {'alienation', 'alineation'},
#  'aaeilnort': {'alienator', 'rationale'},
#  'aeiilmns': {'alienism', 'milesian'},
#  'afil': {'alif', 'fail'},
#  'aegilorsu': {'aligerous', 'glaireous'},
#  'aegilnr': {'aligner', 'engrail', 'realign', 'reginal'},
#  'aegilmnnt': {'alignment', 'lamenting'},
#  'aeikl': {'alike', 'lakie'},
#  'aeeiklnss': {'alikeness', 'leakiness'},
#  'aailm': {'alima', 'lamia'},
#  'aeeilmnrt': {'alimenter', 'marteline'},
#  'aceiilmnt': {'alimentic', 'antilemic', 'melanitic', 'metanilic'},
#  'adeiilmno': {'alimonied', 'maleinoid'},
#  'ailn': {'alin', 'anil', 'lain', 'lina', 'nail'},
#  'adeilp': {'aliped', 'elapid'},
#  'aeilpst': {'aliptes', 'pastile', 'talipes'},
#  'aciilpt': {'aliptic', 'aplitic'},
#  'aaeillpst': {'aliseptal', 'pallasite'},
#  'ahils': {'alish', 'hilsa'},
#  'aeiilrs': {'alisier', 'israeli'},
#  'ailos': {'aliso', 'alois'},
#  'ailnos': {'alison', 'anolis'},
#  'ailps': {'alisp', 'lapsi'},
#  'ailst': {'alist', 'litas', 'slait', 'talis'},
#  'ailt': {'alit', 'tail', 'tali'},
#  'aeilt': {'alite', 'laeti'},
#  'adeilnu': {'aliunde', 'unideal'},
#  'aeeilnssv': {'aliveness', 'vealiness'},
#  'ailx': {'alix', 'axil'},
#  'akl': {'alk', 'lak'},
#  'aaeikllrz': {'alkalizer', 'lazarlike'},
#  'aaiklmn': {'alkamin', 'malakin'},
#  'aeekln': {'alkene', 'lekane'},
#  'aekls': {'alkes', 'sakel', 'slake'},
#  'aeikln': {'alkine', 'ilkane', 'inlake', 'inleak'},
#  'akly': {'alky', 'laky'},
#  'aciklly': {'alkylic', 'lilacky'},
#  'aaegillt': {'allagite', 'alligate', 'talliage'},
#  'aahll': {'allah', 'halal'},
#  'aally': {'allay', 'yalla'},
#  'aaellry': {'allayer', 'yallaer'},
#  'abellno': {'allbone', 'bellona'},
#  'aell': {'alle', 'ella', 'leal'},
#  'aceellrt': {'allecret', 'cellaret'},
#  'aaeegllt': {'allegate', 'ellagate'},
#  'aegillorst': {'allegorist', 'legislator'},
#  'aeegllnr': {'allergen', 'generall'},
#  'aaegillr': {'allergia', 'galleria'},
#  'aegillnr': {'allergin', 'gralline'},
#  'aegllry': {'allergy', 'gallery', 'largely', 'regally'},
#  'aabeilll': {'alliable', 'labiella'},
#  'aabillly': {'alliably', 'labially'},
#  'aaceilln': {'alliance', 'canaille'},
#  'aaceillnr': {'alliancer', 'ralliance'},
#  'aeill': {'allie', 'leila', 'lelia'},
#  'aeills': {'allies', 'aselli'},
#  'aillmu': {'allium', 'alulim', 'muilla'},
#  'aacillnoot': {'allocation', 'locational'},
#  'acellotu': {'allocute', 'loculate'},
#  'acillnootu': {'allocution', 'loculation'},
#  'acegillno': {'allogenic', 'collegian'},
#  'allmnoy': {'allonym', 'malonyl'},
#  'aahllopty': {'allopathy', 'lalopathy'},
#  'aacilloprt': {'allopatric', 'patrilocal'},
#  'allot': {'allot', 'atoll'},
#  'aceghillnoot': {'allothogenic', 'ethnological'},
#  'aellorv': {'allover', 'overall'},
#  'aellorw': {'allower', 'reallow'},
#  'alloy': {'alloy', 'loyal'},
#  'adellu': {'allude', 'aludel'},
#  'aellru': {'allure', 'laurel'},
#  'aalm': {'alma', 'amla', 'lama', 'mala'},
#  'aachlm': {'almach', 'chamal'},
#  'aaacgilm': {'almaciga', 'macaglia'},
#  'aailmn': {'almain', 'animal', 'lamina', 'manila'},
#  'aalmn': {'alman', 'lamna', 'manal'},
#  'aadeilmnt': {'almandite', 'laminated'},
#  'aaeilmnr': {'almerian', 'manerial'},
#  'agilmno': {'almoign', 'loaming'},
#  'almno': {'almon', 'monal'},
#  'adlmno': {'almond', 'dolman'},
#  'aelmnor': {'almoner', 'moneral', 'nemoral'},
#  'almnory': {'almonry', 'romanly'},
#  'alms': {'alms', 'salm', 'slam'},
#  'acelmu': {'almuce', 'caelum', 'macule'},
#  'adelmu': {'almude', 'maudle'},
#  'aelmntu': {'almuten', 'emulant'},
#  'aln': {'aln', 'lan'},
#  'aaegln': {'alnage', 'angela', 'galena', 'lagena'},
#  'acilno': {'alnico', 'cliona', 'oilcan'},
#  'aaillmn': {'alnilam', 'manilla'},
#  'aeilnot': {'alnoite', 'elation', 'toenail'},
#  'ailnnu': {'alnuin', 'unnail'},
#  'alo': {'alo', 'lao', 'loa'},
#  'adlo': {'alod', 'dola', 'load', 'odal'},
#  'aelo': {'aloe', 'olea'},
#  'aceilot': {'aloetic', 'coalite'},
#  'aflot': {'aloft', 'float', 'flota'},
#  'aagilno': {'alogian', 'logania'},
#  'aacgillo': {'alogical', 'colalgia'},
#  'adilo': {'aloid', 'dolia', 'idola'},
#  'ailno': {'aloin', 'anoil', 'anoli'},
#  'aelno': {'alone', 'anole', 'olena'},
#  'aglno': {'along', 'gonal', 'lango', 'longa', 'nogal'},
#  'alnoos': {'alonso', 'alsoon', 'saloon'},
#  'alnooz': {'alonzo', 'zoonal'},
#  'alop': {'alop', 'opal'},
#  'aceilopst': {'alopecist', 'altiscope', 'epicostal', 'scapolite'},
#  'aalos': {'alosa', 'loasa', 'oasal'},
#  'aelos': {'alose', 'osela', 'solea'},
#  'alow': {'alow', 'awol', 'lowa'},
#  'aeilotx': {'aloxite', 'oxalite'},
#  'alp': {'alp', 'lap', 'pal'},
#  'aeelnp': {'alpeen', 'lenape', 'pelean'},
#  'aelnp': {'alpen', 'nepal', 'panel', 'penal', 'plane'},
#  'aaellprst': {'alpestral', 'palestral'},
#  'aaeilnprst': {'alpestrian', 'palestrian', 'psalterian'},
#  'aeeilnprst': {'alpestrine', 'episternal', 'interlapse', 'presential'},
#  'acehilnp': {'alphenic', 'cephalin'},
#  'aehlnops': {'alphonse', 'phenosal'},
#  'ahlops': {'alphos', 'pholas'},
#  'ahilopss': {'alphosis', 'haplosis'},
#  'adilp': {'alpid', 'plaid'},
#  'aeilpu': {'alpieu', 'paulie'},
#  'aeilnp': {'alpine', 'nepali', 'penial', 'pineal'},
#  'aiilnpst': {'alpinist', 'antislip'},
#  'ailpst': {'alpist', 'pastil', 'spital'},
#  'aalnru': {'alraun', 'alruna', 'ranula'},
#  'aghilrty': {'alrighty', 'arightly'},
#  'aeilns': {'alsine', 'neslia', 'saline', 'selina', 'silane'},
#  'alos': {'also', 'sola'},
#  'adeiilnnost': {'alstonidine', 'nonidealist'},
#  'aeilnnost': {'alstonine', 'tensional'},
#  'alt': {'alt', 'lat', 'tal'},
#  'aaailnt': {'altaian', 'latania', 'natalia'},
#  'aacilt': {'altaic', 'altica'},
#  'aailrt': {'altair', 'atrail', 'atrial', 'lariat', 'latria', 'talari'},
#  'aaailmrt': {'altamira', 'matralia'},
#  'aalrt': {'altar', 'artal', 'ratal', 'talar'},
#  'aadelrt': {'altared', 'laterad'},
#  'aailrstt': {'altarist', 'striatal'},
#  'aabeiillrtty': {'alterability', 'bilaterality', 'relatability'},
#  'aabeellrt': {'alterable', 'relatable'},
#  'aaelnrtt': {'alterant', 'tarletan'},
#  'aeelrrt': {'alterer', 'realter', 'relater'},
#  'aelnrt': {'altern', 'antler', 'learnt', 'rental', 'ternal'},
#  'aeelnrt': {'alterne', 'enteral', 'eternal', 'teleran', 'teneral'},
#  'aaehlt': {'althea', 'elatha'},
#  'ahlot': {'altho', 'lhota', 'loath'},
#  'ahlnort': {'althorn', 'anthrol', 'thronal'},
#  'ailnt': {'altin', 'latin'},
#  'adeilttu': {'altitude', 'latitude'},
#  'aadiillnttu': {'altitudinal', 'latitudinal'},
#  'aaadiiilnnrttu': {'altitudinarian', 'latitudinarian'},
#  'alot': {'alto', 'lota'},
#  'aceilrst': {'altrices', 'selictar'},
#  'ailmrstu': {'altruism', 'muralist', 'traulism', 'ultraism'},
#  'ailrsttu': {'altruist', 'ultraist'},
#  'aciilrsttu': {'altruistic', 'truistical', 'ultraistic'},
#  'aelltu': {'alulet', 'luteal'},
#  'almu': {'alum', 'maul'},
#  'aaeilmntu': {'aluminate', 'alumniate'},
#  'adeiilmnu': {'aluminide', 'unimedial'},
#  'aaceiiillmnostu': {'aluminosilicate', 'silicoaluminate'},
#  'aalmnu': {'alumna', 'manual'},
#  'ailmnu': {'alumni', 'unmail'},
#  'alru': {'alur', 'laur', 'lura', 'raul', 'ural'},
#  'aelru': {'alure', 'ureal'},
#  'aegilrtu': {'alurgite', 'ligature'},
#  'aaltu': {'aluta', 'taula'},
#  'aalnv': {'alvan', 'naval'},
#  'aalrv': {'alvar', 'arval', 'larva'},
#  'aelsuv': {'alveus', 'avulse'},
#  'ailnv': {'alvin', 'anvil', 'nival', 'vinal'},
#  'aly': {'aly', 'lay'},
#  'ailnpy': {'alypin', 'pialyn'},
#  'aelsty': {'alytes', 'astely', 'lysate', 'stealy'},
#  'am': {'am', 'ma'},
#  'aaceimnr': {'amacrine', 'american', 'camerina', 'cinerama'},
#  'aadim': {'amadi', 'damia', 'madia', 'maida'},
#  'aaehmnot': {'amaethon', 'thomaean'},
#  'aahm': {'amah', 'maha'},
#  'aaimn': {'amain', 'amani', 'amnia', 'anima', 'mania'},
#  'aaaglmm': {'amalgam', 'malagma'},
#  'aagmn': {'amang', 'ganam', 'manga'},
#  'aaimnst': {'amanist', 'stamina'},
#  'aaiimnnt': {'amanitin', 'maintain'},
#  ...}

# %%
# smart anagram search: look up myword's signature, return set

def find_anagram_fast(myword):
    sig = signature(myword)

    return anagrams_by_sig[sig]

# %%
find_anagram_fast('tops')
# Out:
# {'post', 'spot', 'stop', 'tops'}

# %%
find_anagram_fast('michele')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-f63deca0a2c9> in <cell line: 1>()
# ----> 1 find_anagram_fast('michele')
#
# <ipython-input-35-45738f04c9aa> in find_anagram_fast(myword)
#       4     sig = signature(myword)
#       5
# ----> 6     return anagrams_by_sig[sig]
#
# KeyError: 'ceehilm'

# %%
# handle case when myword's signature is not found, returning the empty set

def find_anagram_fast(myword):
    sig = signature(myword)

    try:
        return anagrams_by_sig[sig]
    except KeyError:
        return set()

# %%
find_anagram_fast('Michele')
# Out:
# set()

# %%
# %time find_anagram_fast('Michele')
# Out:
# CPU times: user 14 µs, sys: 0 ns, total: 14 µs
# Wall time: 18.1 µs
# set()

# %%
# list of signatures, sorted by length, longest first
sorted(anagrams_by_sig.keys(), key=len, reverse=True)
# Out:
# ['ccddeehlmnooooossttuyy',
#  'acddeehiimmnoopprrruuy',
#  'aaaaccghiillmnooooptt',
#  'acghhhhilmooooopprrtt',
#  'aaccddeeemnnoooprttuy',
#  'aaabegghilllnoooprssy',
#  'aaccghiiilmnoooopsty',
#  'acceeeeeghillmnnnoop',
#  'aaabeggillllnooorssy',
#  'aaaccghiilmnooooptt',
#  'aacccghiiilllnooopt',
#  'aceeeghiiilmnnnopst',
#  'aaegghmooooprssstty',
#  'bceiiiilnnoorrtttvy',
#  'aacccdeehiiinopprrr',
#  'accghhiilloooppssyy',
#  'aaccdhmmnoooorrsxy',
#  'cdehiiiiinooorrstt',
#  'accghhhinoooopprrt',
#  'ceeeeehlmmoorrrttt',
#  'addeiimmooopsstvyy',
#  'aaeeeghlmmnoorrttv',
#  'aadeeehhiknorrsttx',
#  'aagghiilnnoprrstyy',
#  'aaceghlmnooorrttyy',
#  'acceghillnoooprsuy',
#  'aacdeeehiillmntty',
#  'aaaabchiimnoprrst',
#  'aaccceeiilloorssu',
#  'aceeghiiilmnnopst',
#  'bceeegiiimnnorrst',
#  'aacccceehhiilmmno',
#  'acghhhilmoooprrty',
#  'acghhhmoooopprrty',
#  'acghhhnoooopprrty',
#  'aciiilmnnoosstttu',
#  'acdegiilmoooopsuy',
#  'aacceeegillmnortt',
#  'aceeehiillmnopsty',
#  'aacdeehhiknoorstx',
#  'adehhmnoooprrtuxy',
#  'aaehlmoooprrsttyy',
#  'ceehmmmooorsttyyy',
#  'aaaegghllnnoprryy',
#  'accghhiimooopprrt',
#  'ccceeimooopprrsst',
#  'aeeeiimnnoprrsstt',
#  'aacdeeiillopprrru',
#  'aabdeeiilmnnotxz',
#  'acdhhiinoorrrstt',
#  'aaacdghiiooprrtu',
#  'abccghiillooopsy',
#  'aaccceelnooorrsu',
#  'acghhhnoooopprrt',
#  'acfgiiimnnoorstu',
#  'aaccdeeillmnorty',
#  'accdefhiinorrryy',
#  'accdefhinoorrryy',
#  'aabcfimmooorrsxy',
#  'aceeghhloopprsty',
#  'aeghhhilooopprty',
#  'aeehhmmnoooprtux',
#  'bceeiilnnoorrttv',
#  'aceeiiilnnossttv',
#  'aaellmnooopprsty',
#  'aghhhilooopprtty',
#  'ceeeegillmmnnooy',
#  'acghhimooopprrty',
#  'cehilmnoopprrsuu',
#  'acceiilmooopprtt',
#  'aaaeilmoopqrsstu',
#  'aaceeiinnnoppttt',
#  'aaceghillopprrty',
#  'aghhiiinnoprrsty',
#  'aeeghhooopprrstt',
#  'aceeghhiloopprtt',
#  'cghhiloooppssyyy',
#  'cceghhlnooopstyy',
#  'aeeeglmooprrrtuy',
#  'aacccillorrstuuu',
#  'aacchilmnnoopsst',
#  'cceeeeloopprsstt',
#  'cehiiooprrsssttt',
#  'aaabdgiilmnnoov',
#  'aabcdeiilmnoosv',
#  'aaceiiillmnostu',
#  'aaadghiooprrtuy',
#  'aabeghhmooprrrt',
#  'abccgiiilloooos',
#  'acccehhiilmopsy',
#  'aaceeghimnoprrt',
#  'aabceilmnootttu',
#  'aceiinnoorssttv',
#  'cciimnnoorssttu',
#  'cehiiorrsstttuy',
#  'aacddeeiloprtty',
#  'adeeimnoorrsstu',
#  'adeiilnorrssttx',
#  'accceeiiilmssst',
#  'acceeegilmnortt',
#  'aeegiinorrssttt',
#  'adeehhilmnoopst',
#  'accfiilnoooprtt',
#  'aacefgiiimnnort',
#  'aacghillmnoopry',
#  'aadeeehhnorrttx',
#  'bceeiiilmpprrst',
#  'beeeiilmnprssss',
#  'eefiinoooprrrst',
#  'ehhilmnoooprtty',
#  'aacghhmooopprrt',
#  'eegiiilmmnnosty',
#  'acghhimooopprrt',
#  'ccehimoooopprst',
#  'acdeeiimmoorrrt',
#  'addeeimnnrrsstu',
#  'aaeeilmoopprrtt',
#  'aaceeiiloprrstv',
#  'aeeghhloopprtty',
#  'aghhoooppprttyy',
#  'aehmnooopprtuxy',
#  'eeiooopprrrsstu',
#  'aeiimnnoprrssst',
#  'acegiilnosstttu',
#  'ceeeeelooprsstt',
#  'abeeelnorrrsttv',
#  'aabceeelnnrsstu',
#  'aacddehmnnooor',
#  'aaadiiilnnrttu',
#  'aacdghimnnooor',
#  'aaacchiilnrstt',
#  'aeefiinnoorrrt',
#  'aeeinooprrrstu',
#  'aaciiimnoossst',
#  'aaadghiooprrtu',
#  'abcelmoossttuy',
#  'bcdfhilooorruy',
#  'aaacccimnoorrs',
#  'accceeiilorsvv',
#  'acchiillnooprt',
#  'abcdfhimnooorr',
#  'aaceilnnoorstv',
#  'ceiinnoorstttu',
#  'abceeloorrsttv',
#  'cehinooprsssty',
#  'aadeeenorrsttt',
#  'aadeeinnostttu',
#  'acdegiillooprt',
#  'adellnoorrstvy',
#  'addeejjlnnoouu',
#  'accdeeilmnorty',
#  'cceeehilmorrtt',
#  'ehhillnoprrtyy',
#  'aeiiinoprstttx',
#  'aaefilnooprrtt',
#  'aeflmnoooprrtt',
#  'aaccghilnopsvy',
#  'eeegiimnoprsss',
#  'adeehhhillmoor',
#  'aceeghillooprt',
#  'dehhinooprrssy',
#  'beiiiilmprssty',
#  'eeeiimnprssssv',
#  'aceegilmnnoort',
#  'aeeiillnnoprtt',
#  'aceeiilnnorstt',
#  'aeiiinnoprrstt',
#  'cdeiiloorrssuu',
#  'accdehiilmopsy',
#  'beehiilmoprstt',
#  'eeeeimnprrrsst',
#  'aaciillnrsttuy',
#  'eehiilnopprsty',
#  'cehinooprsssuy',
#  'acdeeinnnoorst',
#  'aaaacdiillprsy',
#  'aaeegiilnnoprv',
#  'aabeilnoprrttu',
#  'aaceghilopprrt',
#  'acegilllooprty',
#  'aaelmoopqrsstu',
#  'aeeghhloopprtt',
#  'aceeilloprrsuv',
#  'aaeeiilnoprrtz',
#  'eeeeinnprssstv',
#  'aegimmnooprstu',
#  'ahinnopprrtuux',
#  'adeeehilnooprt',
#  'aaeiiilnorttvz',
#  'adefiilnoorttu',
#  'aabceelorrrstv',
#  'aeeilnoorrsstu',
#  'aaceiiilnosttt',
#  'ccgiiilnossttu',
#  'abdeeghinnrrtu',
#  'aaaiimnnnorstt',
#  'aabeeelmnnnssu',
#  'aaacehilmnoor',
#  'aaaceghiloprr',
#  'aacefiiilmnot',
#  'aacfiiilmnopt',
#  'acghiiilnoost',
#  'aaaegikmnoort',
#  'aciiilmnnortu',
#  'acfiiinooprst',
#  'aeefginorrstu',
#  'aehiiorrssttt',
#  'aeeeinnsstttv',
#  'aeehioorssttu',
#  'abdeeelnrssss',
#  'beeeflnnooruz',
#  'bcghilooopsyy',
#  'abcceilmostty',
#  'abhiilnoopstt',
#  'aaabccfhiilor',
#  'abcccceiloruv',
#  'acceehilmoprt',
#  'acdehloooppsu',
#  'accefiiinortt',
#  'acceefiiirttv',
#  'accefiiorrtty',
#  'accdeiloorrsv',
#  'aacccefiilorv',
#  'aabcceiillorv',
#  'aabceeehlnsst',
#  'aceeehilmorst',
#  'accdhlnooorst',
#  'acdhilmnooopr',
#  'acdhmmnooorxy',
#  'ceeiilnoorstt',
#  'cciiloooprstt',
#  'ceeiimnooprtt',
#  'ciimmnoooprss',
#  'acdlmnooostuy',
#  'acdeeiinorstv',
#  'acdeenorrsttu',
#  'ceeeilmnrssss',
#  'acgiilnnorruu',
#  'acemooprsttty',
#  'ceiilopssttyy',
#  'acdeloprsttuy',
#  'aacdeehiilnop',
#  'adeiimnnooprt',
#  'cdeeeilmorrst',
#  'adegiimooprst',
#  'acdehilloppsu',
#  'degiilooprstt',
#  'acdiiimnorrst',
#  'deghiiinrsstu',
#  'adeeiinorrstt',
#  'deehhimnoopst',
#  'eeiimnoprsssx',
#  'abfilnooorrtt',
#  'aeggilnnnooru',
#  'aaceghioprstt',
#  'aceghinoprrst',
#  'aegiinnorrtuy',
#  'aacghilmnoopr',
#  'aaadeglnnprrt',
#  'aacgghilloopr',
#  'aaghinoprrstu',
#  'aaceehilmpsty',
#  'aaaeeghilmopt',
#  'aceehhinopprt',
#  'adehhloprstuy',
#  'acceiilmnoort',
#  'aeiimnnooprst',
#  'eiiimmnoprsss',
#  'aacdeilllmnou',
#  'aiiinnnoosttv',
#  'aciilnnorsttu',
#  'aaceiilnnortt',
#  'aceiiimnnorrt',
#  'cceefiiinprst',
#  'aaceilnrrstuv',
#  'aegiiinnosttv',
#  'aaachllmnorsy',
#  'aaeellnorrttv',
#  'aeghlmnooopsu',
#  'aaeegillmnops',
#  'achimnooprrst',
#  'aceilmooprstu',
#  'ceeiimnopprst',
#  'eggiimnossstu',
#  'eeiilmnorstuy',
#  'aaccdehinoprr',
#  'achiimnnoortt',
#  'aceeilmoorstt',
#  'acceeilorrtuv',
#  'aceeinorsssuv',
#  'aaehiinpprrst',
#  'aaehnnoprstty',
#  'acdeeiimnoprt',
#  'aabeilmnoprtu',
#  'aabelmoprrtuy',
#  'acdeiiiloprst',
#  'aceiilnoprsst',
#  'ceehilnnopprs',
#  'aehmnnoopptuy',
#  'admoooopssttu',
#  'cdeeiinoprrst',
#  'aaeiloopprrrt',
#  'dehiloopprstu',
#  'acchimoopssty',
#  'aceeiimoppsty',
#  'cceeiimoppsty',
#  'adeeginorrrtt',
#  'eiinoopprsstu',
#  'aaccfiiinorst',
#  'abccillorstuy',
#  'deeeinnprrstu',
#  'aabeiilmnntuy',
#  'abceefiilnrtu',
#  'abceelnnorsuv',
#  'beeiilmnprssu',
#  'ceeeiklnprstu',
#  'bceeilnpsstuu',
#  'aacegiilnosvv',
#  'accehilmoprs',
#  'aaccehilnort',
#  'aacchiimnort',
#  'acdhiiloopsu',
#  'aaccillorsty',
#  'aaceinnoprtt',
#  'aaccelmntuuu',
#  'aacdemnoosty',
#  'aabdefimnoor',
#  'aaacdemnoors',
#  'adiimnooprss',
#  'acdeinooprrt',
#  'aaaceilnnrst',
#  'aceghillnoot',
#  'aabeiillrtty',
#  'ahimoopprstu',
#  'aaceghimnopr',
#  'aabfgiimnoor',
#  'aaeilmnnrtuy',
#  'aaceeiinrttv',
#  'acfiiinnortt',
#  'aiimnooqsttu',
#  'acehiinnoptt',
#  'aaeeinoprstt',
#  'aaiilnorstty',
#  'aaciilnoprtt',
#  'aachiilmoprs',
#  'aeeginooqsuu',
#  'aeeinoprrsty',
#  'aabceillprry',
#  'aabceehloprr',
#  'aabcdhinoopr',
#  'abdehmoorrty',
#  'aacccdeimnoo',
#  'acceiillnost',
#  'acdeiilmortt',
#  'accelmopstuy',
#  'abcddehiorry',
#  'aaceiimnrsst',
#  'aacdeflmooru',
#  'aaacdellortu',
#  'acdelnoorrst',
#  'aceeillnnort',
#  'aacceehlortt',
#  'accefiiorrtt',
#  'accdeiinorvy',
#  'aaceehlmprst',
#  'aceehlnoprss',
#  'cdehiiooprst',
#  'accehiilmotv',
#  'acchiimnorst',
#  'chhiiooprsst',
#  'aacehilmnoor',
#  'cddehiilooor',
#  'accehmoortty',
#  'acghhoprrsyy',
#  'ccciilnnooot',
#  'aciiilnoostt',
#  'cceeillnoort',
#  'ceelnoprrtuy',
#  'aacghilooprr',
#  'aaceilmmnort',
#  'ceiimmnoorss',
#  'aceeemnoprtt',
#  'cdeeehmnoprr',
#  'cceeinnoorss',
#  'acceinnnooss',
#  'aceinnoorstv',
#  'aceeinorstvv',
#  'abcinnoorttu',
#  'ceeinnnoortv',
#  'acghioopprst',
#  'acceinooprtu',
#  'aceilooprrst',
#  'cceeinoorrrt',
#  'acelnoorsstt',
#  'acceenorrttu',
#  'accehmnorrtu',
#  'acdegnorrtuu',
#  'acdeelnoprtu',
#  'acdeehnorstu',
#  'acdennorsttu',
#  'cehiioprrstu',
#  'aceeeinrsstv',
#  'cdehiioprrst',
#  'ceeeimorrstt',
#  'ccdhiioorrty',
#  'acegilnorrtu',
#  'abcfimoorsty',
#  'acdeeiilmrst',
#  'acdeeeilnsst',
#  'adeiiilmnott',
#  'aadeeilllmpr',
#  'adegiillnntu',
#  'adegillnnotu',
#  'adeiilnoopst',
#  'acdeeiinoprt',
#  'aadeiilnortv',
#  'adeehmnooprt',
#  'acdeeioprstu',
#  'addeeinrstuv',
#  'adeeiimrsstt',
#  'cdeiinnorstu',
#  'cdeeeinrssst',
#  'aadelloorrst',
#  'addenoorrstv',
#  'adelnoorrstv',
#  'aacehillmpty',
#  'ceeegiinrstt',
#  'aeeghhoprrty',
#  'aeehiinorttz',
#  'aaeeinoprstx',
#  'aeeeflmnssss',
#  'abefiilmoort',
#  'abefimnoorru',
#  'eeffgilnorrw',
#  'adefinnoortu',
#  'aaaegllnnott',
#  'aacghioprstt',
#  'degghloooryy',
#  'aabgilllooss',
#  'defgiinoorsu',
#  'aghimnooprst',
#  'acghhinooppr',
#  'ahhooopprstu',
#  'aceehiinortt',
#  'aceehoprrstu',
#  'eeghnoorstuy',
#  'acehilmoopty',
#  'aadehilmorru',
#  'achiilmorstu',
#  'eehlnrsssstu',
#  'achimoopstty',
#  'aehhoprsttyy',
#  'aaciiilprstt',
#  'abeeeilmnprt',
#  'abeeilmnprty',
#  'aceimnnoprtu',
#  'eeiilmprssvy',
#  'aaciiinnottv',
#  'abceilmnoptu',
#  'ceiinnnosstt',
#  'ddeefiiinntu',
#  'abdeeiilnprv',
#  'cdeeiilnrsty',
#  'aabbeiilnnot',
#  'aaceilnoprtu',
#  'ceeiinnorsst',
#  'ceiiiimnrstt',
#  'ceeinooprrtt',
#  'aeeeillnprtt',
#  'cdeeinoprrtu',
#  'aeeiinrstttu',
#  'aeiinnorsttt',
#  'eeiinnnorttv',
#  'aegiilnnortt',
#  'aabeiilnorrt',
#  'aceeeinnprrt',
#  'accehiilorst',
#  'aaccchiiorss',
#  'aceilnooprtt',
#  'aadeiiloprsu',
#  'aacehilnopst',
#  'aehhiilnoprt',
#  'acegillmoort',
#  'aacehilmpsty',
#  'aacgillmoost',
#  'aaeghlmnrstu',
#  'aeeelmnsssst',
#  'adeeilmnortv',
#  'aacehilmoprt',
#  'aceilmmnoort',
#  'accehilmopry',
#  'ceimooprrstu',
#  'adiiimnorstt',
#  'acdeimnoosty',
#  'hllmnooopsuy',
#  'chimmnoopssy',
#  'chimooopprrt',
#  'eeilmnorstuv',
#  'aeghhmoprrty',
#  'aacceinnorst',
#  'aaciilnrsttu',
#  'aehmnnooptty',
#  'ceeehlnoopps',
#  'aceghillnoop',
#  'eghilnooprst',
#  'acehhinopprt',
#  'adeehinopprs',
#  'aehinoopprst',
#  'ehinoopprssy',
#  'cdeefiinnort',
#  'acinnnorsttu',
#  'aceiilmnnopr',
#  'aceiilnnoprt',
#  'eeelnnosssst',
#  'abcinorssttu',
#  'acchiooprstt',
#  'aeghiilnoopr',
#  'ceghiilnoopr',
#  'aehinooprrtt',
#  'aacfiiilnopt',
#  'aabdeillmopt',
#  'acilnooprstu',
#  'aceghloppryy',
#  'adeeenprrtuv',
#  'ceeeilpprtvy',
#  'aceellpprtuy',
#  'aceinnooprtt',
#  'ceeinoprrssu',
#  'aefiilnooprt',
#  'aeefimoprrtv',
#  'aeeilpprsttu',
#  'eeinoprsssuv',
#  'aeeghopprrrt',
#  'aceghiopprrt',
#  'aeghhoopprrt',
#  'acehlnooprst',
#  'dhlloooppsuy',
#  'eeghinopssty',
#  'ceeghinoptty',
#  'aaellnprstty',
#  'accilooprsuy',
#  'adhiioprrstt',
#  'aaceiloprstt',
#  'cdehilloopry',
#  'eeinooprssss',
#  'aaghoopprssu',
#  'aceiiopprrtt',
#  'abceilnnopru',
#  'celnooprrstu',
#  'acdeiiloprst',
#  'eeeilnprstvy',
#  'einooopprrrt',
#  'cdeinooprrtu',
#  'chiooopprrtt',
#  'deelnoprstuy',
#  'cehhimopssty',
#  'aacceehinrst',
#  'aaceinorrttt',
#  'acceeilorstv',
#  'adeeiinorrtv',
#  'aeeillrrsttu',
#  'eeiimnoprrss',
#  'aeeimnnorrtu',
#  'ceeeiprrssuv',
#  'aeeghinrrstt',
#  'eeeghnnrrstt',
#  'aeiinnoprstu',
#  'aaelnnprrstt',
#  'eeeilnrsssst',
#  'abcfiiinortu',
#  'aaccfiiorrst',
#  'aaaadilmnnrs',
#  'eeimnoprsstu',
#  'eeinnoprsstu',
#  'aceimooprstz',
#  'chimooprrstu',
#  'eelnopssssst',
#  'aeeflnsssttu',
#  'aceehmnrrstt',
#  'aehilooprstt',
#  'abeeilnssstu',
#  'aabeelnrrstu',
#  'aacelnprrsuu',
#  'eeimnprrsstu',
#  'adhimnoprssw',
#  'abeehiinnrtt',
#  'aaelmnnorttu',
#  'abcdeeelnrtu',
#  'aacdeglnotuu',
#  'abceeelnptux',
#  'eeiimnprssuv',
#  'abeeelnnprtu',
#  'adeeinnrsttu',
#  'ceeinpsstuuv',
#  'aaacelprtty',
#  'aacceelorrt',
#  'acceeinorss',
#  'aaacdehinrt',
#  'acdeeiinprs',
#  'aciimnoorsu',
#  'acciilmnoru',
#  'acciimorsst',
#  'acchiooprrt',
#  'aaacdeeinot',
#  'aceiinoprtt',
#  'aadiimnopst',
#  'accdeeinopt',
#  'aadeilmnoop',
#  'aabdiilorty',
#  'acdeilnorty',
#  'acdefiimoor',
#  'aaeeghoprrr',
#  'aaceghioprr',
#  'aacegilloor',
#  'aaeimnorstu',
#  'aaceiorsstt',
#  'aacfilnnotu',
#  'accehiilmst',
#  'aaadeilnnrx',
#  'acghiilmort',
#  'adeiilnnost',
#  'aadiillnttu',
#  'aabeiilmnty',
#  'aaeehlmnorr',
#  'adehilmnoop',
#  'acilmmnooty',
#  'aeeeemmprrt',
#  'aeghimnopsu',
#  'achhiilmopp',
#  'adhimooppsu',
#  'aacceinnort',
#  'aaaceillnpt',
#  'aaachilnopr',
#  'aadhnooprrt',
#  'acehimnorst',
#  'achiimnorst',
#  'aaeghmnopry',
#  'aacegilllny',
#  'aaehimnosst',
#  'addehiinryz',
#  'aceiimnorst',
#  'aehiinorttt',
#  'aeghnnoostu',
#  'aabdiilmntu',
#  'acciilnnotu',
#  'aacdiilnott',
#  'aeeeimnrttx',
#  'aaeiillmnnt',
#  'aceiinnoptt',
#  'aaeilnnrttu',
#  'aahiinprsst',
#  'aceiinprtty',
#  'acdeeinrrtu',
#  'adeinooprtt',
#  'acdhiioprst',
#  'ahoopprsstu',
#  'aeinoopprrt',
#  'aaabeilpprs',
#  'adeeehnpprr',
#  'aaccdhiinor',
#  'aacehloprst',
#  'aaceehlprrt',
#  'aceeiilnort',
#  'aaceeinrrst',
#  'aaeilnorsst',
#  'aceghimnost',
#  'aeeilntttvy',
#  'aaiillnootv',
#  'abcefimorrt',
#  'abehiimorsv',
#  'beilnnoortz',
#  'abcegilnost',
#  'abceilmorst',
#  'beilorrsttw',
#  'aaabbcceemo',
#  'abeilnoosst',
#  'abcdehioopr',
#  'aabcdeorrst',
#  'aabddeoprrs',
#  'aaacdeilnnr',
#  'aacceilltuv',
#  'aaacdeillnr',
#  'aacghillpry',
#  'aacceilnort',
#  'acdeeinoprt',
#  'aaceillmnpt',
#  'aaciillprty',
#  'aacdeinnort',
#  'aacgiilnnor',
#  'acceeioprrt',
#  'aacgilnoopr',
#  'aaceilprttu',
#  'aacddloorsu',
#  'aaciillnotv',
#  'ceeelnrsssu',
#  'aceilmnnort',
#  'aaceinnortx',
#  'ccelnnstuuu',
#  'acceiloprst',
#  'abceefiilrt',
#  'ccehimooprt',
#  'abcehlnoosu',
#  'aaceghhnott',
#  'aacehilnrty',
#  'acdeehilnot',
#  'acehiimrstt',
#  'acehiilostt',
#  'acddehiiino',
#  'acchiimnort',
#  'achiloprsty',
#  'acehilmnoor',
#  'acdhlnooort',
#  'achiinoortz',
#  'cchimooprty',
#  'accdehiiort',
#  'aciiinnortt',
#  'ceegilnosty',
#  'acceeilrrtu',
#  'acdeiilnort',
#  'cceeehinnor',
#  'aceillnoort',
#  'aciillnoost',
#  'acdegimorty',
#  'aciimmnnoot',
#  'aciimnooprt',
#  'cdeiinnoort',
#  'ceegnnoorsu',
#  'acceilnnotv',
#  'abceelnorsv',
#  'accennorsvy',
#  'acdeeinorst',
#  'ccenorrsttu',
#  'acccehnorty',
#  'ceghioprrty',
#  'aciimnorrty',
#  'acdeinoorrt',
#  'acceiimnost',
#  'aciilnopsst',
#  'aceinoprrst',
#  'acdeeinortu',
#  'acelnoprtuy',
#  'aceelnorstu',
#  'aceilnorttu',
#  'aceilnortuv',
#  'aceinorrtuv',
#  'acceimnorty',
#  'acgimnnoory',
#  'acefimorrrt',
#  'acceimorrtt',
#  'aaceinorrty',
#  'aceiinorstt',
#  'aaceilmorrt',
#  'aceeilnnort',
#  'aceeiilmnrs',
#  'ccdeiiloort',
#  'aceimoprrty',
#  'cehilnosssu',
#  'acchinnopyy',
#  'acmmoostxyy',
#  'acdlmnootyy',
#  'cdeeimoostx',
#  'aacdeilnort',
#  'adehinoortt',
#  'acdefiiinot',
#  'acdefiiorty',
#  'acdeiillsty',
#  'deiilnosstu',
#  'addegilmnny',
#  'aacdeimnort',
#  'acdeiimmnos',
#  'degilmnrruy',
#  'aabdeillnot',
#  'acdeinnortu',
#  'adeiinoprtt',
#  'acdeeiopttt',
#  'adeilnooprt',
#  'adegilnprvy',
#  'cdeiinoprst',
#  'accdeiinost',
#  'adeeinoprst',
#  'adeeimnnrtt',
#  'adehiimnopr',
#  'adehhiinprt',
#  'adehhioppst',
#  'degilooprty',
#  'aadeeipprrs',
#  'cdeeimnnrst',
#  'bdeeeimmrrs',
#  'aadiinoprst',
#  'abdeeilnpss',
#  'diiiimnossv',
#  'aacdilooprs',
#  'addeilmoors',
#  'aacdloorrss',
#  'aceehlmopsy',
#  'eilooprssty',
#  'aehinorrsst',
#  'adeegilnnry',
#  'deimnooprsu',
#  'aeegilmnnrt',
#  'ceeehlnprsu',
#  'aabeelnrttu',
#  'ehilmnoopty',
#  'aceilnopstt',
#  'aeeimnnortu',
#  'aceiinnnotu',
#  'ceioorrsuuv',
#  'aeeimnprsst',
#  'aceghilloot',
#  'aceelloptuy',
#  'aceeinoprtu',
#  'adeeehilrtv',
#  'aaeiimnnotx',
#  'aefiinnostt',
#  'abfiilmoopr',
#  'bcfimoorsuu',
#  'abfimmoorxy',
#  'befioorrssu',
#  'adefnorrssw',
#  'abefgiillor',
#  'aaflnnoorst',
#  'cefilorstuu',
#  'afilmnortuy',
#  'aacgillnnot',
#  'aabegggllry',
#  'aceeggimnot',
#  'acgimnoorst',
#  'aeegiilnrtz',
#  'acegilnopty',
#  'eeghimoorst',
#  'aceegilmort',
#  'cceeginoott',
#  'aeghmnooprr',
#  'ceegiilnryz',
#  'deghlmnootu',
#  'eeggnooqrsu',
#  'afgiimmnorr',
#  'acghimnoopr',
#  'aegginorrsu',
#  'acgghiloopr',
#  'aeeghmoprrt',
#  'acghiopprty',
#  'aeghopprrss',
#  'ahhilmopsty',
#  'aabeehklrrt',
#  'aacdehinppr',
#  'achhioopprt',
#  'achioopprtt',
#  'adeeehnrsst',
#  'accehiilott',
#  'beeehillnor',
#  'aehhimoprty',
#  'aeehiimprss',
#  'accehiloopt',
#  'aehmoopstty',
#  'adehiloppty',
#  'aceehillrty',
#  'aceehimortt',
#  'ceeehilortt',
#  'deehmoorrty',
#  'aeehhoprtty',
#  'adeehlooprt',
#  'cdehilnoort',
#  'eeghmnooosu',
#  'efhlnrsstuu',
#  'acdhhiorrsy',
#  'ghilmnoosty',
#  'dehhioortyy',
#  'aeghmoprsuy',
#  'ghiloopstty',
#  'acehlloprsy',
#  'aeehilrssty',
#  'adeiiilnort',
#  'acchiiiilos',
#  'aadillortuy',
#  'acdeiillort',
#  'aaeiilmmrst',
#  'aeeeimnprtt',
#  'aeeimnoprst',
#  'aeimnoprttu',
#  'beeiilmprss',
#  'beiilmprssy',
#  'aceimnoprrt',
#  'aceiinnnost',
#  'acinnnnoost',
#  'aceinooprrt',
#  'aceiinorstv',
#  'aeegiinrttv',
#  'aaeilnrrstt',
#  'eefgiinnrrt',
#  'aeeeilnrrtv',
#  'aeilmnrttuu',
#  'aeiilnnrtty',
#  'ceeeiinnrtv',
#  'aeeilnoprtt',
#  'eeinoprrstu',
#  'eeeinprrrtt',
#  'eeinprrrttu',
#  'aceiilnorst',
#  'aeilnoprrst',
#  'abeeilnrrtv',
#  'eeeiinrrtvw',
#  'acciimnorst',
#  'aacilnorstt',
#  'aaeilnprstt',
#  'aaiilnnprst',
#  'aeeiilnrstv',
#  'ahhillopsty',
#  'abceiijlstu',
#  'aabeillmnot',
#  'aceilmmnoty',
#  'aeglmnoorty',
#  'aeilorrsstt',
#  'aciilmnortu',
#  'adeehilnort',
#  'agilmnnoosu',
#  'aabcllmorsu',
#  'aadehilmnpy',
#  'aehilmnoppy',
#  'adeimmnorst',
#  'eegimnorstu',
#  'ceehimnorst',
#  'acegillmoos',
#  'aeelmnorstv',
#  'aaceilmpstt',
#  'acehimoprtt',
#  'ceeiimorstt',
#  'aaceeimrstt',
#  'aeimooprstt',
#  'accehilmopr',
#  'acceiimmnor',
#  'aeiilmnorst',
#  'eeimoprrrst',
#  'achiiimrstt',
#  'cdeiimnorst',
#  'aacdillmnoy',
#  'cilmnnooosu',
#  'acgillmnooo',
#  'chimmnooopr',
#  'ailmnnoopst',
#  'acilmnoopty',
#  'aemmnnortuy',
#  'acghimooprt',
#  'acghimopsty',
#  'ciilmoopsty',
#  'aghimoprsty',
#  'emmnooottyy',
#  'aaehhilnptz',
#  'aabilnoorst',
#  'aaaallnopst',
#  'aaceeinnrss',
#  'aceilnooprt',
#  'eghilnoopst',
#  'ccehilnoopr',
#  'aehhnopprty',
#  'aehmnooprst',
#  'einoprrstuy',
#  'aeelnnrsstu',
#  'aceinnnoort',
#  'aceeinnortv',
#  'aeilnnnoort',
#  'aaelnnnoprt',
#  'abceeijottv',
#  'abiiillotvy',
#  'abccinorstu',
#  'acffinoostu',
#  'ceeimnoorst',
#  'acgillnooot',
#  'aeiinoprtty',
#  'abeelnopsst',
#  'acgillooopt',
#  'aeiilnorstt',
#  'aghilnooort',
#  'aeinnoosttt',
#  'ceeimoorstt',
#  'deeinossstu',
#  'aabiloortuv',
#  'deeinooprtv',
#  'aacillnopty',
#  'aaceilprsst',
#  'aciiilnpstu',
#  'achiinnoprt',
#  'aaciiloprst',
#  'aaaeghpprrr',
#  'aacehinpprr',
#  'aaachinprsu',
#  'aaeilmnprst',
#  'aaeilnprtty',
#  'acdeeiinprt',
#  'aeiinoprrtt',
#  'aeenoprrstt',
#  'adeilnnoptu',
#  'adeeimnoprt',
#  'aabeelmprtu',
#  'cdemnooppru',
#  'aeefioprrtv',
#  'aceeiipprtt',
#  'aadeeiipprt',
#  'aaeeilnpprt',
#  'eeiopprrstu',
#  ...]

# %%
# list of anagram sets, sorted by signature length
[anagrams_by_sig[sig] for sig in sorted(anagrams_by_sig.keys(), key=len, reverse=True)]
# Out:
# [{'cholecystoduodenostomy', 'duodenocholecystostomy'},
#  {'hydropneumopericardium', 'pneumohydropericardium'},
#  {'anatomicopathological', 'pathologicoanatomical'},
#  {'chromophotolithograph', 'photochromolithograph'},
#  {'duodenopancreatectomy', 'pancreatoduodenectomy'},
#  {'glossolabiopharyngeal', 'labioglossopharyngeal'},
#  {'anatomicophysiologic', 'physiologicoanatomic'},
#  {'encephalomeningocele', 'meningoencephalocele'},
#  {'glossolabiolaryngeal', 'labioglossolaryngeal'},
#  {'anatomicopathologic', 'pathologicoanatomic'},
#  {'clinicopathological', 'pathologicoclinical'},
#  {'encephalomeningitis', 'meningoencephalitis'},
#  {'esophagogastrostomy', 'gastroesophagostomy'},
#  {'incontrovertibility', 'introconvertibility'},
#  {'pericardiacophrenic', 'phrenicopericardiac'},
#  {'physiopsychological', 'psychophysiological'},
#  {'chondromyxosarcoma', 'myxochondrosarcoma'},
#  {'chorioidoretinitis', 'retinochorioiditis'},
#  {'chronophotographic', 'photochronographic'},
#  {'electrothermometer', 'thermoelectrometer'},
#  {'epididymovasostomy', 'vasoepididymostomy'},
#  {'galvanothermometer', 'thermogalvanometer'},
#  {'hexakistetrahedron', 'tetrakishexahedron'},
#  {'laryngopharyngitis', 'pharyngolaryngitis'},
#  {'laryngotracheotomy', 'tracheolaryngotomy'},
#  {'neuropsychological', 'psychoneurological'},
#  {'acetmethylanilide', 'methylacetanilide'},
#  {'basiparachromatin', 'marsipobranchiata'},
#  {'calcareosiliceous', 'siliceocalcareous'},
#  {'cephalomeningitis', 'meningocephalitis'},
#  {'cerebromeningitis', 'meningocerebritis'},
#  {'chemicomechanical', 'mechanicochemical'},
#  {'chromolithography', 'lithochromography'},
#  {'chromophotography', 'photochromography'},
#  {'chronophotography', 'photochronography'},
#  {'constitutionalism', 'misconstitutional'},
#  {'dioeciopolygamous', 'polygamodioecious'},
#  {'electromagnetical', 'magnetoelectrical'},
#  {'encephalomyelitis', 'myeloencephalitis'},
#  {'hexakisoctahedron', 'octakishexahedron'},
#  {'hydropneumothorax', 'pneumohydrothorax'},
#  {'hysterolaparotomy', 'laparohysterotomy'},
#  {'hysteromyomectomy', 'myomohysterectomy'},
#  {'laryngopharyngeal', 'pharyngolaryngeal'},
#  {'microphotographic', 'photomicrographic'},
#  {'microspectroscope', 'spectromicroscope'},
#  {'misrepresentation', 'representationism'},
#  {'pericardiopleural', 'pleuropericardial'},
#  {'antibenzaldoxime', 'benzantialdoxime'},
#  {'arthrochondritis', 'chondroarthritis'},
#  {'autoradiographic', 'radioautographic'},
#  {'biopsychological', 'psychobiological'},
#  {'calcareocorneous', 'corneocalcareous'},
#  {'chronophotograph', 'photochronograph'},
#  {'configurationism', 'misconfiguration'},
#  {'dynamoelectrical', 'electrodynamical'},
#  {'ferrihydrocyanic', 'hydroferricyanic'},
#  {'ferrohydrocyanic', 'hydroferrocyanic'},
#  {'fibromyxosarcoma', 'myxofibrosarcoma'},
#  {'glycerophosphate', 'phosphoglycerate'},
#  {'heliophotography', 'photoheliography'},
#  {'hemopneumothorax', 'pneumohemothorax'},
#  {'incontrovertible', 'introconvertible'},
#  {'intestinovesical', 'vesicointestinal'},
#  {'laparosplenotomy', 'splenolaparotomy'},
#  {'lithophotography', 'photolithography'},
#  {'meningomyelocele', 'myelomeningocele'},
#  {'microphotography', 'photomicrography'},
#  {'monopersulphuric', 'permonosulphuric'},
#  {'occipitotemporal', 'temporooccipital'},
#  {'parietosquamosal', 'squamosoparietal'},
#  {'pectinatopinnate', 'pinnatopectinate'},
#  {'petrographically', 'pterylographical'},
#  {'pharyngorhinitis', 'rhinopharyngitis'},
#  {'photostereograph', 'stereophotograph'},
#  {'phototelegraphic', 'telephotographic'},
#  {'physiopsychology', 'psychophysiology'},
#  {'psychotechnology', 'technopsychology'},
#  {'pyeloureterogram', 'ureteropyelogram'},
#  {'sacculoutricular', 'utriculosaccular'},
#  {'somatosplanchnic', 'splanchnosomatic'},
#  {'spectrotelescope', 'telespectroscope'},
#  {'streptothricosis', 'streptotrichosis'},
#  {'abdominovaginal', 'vaginoabdominal'},
#  {'abdominovesical', 'vesicoabdominal'},
#  {'aluminosilicate', 'silicoaluminate'},
#  {'autoradiography', 'radioautography'},
#  {'barothermograph', 'thermobarograph'},
#  {'biosociological', 'sociobiological'},
#  {'chemicophysical', 'physicochemical'},
#  {'cinematographer', 'megachiropteran'},
#  {'columbotitanate', 'titanocolumbate'},
#  {'conservationist', 'conversationist'},
#  {'constructionism', 'misconstruction'},
#  {'cystourethritis', 'urethrocystitis'},
#  {'dactylopteridae', 'pterodactylidae'},
#  {'dermatoneurosis', 'neurodermatosis'},
#  {'dextrosinistral', 'sinistrodextral'},
#  {'ecclesiasticism', 'misecclesiastic'},
#  {'electromagnetic', 'magnetoelectric'},
#  {'enterogastritis', 'gastroenteritis'},
#  {'ethmosphenoidal', 'sphenoethmoidal'},
#  {'frontooccipital', 'occipitofrontal'},
#  {'germanification', 'remagnification'},
#  {'gramophonically', 'monographically', 'nomographically', 'phonogramically'},
#  {'hexatetrahedron', 'tetrahexahedron'},
#  {'imperscriptible', 'imprescriptible'},
#  {'impressibleness', 'permissibleness'},
#  {'inferoposterior', 'posteroinferior'},
#  {'lithonephrotomy', 'nephrolithotomy'},
#  {'macrophotograph', 'photomacrograph'},
#  {'meningomyelitis', 'myelomeningitis'},
#  {'microphotograph', 'photomicrograph'},
#  {'microphotoscope', 'photomicroscope'},
#  {'microradiometer', 'radiomicrometer'},
#  {'misunderstander', 'remisunderstand'},
#  {'parietotemporal', 'temporoparietal'},
#  {'parietovisceral', 'visceroparietal'},
#  {'phototelegraphy', 'telephotography'},
#  {'phototypography', 'phytotopography'},
#  {'pneumopyothorax', 'pyopneumothorax'},
#  {'posterosuperior', 'superoposterior'},
#  {'pretransmission', 'transimpression'},
#  {'silicotungstate', 'tungstosilicate'},
#  {'stereotelescope', 'telestereoscope'},
#  {'sternovertebral', 'vertebrosternal'},
#  {'uncreatableness', 'untraceableness'},
#  {'adenochondroma', 'chondroadenoma'},
#  {'altitudinarian', 'latitudinarian'},
#  {'angiochondroma', 'chondroangioma'},
#  {'antarchistical', 'charlatanistic'},
#  {'anteroinferior', 'inferoanterior'},
#  {'anterosuperior', 'superoanterior'},
#  {'associationism', 'misassociation'},
#  {'autoradiograph', 'radioautograph'},
#  {'blastomycetous', 'cytoblastemous'},
#  {'borofluohydric', 'hydrofluoboric'},
#  {'carcinosarcoma', 'sarcocarcinoma'},
#  {'cervicovesical', 'vesicocervical'},
#  {'chloroplatinic', 'platinochloric'},
#  {'chondrofibroma', 'fibrochondroma'},
#  {'conservational', 'conversational'},
#  {'constitutioner', 'reconstitution'},
#  {'costovertebral', 'vertebrocostal'},
#  {'cystonephrosis', 'nephrocystosis'},
#  {'dentatoserrate', 'serratodentate'},
#  {'dentatosinuate', 'sinuatodentate'},
#  {'dipterological', 'pteridological'},
#  {'dorsoventrally', 'ventrodorsally'},
#  {'duodenojejunal', 'jejunoduodenal'},
#  {'dynamoelectric', 'electrodynamic'},
#  {'electrothermic', 'thermoelectric'},
#  {'erythrophyllin', 'phylloerythrin'},
#  {'extirpationist', 'sextipartition'},
#  {'frontoparietal', 'parietofrontal'},
#  {'frontotemporal', 'temporofrontal'},
#  {'galvanopsychic', 'psychogalvanic'},
#  {'geissospermine', 'spermiogenesis'},
#  {'hemiholohedral', 'holohemihedral'},
#  {'herpetological', 'pretheological'},
#  {'hydronephrosis', 'nephrohydrosis'},
#  {'impressibility', 'permissibility'},
#  {'impressiveness', 'permissiveness'},
#  {'inconglomerate', 'nongeometrical'},
#  {'interpellation', 'interpollinate'},
#  {'intersectional', 'intraselection'},
#  {'interspiration', 'repristination'},
#  {'ludicroserious', 'serioludicrous'},
#  {'medicophysical', 'physicomedical'},
#  {'metrophlebitis', 'phlebometritis'},
#  {'misrepresenter', 'remisrepresent'},
#  {'naturistically', 'unartistically'},
#  {'nephropyelitis', 'pyelonephritis'},
#  {'neuropsychosis', 'psychoneurosis'},
#  {'nondesecration', 'recondensation'},
#  {'paradisaically', 'paradisiacally'},
#  {'perineovaginal', 'vaginoperineal'},
#  {'perturbational', 'protuberantial'},
#  {'petrographical', 'pterographical'},
#  {'petrologically', 'pterylological'},
#  {'petrosquamosal', 'squamopetrosal'},
#  {'phototelegraph', 'telephotograph'},
#  {'pleurovisceral', 'visceropleural'},
#  {'prerealization', 'proletarianize'},
#  {'presentiveness', 'pretensiveness'},
#  {'protomagnesium', 'spermatogonium'},
#  {'purpuroxanthin', 'xanthopurpurin'},
#  {'radiotelephone', 'teleradiophone'},
#  {'relativization', 'revitalization'},
#  {'rotundifoliate', 'titanofluoride'},
#  {'sacrovertebral', 'vertebrosacral'},
#  {'salinoterreous', 'soliterraneous'},
#  {'silicotitanate', 'titanosilicate'},
#  {'silicotungstic', 'tungstosilicic'},
#  {'thunderbearing', 'underbreathing'},
#  {'transamination', 'transanimation'},
#  {'unamenableness', 'unnameableness'},
#  {'aeolharmonica', 'chloroanaemia'},
#  {'aerographical', 'areographical'},
#  {'amelification', 'maleficiation'},
#  {'amplification', 'palmification'},
#  {'angiocholitis', 'cholangioitis'},
#  {'angiokeratoma', 'keratoangioma'},
#  {'anticlinorium', 'inclinatorium'},
#  {'antisoporific', 'prosification', 'sporification'},
#  {'argentiferous', 'garnetiferous'},
#  {'arthrosteitis', 'ostearthritis'},
#  {'attentiveness', 'tentativeness'},
#  {'autoheterosis', 'heteroousiast'},
#  {'beardlessness', 'breadlessness'},
#  {'benzofluorene', 'fluorobenzene'},
#  {'biopsychology', 'psychobiology'},
#  {'blastomycetic', 'cytoblastemic'},
#  {'botanophilist', 'philobotanist'},
#  {'brachiofacial', 'faciobrachial'},
#  {'buccocervical', 'cervicobuccal'},
#  {'cephalometric', 'petrochemical'},
#  {'cephalopodous', 'podocephalous'},
#  {'certification', 'cretification', 'rectification'},
#  {'certificative', 'rectificative'},
#  {'certificatory', 'rectificatory'},
#  {'cervicodorsal', 'dorsocervical'},
#  {'cervicofacial', 'faciocervical'},
#  {'cervicolabial', 'labiocervical'},
#  {'cheatableness', 'teachableness'},
#  {'cholesteremia', 'heteroecismal'},
#  {'chondrocostal', 'costochondral'},
#  {'chondrolipoma', 'lipochondroma'},
#  {'chondromyxoma', 'myxochondroma'},
#  {'coloenteritis', 'enterocolitis'},
#  {'coloproctitis', 'proctocolitis'},
#  {'competitioner', 'recompetition'},
#  {'compromission', 'procommission'},
#  {'condylomatous', 'monodactylous'},
#  {'considerative', 'devisceration'},
#  {'countertrades', 'unstercorated'},
#  {'crimelessness', 'mercilessness'},
#  {'cruroinguinal', 'inguinocrural'},
#  {'cryptostomate', 'prostatectomy'},
#  {'cystopyelitis', 'pyelocystitis'},
#  {'dactylopterus', 'pterodactylus'},
#  {'deinocephalia', 'palaeechinoid'},
#  {'demipronation', 'preadmonition', 'predomination'},
#  {'dermosclerite', 'sclerodermite'},
#  {'diageotropism', 'geodiatropism'},
#  {'diplocephalus', 'pseudophallic'},
#  {'dipterologist', 'pteridologist'},
#  {'discriminator', 'doctrinairism'},
#  {'distinguisher', 'redistinguish'},
#  {'endoarteritis', 'sideronatrite'},
#  {'ethmosphenoid', 'sphenoethmoid'},
#  {'expressionism', 'misexpression'},
#  {'frontoorbital', 'orbitofrontal'},
#  {'ganglioneuron', 'neuroganglion'},
#  {'gastrohepatic', 'hepatogastric'},
#  {'gastrophrenic', 'nephrogastric', 'phrenogastric'},
#  {'genitourinary', 'urinogenitary'},
#  {'gramophonical', 'monographical', 'nomographical'},
#  {'grandparental', 'grandpaternal'},
#  {'graphological', 'logographical'},
#  {'guarantorship', 'uranographist'},
#  {'hemicatalepsy', 'mesaticephaly'},
#  {'hepatomegalia', 'megalohepatia'},
#  {'hepatonephric', 'phrenohepatic'},
#  {'hydrosulphate', 'sulphohydrate'},
#  {'iconometrical', 'intracoelomic'},
#  {'impersonation', 'prosemination', 'semipronation'},
#  {'impressionism', 'misimpression'},
#  {'incudomalleal', 'malleoincudal'},
#  {'innovationist', 'nonvisitation'},
#  {'instructional', 'nonaltruistic'},
#  {'interactional', 'intercalation'},
#  {'intermorainic', 'recrimination'},
#  {'interspecific', 'prescientific'},
#  {'intervascular', 'vernacularist'},
#  {'investigation', 'tenovaginitis'},
#  {'lachrymonasal', 'nasolachrymal'},
#  {'lateroventral', 'ventrolateral'},
#  {'megalophonous', 'omphalogenous'},
#  {'megalosplenia', 'splenomegalia'},
#  {'micranthropos', 'promonarchist'},
#  {'micropetalous', 'somatopleuric'},
#  {'misperception', 'perceptionism'},
#  {'missuggestion', 'suggestionism'},
#  {'myeloneuritis', 'neuromyelitis'},
#  {'nephrocardiac', 'phrenocardiac'},
#  {'ornithomantic', 'orthantimonic'},
#  {'osteometrical', 'stereotomical'},
#  {'overcirculate', 'uterocervical'},
#  {'oversauciness', 'veraciousness'},
#  {'paranephritis', 'paraphrenitis'},
#  {'parasyntheton', 'thysanopteran'},
#  {'pedometrician', 'premedication'},
#  {'perambulation', 'preambulation'},
#  {'perambulatory', 'preambulatory'},
#  {'peridiastolic', 'periodicalist', 'proidealistic'},
#  {'personalistic', 'pictorialness'},
#  {'phrenosplenic', 'splenonephric', 'splenophrenic'},
#  {'pneumatophony', 'pneumonopathy'},
#  {'podostomatous', 'stomatopodous'},
#  {'prediscretion', 'redescription'},
#  {'propraetorial', 'protoperlaria'},
#  {'protosulphide', 'sulphoproteid'},
#  {'psychosomatic', 'somatopsychic'},
#  {'pyosepticemia', 'septicopyemia'},
#  {'pyosepticemic', 'septicopyemic'},
#  {'redintegrator', 'retrogradient'},
#  {'resupposition', 'superposition'},
#  {'sacrification', 'scarification'},
#  {'scorbutically', 'subcortically'},
#  {'superintender', 'unenterprised'},
#  {'unamenability', 'unnameability'},
#  {'uncertifiable', 'unrectifiable'},
#  {'unconservable', 'unconversable'},
#  {'unimpressible', 'unpermissible'},
#  {'unspecterlike', 'unspectrelike'},
#  {'unsusceptible', 'unsuspectible'},
#  {'vaginovesical', 'vesicovaginal'},
#  {'accomplisher', 'reaccomplish'},
#  {'acherontical', 'anchoretical'},
#  {'achromatinic', 'chromatician'},
#  {'acidophilous', 'aphidicolous'},
#  {'acrostically', 'socratically'},
#  {'actinopteran', 'precantation'},
#  {'acutenaculum', 'unaccumulate'},
#  {'adenocystoma', 'cystoadenoma'},
#  {'adenofibroma', 'fibroadenoma'},
#  {'adenosarcoma', 'sarcoadenoma'},
#  {'adpromission', 'proadmission'},
#  {'adrenotropic', 'incorporated'},
#  {'alcantarines', 'lancasterian'},
#  {'allothogenic', 'ethnological'},
#  {'alterability', 'bilaterality', 'relatability'},
#  {'amphitropous', 'pastophorium'},
#  {'anemographic', 'phanerogamic'},
#  {'angiofibroma', 'fibroangioma'},
#  {'anteluminary', 'unalimentary'},
#  {'anticreative', 'antireactive'},
#  {'antifriction', 'nitrifaction'},
#  {'antimosquito', 'misquotation'},
#  {'antiphonetic', 'pentathionic'},
#  {'antiprotease', 'entoparasite'},
#  {'antiroyalist', 'stationarily'},
#  {'antitropical', 'practitional'},
#  {'aphorismical', 'parochialism'},
#  {'aqueoigneous', 'igneoaqueous'},
#  {'arsenopyrite', 'pyroarsenite'},
#  {'bicarpellary', 'prebacillary'},
#  {'blepharocera', 'reproachable'},
#  {'branchiopoda', 'podobranchia'},
#  {'bromohydrate', 'hydrobromate'},
#  {'cacodaemonic', 'cacodemoniac'},
#  {'callisection', 'clinoclasite'},
#  {'calotermitid', 'dilatometric'},
#  {'capsulectomy', 'scapulectomy'},
#  {'carbohydride', 'hydrocarbide'},
#  {'cartesianism', 'sectarianism'},
#  {'caudofemoral', 'femorocaudal'},
#  {'caudolateral', 'laterocaudal'},
#  {'centrodorsal', 'dorsocentral'},
#  {'centrolineal', 'crenellation'},
#  {'ceratothecal', 'chloracetate'},
#  {'certificator', 'rectificator'},
#  {'cervicodynia', 'corycavidine'},
#  {'chapelmaster', 'spermathecal'},
#  {'chaperonless', 'proseneschal'},
#  {'cheiropodist', 'coeditorship'},
#  {'chemicovital', 'vitochemical'},
#  {'chiromancist', 'monarchistic'},
#  {'chirosophist', 'opisthorchis'},
#  {'chloroanemia', 'choleromania'},
#  {'chloroiodide', 'iodochloride'},
#  {'chromatocyte', 'thoracectomy'},
#  {'chrysography', 'psychorrhagy'},
#  {'clonicotonic', 'tonicoclonic'},
#  {'coalitionist', 'solicitation'},
#  {'collectioner', 'recollection'},
#  {'colpeurynter', 'counterreply'},
#  {'colporrhagia', 'orographical'},
#  {'commentarial', 'manometrical'},
#  {'commissioner', 'recommission'},
#  {'compenetrate', 'contemperate'},
#  {'comprehender', 'recomprehend'},
#  {'concessioner', 'reconcession'},
#  {'connoissance', 'nonaccession'},
#  {'conservation', 'conversation'},
#  {'conservative', 'conversative'},
#  {'conturbation', 'obtruncation'},
#  {'conventioner', 'reconvention'},
#  {'coprophagist', 'topographics'},
#  {'cornucopiate', 'reoccupation'},
#  {'corporealist', 'prosectorial'},
#  {'correctioner', 'recorrection'},
#  {'costosternal', 'sternocostal'},
#  {'counteracter', 'countercarte'},
#  {'countercharm', 'countermarch'},
#  {'counterguard', 'uncorrugated'},
#  {'counterpaled', 'counterplead', 'unpercolated'},
#  {'countershade', 'decantherous'},
#  {'counterstand', 'uncontrasted'},
#  {'courtiership', 'peritrichous'},
#  {'creativeness', 'reactiveness'},
#  {'creditorship', 'directorship'},
#  {'crestmoreite', 'stereometric'},
#  {'cricothyroid', 'thyrocricoid'},
#  {'crurogenital', 'genitocrural'},
#  {'cystofibroma', 'fibrocystoma'},
#  {'decimestrial', 'sedimetrical'},
#  {'delicateness', 'delicatessen'},
#  {'delimitation', 'mniotiltidae'},
#  {'demiparallel', 'imparalleled'},
#  {'dentilingual', 'indulgential', 'linguidental'},
#  {'dentolingual', 'linguodental'},
#  {'depositional', 'despoliation'},
#  {'depreciation', 'predeication'},
#  {'derivational', 'revalidation'},
#  {'dermatophone', 'herpetomonad'},
#  {'dipteraceous', 'epiceratodus'},
#  {'disadventure', 'unadvertised'},
#  {'disastimeter', 'semistriated'},
#  {'discontinuer', 'undiscretion'},
#  {'discreetness', 'discreteness'},
#  {'dorsolateral', 'laterodorsal'},
#  {'dorsoventrad', 'ventrodorsad'},
#  {'dorsoventral', 'ventrodorsal'},
#  {'empathically', 'emphatically'},
#  {'energeticist', 'energetistic'},
#  {'erythrophage', 'heterography'},
#  {'etherization', 'heterization'},
#  {'exasperation', 'xenoparasite'},
#  {'famelessness', 'selfsameness'},
#  {'femorotibial', 'tibiofemoral'},
#  {'fibroneuroma', 'neurofibroma'},
#  {'fingerflower', 'fringeflower'},
#  {'foundationer', 'refoundation'},
#  {'gallotannate', 'tannogallate'},
#  {'gastropathic', 'graphostatic'},
#  {'geohydrology', 'hydrogeology'},
#  {'glossolabial', 'labioglossal'},
#  {'gonidiferous', 'indigoferous'},
#  {'gramophonist', 'monographist'},
#  {'graphophonic', 'phonographic'},
#  {'haptophorous', 'pathophorous'},
#  {'heretication', 'theoretician'},
#  {'heterocarpus', 'urethrascope'},
#  {'heterogynous', 'thyreogenous'},
#  {'homeotypical', 'polymetochia'},
#  {'humeroradial', 'radiohumeral'},
#  {'humoralistic', 'humoristical'},
#  {'hurtlessness', 'ruthlessness'},
#  {'hypostomatic', 'somatophytic'},
#  {'hysteropathy', 'hysterophyta'},
#  {'iatraliptics', 'partialistic'},
#  {'impenetrable', 'intemperable'},
#  {'impenetrably', 'intemperably'},
#  {'importunance', 'unimportance'},
#  {'impressively', 'permissively'},
#  {'inactivation', 'vaticination'},
#  {'incomputable', 'uncompatible'},
#  {'inconsistent', 'nonscientist'},
#  {'indefinitude', 'unidentified'},
#  {'indeprivable', 'predivinable'},
#  {'indiscreetly', 'indiscretely', 'iridescently'},
#  {'inobtainable', 'nonbilabiate'},
#  {'inoperculata', 'precautional'},
#  {'intercession', 'recensionist'},
#  {'interimistic', 'trimesitinic'},
#  {'interoceptor', 'reprotection'},
#  {'interpellate', 'pantellerite'},
#  {'interproduce', 'prereduction'},
#  {'intersituate', 'tenuistriate'},
#  {'interstation', 'strontianite'},
#  {'intervention', 'introvenient'},
#  {'intolerating', 'nitrogelatin'},
#  {'irrationable', 'orbitelarian'},
#  {'irrepentance', 'pretercanine'},
#  {'ischiorectal', 'sciotherical'},
#  {'isosaccharic', 'sacroischiac'},
#  {'lactoprotein', 'protectional'},
#  {'lepidosauria', 'pliosauridae'},
#  {'lipsanotheca', 'sphacelation'},
#  {'lithonephria', 'philotherian'},
#  {'logometrical', 'metrological'},
#  {'lymphectasia', 'metaphysical'},
#  {'malacologist', 'mastological'},
#  {'manslaughter', 'slaughterman'},
#  {'matelessness', 'tamelessness'},
#  {'medioventral', 'ventromedial'},
#  {'metaphorical', 'pharmacolite'},
#  {'metronomical', 'monometrical'},
#  {'microcephaly', 'pyrochemical'},
#  {'micropterous', 'prosectorium'},
#  {'mistradition', 'traditionism'},
#  {'monocystidae', 'monocystidea'},
#  {'monophyllous', 'nomophyllous'},
#  {'monopsychism', 'psychomonism'},
#  {'morphotropic', 'protomorphic'},
#  {'multinervose', 'volunteerism'},
#  {'mythographer', 'thermography'},
#  {'narcaciontes', 'transoceanic'},
#  {'naturalistic', 'unartistical'},
#  {'nematophyton', 'tenontophyma'},
#  {'nepheloscope', 'phonelescope'},
#  {'nephological', 'phenological'},
#  {'nephrologist', 'phrenologist'},
#  {'nephropathic', 'phrenopathic'},
#  {'nephropsidae', 'praesphenoid'},
#  {'nephroptosia', 'prosiphonate'},
#  {'nephropyosis', 'pyonephrosis'},
#  {'noncertified', 'nonrectified'},
#  {'noncurantist', 'unconstraint'},
#  {'nonempirical', 'prenominical'},
#  {'nonpearlitic', 'pratincoline'},
#  {'notelessness', 'tonelessness'},
#  {'obscurantist', 'substraction'},
#  {'octastrophic', 'postthoracic'},
#  {'oligonephria', 'oligophrenia'},
#  {'oligonephric', 'oligophrenic'},
#  {'ornithoptera', 'prototherian'},
#  {'palification', 'pontificalia'},
#  {'palmatilobed', 'palmilobated'},
#  {'patroclinous', 'pratincolous'},
#  {'pelycography', 'pyrgocephaly'},
#  {'peradventure', 'preadventure'},
#  {'perceptively', 'preceptively'},
#  {'perceptually', 'preceptually'},
#  {'percontation', 'pernoctation'},
#  {'percussioner', 'repercussion'},
#  {'perfoliation', 'prefoliation'},
#  {'performative', 'preformative'},
#  {'perpetualist', 'pluriseptate'},
#  {'perviousness', 'previousness', 'viperousness'},
#  {'petrographer', 'pterographer'},
#  {'petrographic', 'pterographic'},
#  {'photographer', 'rephotograph'},
#  {'phrenocostal', 'plastochrone'},
#  {'phyllopodous', 'podophyllous'},
#  {'phytogenesis', 'pythogenesis'},
#  {'phytogenetic', 'pythogenetic'},
#  {'platysternal', 'transeptally'},
#  {'plousiocracy', 'procaciously'},
#  {'podarthritis', 'traditorship'},
#  {'poetastrical', 'spectatorial'},
#  {'policyholder', 'polychloride'},
#  {'possessioner', 'repossession'},
#  {'prasophagous', 'saprophagous'},
#  {'precipitator', 'prepatriotic'},
#  {'preconnubial', 'pronunciable'},
#  {'preconsultor', 'supercontrol'},
#  {'prediastolic', 'psiloceratid'},
#  {'presentively', 'pretensively'},
#  {'proportioner', 'reproportion'},
#  {'proreduction', 'reproduction'},
#  {'prototrophic', 'trophotropic'},
#  {'pseudelytron', 'unproselyted'},
#  {'psychotheism', 'theopsychism'},
#  {'rachianectes', 'rhacianectes'},
#  {'reattraction', 'retractation'},
#  {'rectovesical', 'vesicorectal'},
#  {'rederivation', 'veratroidine'},
#  {'reillustrate', 'ultrasterile'},
#  {'reimpression', 'repermission'},
#  {'remuneration', 'renumeration'},
#  {'repercussive', 'superservice'},
#  {'restraighten', 'straightener'},
#  {'restrengthen', 'strengthener'},
#  {'resupination', 'uranospinite'},
#  {'retransplant', 'transplanter'},
#  {'ritelessness', 'tirelessness'},
#  {'rubification', 'urbification'},
#  {'sacrificator', 'scarificator'},
#  {'salamandarin', 'salamandrian', 'salamandrina'},
#  {'sempiternous', 'supermoisten'},
#  {'serpentinous', 'supertension'},
#  {'spermatozoic', 'zoospermatic'},
#  {'sporotrichum', 'trichosporum'},
#  {'spotlessness', 'stoplessness'},
#  {'statefulness', 'tastefulness'},
#  {'stretcherman', 'trenchmaster'},
#  {'strophiolate', 'theatropolis'},
#  {'subessential', 'suitableness'},
#  {'subterraneal', 'unarrestable'},
#  {'supernacular', 'supranuclear'},
#  {'surprisement', 'trumperiness'},
#  {'swordmanship', 'wordsmanship'},
#  {'terebinthian', 'terebinthina'},
#  {'tournamental', 'ultramontane'},
#  {'unbraceleted', 'uncelebrated'},
#  {'uncatalogued', 'uncoagulated'},
#  {'unexceptable', 'unexpectable'},
#  {'unimpressive', 'unpermissive'},
#  {'unpenetrable', 'unrepentable'},
#  {'unreinstated', 'unstraitened'},
#  {'unsusceptive', 'unsuspective'},
#  {'acalyptrate', 'calyptratae'},
#  {'accelerator', 'retrocaecal'},
#  {'accessioner', 'reaccession'},
#  {'acidanthera', 'cantharidae'},
#  {'acipenserid', 'presidencia'},
#  {'acrimonious', 'isocoumarin'},
#  {'acroclinium', 'alcicornium'},
#  {'acrosticism', 'socraticism'},
#  {'acrotrophic', 'prothoracic'},
#  {'actaeonidae', 'donatiaceae'},
#  {'actinopteri', 'crepitation', 'precitation'},
#  {'adaptionism', 'adoptianism'},
#  {'adenectopic', 'pentadecoic'},
#  {'adenolipoma', 'palaemonoid'},
#  {'adorability', 'roadability'},
#  {'adrenolytic', 'declinatory'},
#  {'aecidioform', 'formicoidea'},
#  {'aerographer', 'areographer'},
#  {'aerographic', 'areographic'},
#  {'aerological', 'areological'},
#  {'aeronautism', 'measuration'},
#  {'aerostatics', 'aortectasis'},
#  {'afunctional', 'unfactional'},
#  {'alchemistic', 'hemiclastic'},
#  {'alexandrian', 'alexandrina'},
#  {'algorithmic', 'logarithmic'},
#  {'alstonidine', 'nonidealist'},
#  {'altitudinal', 'latitudinal'},
#  {'amenability', 'nameability'},
#  {'amenorrheal', 'melanorrhea'},
#  {'amidophenol', 'monodelphia'},
#  {'ammonolytic', 'commonality'},
#  {'amperemeter', 'permeameter'},
#  {'amphigenous', 'musophagine'},
#  {'amphiphloic', 'amphophilic'},
#  {'amphipodous', 'hippodamous'},
#  {'anacreontic', 'canceration'},
#  {'analeptical', 'placentalia'},
#  {'anaphorical', 'pharaonical'},
#  {'anarthropod', 'arthropodan'},
#  {'anchoretism', 'trichomanes'},
#  {'anchoritism', 'chiromantis', 'chrismation', 'harmonistic'},
#  {'anemography', 'phanerogamy'},
#  {'angelically', 'englacially'},
#  {'anhematosis', 'somasthenia'},
#  {'anhydridize', 'hydrazidine'},
#  {'anisometric', 'creationism', 'miscreation', 'ramisection', 'reactionism'},
#  {'anorthitite', 'trithionate'},
#  {'anthogenous', 'neognathous'},
#  {'antialbumid', 'balantidium'},
#  {'anticouncil', 'inculcation'},
#  {'antidotical', 'dictational'},
#  {'antiextreme', 'exterminate'},
#  {'antimallein', 'inalimental'},
#  {'antinepotic', 'pectination'},
#  {'antineutral', 'triannulate'},
#  {'antiphrasis', 'artisanship'},
#  {'antipyretic', 'pertinacity'},
#  {'antireducer', 'reincrudate', 'untraceried'},
#  {'antitorpedo', 'deportation'},
#  {'aphrodistic', 'diastrophic'},
#  {'apostrophus', 'pastophorus'},
#  {'apportioner', 'reapportion'},
#  {'appraisable', 'parablepsia'},
#  {'apprehender', 'reapprehend'},
#  {'arachidonic', 'characinoid'},
#  {'archapostle', 'thecasporal'},
#  {'archprelate', 'pretracheal'},
#  {'arenicolite', 'ricinoleate'},
#  {'ascertainer', 'reascertain', 'secretarian'},
#  {'assertional', 'sensatorial'},
#  {'asthmogenic', 'mesognathic'},
#  {'attentively', 'tentatively'},
#  {'avolitional', 'violational'},
#  {'bacteriform', 'bracteiform'},
#  {'behaviorism', 'misbehavior'},
#  {'benzonitrol', 'nitrobenzol'},
#  {'blastogenic', 'genoblastic'},
#  {'blastomeric', 'meroblastic'},
#  {'blisterwort', 'bristlewort'},
#  {'bombacaceae', 'cabombaceae'},
#  {'bosselation', 'eosinoblast'},
#  {'brachiopode', 'cardiophobe'},
#  {'broadcaster', 'rebroadcast'},
#  {'broadspread', 'spreadboard'},
#  {'calandrinae', 'calendarian'},
#  {'calculative', 'claviculate'},
#  {'calendarial', 'dalecarlian'},
#  {'calligraphy', 'graphically'},
#  {'calonectria', 'ectocranial'},
#  {'capernoited', 'deprecation'},
#  {'capillament', 'implacental'},
#  {'capillarity', 'piratically'},
#  {'carnationed', 'dinoceratan'},
#  {'carolingian', 'inorganical'},
#  {'carpocerite', 'reciprocate'},
#  {'carpogonial', 'coprolagnia'},
#  {'catapultier', 'particulate'},
#  {'caudodorsal', 'dorsocaudal'},
#  {'cavillation', 'vacillation'},
#  {'censureless', 'recluseness'},
#  {'centinormal', 'conterminal', 'nonmetrical'},
#  {'centraxonia', 'excarnation'},
#  {'centunculus', 'unsucculent'},
#  {'ceroplastic', 'cleistocarp', 'coreplastic'},
#  {'certifiable', 'rectifiable'},
#  {'cetomorphic', 'chemotropic', 'ectomorphic'},
#  {'chaenolobus', 'unchoosable'},
#  {'chaetognath', 'gnathotheca'},
#  {'chatelainry', 'trachylinae'},
#  {'chelidonate', 'endothecial'},
#  {'chemiatrist', 'chrismatite', 'theatricism'},
#  {'chiastolite', 'heliostatic'},
#  {'chionididae', 'onchidiidae'},
#  {'chiromantic', 'chromatinic'},
#  {'chiroplasty', 'polyarchist'},
#  {'chloroamine', 'melanochroi'},
#  {'chordotonal', 'notochordal'},
#  {'chorization', 'rhizoctonia', 'zonotrichia'},
#  {'chromotypic', 'cormophytic', 'mycotrophic'},
#  {'citharoedic', 'diachoretic'},
#  {'citrination', 'intrication'},
#  {'cleistogeny', 'lysogenetic'},
#  {'clericature', 'recirculate'},
#  {'clitoridean', 'directional'},
#  {'coinherence', 'incoherence'},
#  {'collationer', 'recollation'},
#  {'colonialist', 'oscillation'},
#  {'comitragedy', 'tragicomedy'},
#  {'commination', 'monamniotic'},
#  {'comparition', 'proamniotic'},
#  {'conditioner', 'recondition'},
#  {'congenerous', 'necrogenous'},
#  {'connectival', 'conventical'},
#  {'conservable', 'conversable'},
#  {'conservancy', 'conversancy'},
#  {'considerate', 'desecration'},
#  {'constructer', 'reconstruct'},
#  {'conycatcher', 'technocracy'},
#  {'copyrighter', 'recopyright'},
#  {'coriamyrtin', 'criminatory'},
#  {'corrodentia', 'recordation'},
#  {'cosmetician', 'encomiastic'},
#  {'costispinal', 'pansciolist'},
#  {'cotranspire', 'pornerastic'},
#  {'counteridea', 'decurionate'},
#  {'counterpaly', 'counterplay'},
#  {'countersale', 'counterseal'},
#  {'countertail', 'reluctation'},
#  {'countervail', 'involucrate'},
#  {'countervair', 'overcurtain', 'recurvation'},
#  {'craniectomy', 'cyanometric'},
#  {'craniognomy', 'organonymic'},
#  {'crateriform', 'terraciform'},
#  {'cratometric', 'metrocratic'},
#  {'creationary', 'reactionary'},
#  {'creationist', 'reactionist'},
#  {'crematorial', 'mercatorial'},
#  {'crenelation', 'intolerance'},
#  {'criminalese', 'misreliance'},
#  {'crocidolite', 'crocodilite'},
#  {'cryptomeria', 'imprecatory'},
#  {'cushionless', 'slouchiness'},
#  {'cyanophycin', 'phycocyanin'},
#  {'cystomyxoma', 'myxocystoma'},
#  {'dactylonomy', 'monodactyly'},
#  {'decimosexto', 'sextodecimo'},
#  {'declaration', 'redactional'},
#  {'dehortation', 'theriodonta'},
#  {'deification', 'edification'},
#  {'deificatory', 'edificatory'},
#  {'deistically', 'dialystelic'},
#  {'delusionist', 'indissolute'},
#  {'demandingly', 'maddeningly'},
#  {'demarcation', 'democratian'},
#  {'demoniacism', 'seminomadic'},
#  {'demurringly', 'murderingly'},
#  {'dentolabial', 'labiodental'},
#  {'denunciator', 'underaction'},
#  {'departition', 'partitioned', 'trepidation'},
#  {'depetticoat', 'petticoated'},
#  {'deploration', 'periodontal'},
#  {'depravingly', 'pervadingly'},
#  {'description', 'discerption'},
#  {'desiccation', 'discoactine'},
#  {'desperation', 'esperantido'},
#  {'determinant', 'detrainment'},
#  {'diamorphine', 'phronimidae'},
#  {'diaphtherin', 'diphtherian'},
#  {'diphosphate', 'phosphatide'},
#  {'dipterology', 'pteridology'},
#  {'disappearer', 'redisappear'},
#  {'discernment', 'rescindment'},
#  {'dismemberer', 'disremember'},
#  {'disparation', 'tridiapason'},
#  {'dispensable', 'piebaldness'},
#  {'divisionism', 'misdivision'},
#  {'dorsoapical', 'prosodiacal'},
#  {'dorsomedial', 'mediodorsal'},
#  {'dorsosacral', 'sacrodorsal'},
#  {'elaphomyces', 'mesocephaly'},
#  {'elytroposis', 'proteolysis'},
#  {'enarthrosis', 'nearthrosis'},
#  {'endearingly', 'engrainedly'},
#  {'endosporium', 'imponderous'},
#  {'engrailment', 'realignment'},
#  {'ensepulcher', 'ensepulchre'},
#  {'entablature', 'untreatable'},
#  {'entomophily', 'monophylite'},
#  {'entoplastic', 'spinotectal', 'tectospinal', 'tenoplastic'},
#  {'enumeration', 'mountaineer'},
#  {'enunciation', 'incuneation'},
#  {'erucivorous', 'overcurious'},
#  {'esperantism', 'strepsinema'},
#  {'ethological', 'lethologica', 'theological'},
#  {'eucalypteol', 'eucalyptole'},
#  {'eucatropine', 'neurectopia'},
#  {'evilhearted', 'vilehearted'},
#  {'examination', 'exanimation'},
#  {'festination', 'infestation', 'sinfonietta'},
#  {'fibrolipoma', 'lipofibroma'},
#  {'fibromucous', 'mucofibrous'},
#  {'fibromyxoma', 'myxofibroma'},
#  {'fibroserous', 'serofibrous'},
#  {'forwardness', 'frowardness'},
#  {'frigolabile', 'glorifiable'},
#  {'frontonasal', 'nasofrontal'},
#  {'fruticulose', 'luctiferous'},
#  {'fulminatory', 'unformality'},
#  {'gallotannic', 'tannogallic'},
#  {'gallybagger', 'gallybeggar'},
#  {'gametogenic', 'gamogenetic', 'geomagnetic'},
#  {'gastronomic', 'monogastric'},
#  {'gelatinizer', 'integralize'},
#  {'genotypical', 'ptyalogenic'},
#  {'geoisotherm', 'isogeotherm'},
#  {'geometrical', 'glaciometer'},
#  {'geotectonic', 'tocogenetic'},
#  {'geranomorph', 'monographer', 'nomographer'},
#  {'glycerinize', 'glycerizine'},
#  {'goldenmouth', 'longmouthed'},
#  {'gongoresque', 'gorgonesque'},
#  {'graminiform', 'marginiform'},
#  {'gramophonic', 'monographic', 'nomographic', 'phonogramic'},
#  {'grangousier', 'gregarinous'},
#  {'graphologic', 'logographic'},
#  {'graphometer', 'meteorgraph'},
#  {'graphotypic', 'pictography', 'typographic'},
#  {'grasshopper', 'hoppergrass'},
#  {'halophytism', 'hylopathism'},
#  {'halterbreak', 'leatherbark'},
#  {'handicapper', 'prehandicap'},
#  {'haptophoric', 'pathophoric'},
#  {'haptotropic', 'protopathic'},
#  {'heartedness', 'neatherdess'},
#  {'heliotactic', 'thiolacetic'},
#  {'helleborein', 'helleborine'},
#  {'hemiatrophy', 'hypothermia'},
#  {'hemiparesis', 'phariseeism'},
#  {'hepatocolic', 'otocephalic'},
#  {'hepatostomy', 'somatophyte'},
#  {'heptaploidy', 'typhlopidae'},
#  {'heretically', 'heterically'},
#  {'heteratomic', 'theorematic'},
#  {'heteroclite', 'heterotelic'},
#  {'heterodromy', 'hydrometeor'},
#  {'heteropathy', 'theotherapy'},
#  {'heteropodal', 'prelatehood'},
#  {'holocentrid', 'lechriodont'},
#  {'homeogenous', 'homogeneous'},
#  {'hurtfulness', 'ruthfulness'},
#  {'hydrocharis', 'hydrorachis'},
#  {'hymnologist', 'smoothingly'},
#  {'hyothyreoid', 'thyreohyoid'},
#  {'hypergamous', 'museography'},
#  {'hypoglottis', 'phytologist'},
#  {'hyposcleral', 'phylloceras'},
#  {'hysteresial', 'hysteriales'},
#  {'idioretinal', 'litorinidae'},
#  {'ilioischiac', 'ischioiliac'},
#  {'illaudatory', 'laudatorily'},
#  {'illoricated', 'lacertiloid'},
#  {'immaterials', 'materialism'},
#  {'impenetrate', 'intemperate'},
#  {'impersonate', 'proseminate'},
#  {'importunate', 'permutation'},
#  {'impressible', 'permissible'},
#  {'impressibly', 'permissibly'},
#  {'improcreant', 'preromantic'},
#  {'incensation', 'inscenation'},
#  {'inconsonant', 'nonsanction'},
#  {'incorporate', 'procreation'},
#  {'insectivora', 'visceration'},
#  {'integrative', 'vertiginate', 'vinaigrette'},
#  {'interastral', 'intertarsal'},
#  {'interfering', 'interfinger'},
#  {'interleaver', 'reverential'},
#  {'intermutual', 'ultraminute'},
#  {'internality', 'itinerantly'},
#  {'internecive', 'reincentive'},
#  {'interpolate', 'triantelope'},
#  {'interposure', 'neuropteris'},
#  {'interpreter', 'reinterpret'},
#  {'interrupter', 'reinterrupt'},
#  {'intersocial', 'orleanistic', 'sclerotinia'},
#  {'intersporal', 'tripersonal'},
#  {'interverbal', 'invertebral'},
#  {'interviewer', 'reinterview'},
#  {'intracosmic', 'narcoticism'},
#  {'intracostal', 'stratonical'},
#  {'intraseptal', 'paternalist', 'prenatalist'},
#  {'intraspinal', 'pinnitarsal'},
#  {'inversatile', 'serviential'},
#  {'isophthalyl', 'lithophysal'},
#  {'jebusitical', 'justiciable'},
#  {'labiomental', 'mentolabial'},
#  {'laminectomy', 'metonymical'},
#  {'laryngotome', 'maternology'},
#  {'latirostres', 'setirostral'},
#  {'latrocinium', 'tourmalinic'},
#  {'leonhardite', 'lionhearted'},
#  {'longanimous', 'longimanous'},
#  {'lumbosacral', 'sacrolumbal'},
#  {'lymphadenia', 'nymphalidae'},
#  {'lymphopenia', 'polyphemian'},
#  {'memorandist', 'moderantism', 'semidormant'},
#  {'mentigerous', 'tergeminous'},
#  {'merosthenic', 'microsthene'},
#  {'mesological', 'semological'},
#  {'mesoventral', 'ventromesal'},
#  {'metaplastic', 'palmatisect'},
#  {'metatrophic', 'metropathic'},
#  {'meteoristic', 'meteoritics'},
#  {'metrectasia', 'remasticate'},
#  {'metroptosia', 'prostomiate'},
#  {'microcephal', 'prochemical'},
#  {'microcinema', 'microcnemia'},
#  {'misrelation', 'orientalism', 'relationism'},
#  {'misreporter', 'reporterism'},
#  {'mithraicist', 'mithraistic'},
#  {'modernistic', 'monstricide'},
#  {'monadically', 'nomadically'},
#  {'monoclinous', 'monoclonius'},
#  {'monological', 'nomological'},
#  {'monomorphic', 'morphonomic'},
#  {'monoplanist', 'postnominal'},
#  {'monotypical', 'toponymical'},
#  {'monumentary', 'unmomentary'},
#  {'motographic', 'tomographic'},
#  {'mycophagist', 'phagocytism'},
#  {'myocolpitis', 'polysomitic'},
#  {'myographist', 'pythagorism'},
#  {'myotenotomy', 'tenomyotomy'},
#  {'naphthalize', 'phthalazine'},
#  {'nasoorbital', 'orbitonasal'},
#  {'nasopalatal', 'palatonasal'},
#  {'necessarian', 'renaissance'},
#  {'neotropical', 'percolation'},
#  {'nephologist', 'phenologist'},
#  {'nephrocolic', 'phrenocolic'},
#  {'nephropathy', 'phrenopathy'},
#  {'nephrostoma', 'strophomena'},
#  {'neurotripsy', 'tripyrenous'},
#  {'neutralness', 'unalertness'},
#  {'noncreation', 'nonreaction'},
#  {'noncreative', 'nonreactive'},
#  {'nonoriental', 'nonrelation'},
#  {'nonparental', 'nonpaternal'},
#  {'objectative', 'objectivate'},
#  {'obliviality', 'violability'},
#  {'obscurantic', 'subnarcotic'},
#  {'offuscation', 'suffocation'},
#  {'oncosimeter', 'semicoronet'},
#  {'ontological', 'tonological'},
#  {'opiniatrety', 'petitionary'},
#  {'optableness', 'potableness'},
#  {'optological', 'topological'},
#  {'orientalist', 'relationist'},
#  {'orthogonial', 'orthologian'},
#  {'ostentation', 'tionontates'},
#  {'osteometric', 'stereotomic'},
#  {'outsideness', 'tediousness'},
#  {'ovariotubal', 'tuboovarial'},
#  {'overpointed', 'predevotion'},
#  {'pactionally', 'polyactinal'},
#  {'palaestrics', 'paracelsist'},
#  {'paniculitis', 'paulinistic'},
#  {'panornithic', 'rhaponticin'},
#  {'paracolitis', 'piscatorial'},
#  {'paragrapher', 'reparagraph'},
#  {'paranephric', 'paraphrenic'},
#  {'parasuchian', 'unpharasaic'},
#  {'parentalism', 'paternalism'},
#  {'parentality', 'paternality'},
#  {'parenticide', 'preindicate'},
#  {'partitioner', 'repartition'},
#  {'paternoster', 'prosternate', 'transportee'},
#  {'pendulation', 'pennatuloid'},
#  {'pentameroid', 'predominate'},
#  {'perambulate', 'preambulate'},
#  {'percompound', 'precompound'},
#  {'perforative', 'prefavorite'},
#  {'peripatetic', 'precipitate'},
#  {'peripatidae', 'peripatidea'},
#  {'periplaneta', 'prepalatine'},
#  {'peripterous', 'prepositure'},
#  ...]

# %%
# Sort the dictionary by the size of the word sets in descending order
sorted_anagrams_by_sig = {sig: wordset for sig, wordset in sorted(anagrams_by_sig.items(), key=lambda item: len(item[1]), reverse=True)}

# Print the sorted dictionary of anagrams
for sig, word_set in sorted_anagrams_by_sig.items():
    print(f"Signature: {sig} -> Anagrams: {word_set}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Signature: dehhinooprrssy -> Anagrams: {'hydronephrosis', 'nephrohydrosis'}
# Signature: acddeehiimmnoopprrruuy -> Anagrams: {'hydropneumopericardium', 'pneumohydropericardium'}
# Signature: adehhmnoooprrtuxy -> Anagrams: {'hydropneumothorax', 'pneumohydrothorax'}
# Signature: adehhloprstuy -> Anagrams: {'sulphohydrate', 'hydrosulphate'}
# Signature: dhorsuy -> Anagrams: {'hydrous', 'shroudy'}
# Signature: hilsty -> Anagrams: {'slithy', 'hylist'}
# Signature: hllsuy -> Anagrams: {'lushly', 'hyllus'}
# Signature: cehimtty -> Anagrams: {'hymettic', 'thymetic'}
# Signature: ghilmnoosty -> Anagrams: {'hymnologist', 'smoothingly'}
# Signature: dehhioortyy -> Anagrams: {'thyreohyoid', 'hyothyreoid'}
# Signature: dhhioortyy -> Anagrams: {'thyrohyoid', 'hyothyroid'}
# Signature: aehhnoprty -> Anagrams: {'hypaethron', 'hypothenar'}
# Signature: aeghmoprsuy -> Anagrams: {'museography', 'hypergamous'}
# Signature: cehioprtxy -> Anagrams: {'xerophytic', 'hypertoxic'}
# Signature: cehinopty -> Anagrams: {'neophytic', 'hypnoetic'}
# Signature: himnopsty -> Anagrams: {'pythonism', 'hypnotism'}
# Signature: hinopstty -> Anagrams: {'pythonist', 'hypnotist'}
# Signature: ehinoptyz -> Anagrams: {'pythonize', 'hypnotize'}
# Signature: dhinoopty -> Anagrams: {'hypnotoid', 'pythonoid'}
# Signature: behloopy -> Anagrams: {'hypobole', 'lyophobe'}
# Signature: adhinoopry -> Anagrams: {'radiophony', 'hypodorian'}
# Signature: ghiloopstty -> Anagrams: {'hypoglottis', 'phytologist'}
# Signature: ehnoopprty -> Anagrams: {'phonotyper', 'hypopteron'}
# Signature: adhioprsuy -> Anagrams: {'hyporadius', 'suprahyoid'}
# Signature: acehlloprsy -> Anagrams: {'phylloceras', 'hyposcleral'}
# Signature: ahimopsy -> Anagrams: {'phymosia', 'hyposmia'}
# Signature: achimoopstty -> Anagrams: {'hypostomatic', 'somatophytic'}
# Signature: cehhopty -> Anagrams: {'photechy', 'hypothec'}
# Signature: dhiilopsy -> Anagrams: {'syphiloid', 'hypsiloid'}
# Signature: aeehilrssty -> Anagrams: {'hysteresial', 'hysteriales'}
# Signature: aehirsty -> Anagrams: {'hysteria', 'sheriyat'}
# Signature: aaehlmoooprrsttyy -> Anagrams: {'hysterolaparotomy', 'laparohysterotomy'}
# Signature: ceehmmmooorsttyyy -> Anagrams: {'hysteromyomectomy', 'myomohysterectomy'}
# Signature: aehhoprsttyy -> Anagrams: {'hysterophyta', 'hysteropathy'}
# Signature: abim -> Anagrams: {'iamb', 'mabi'}
# Signature: ainsu -> Anagrams: {'suina', 'ianus'}
# Signature: aaciiilprstt -> Anagrams: {'partialistic', 'iatraliptics'}
# Signature: aciirt -> Anagrams: {'tricia', 'iatric'}
# Signature: bio -> Anagrams: {'obi', 'ibo'}
# Signature: acceip -> Anagrams: {'ipecac', 'icecap'}
# Signature: cehiilnot -> Anagrams: {'neolithic', 'ichnolite'}
# Signature: aceilnoort -> Anagrams: {'relocation', 'iconolater'}
# Signature: aaciimnnoo -> Anagrams: {'iconomania', 'oniomaniac'}
# Signature: acceiilmnoort -> Anagrams: {'intracoelomic', 'iconometrical'}
# Signature: ceeiinrt -> Anagrams: {'reincite', 'icterine'}
# Signature: cinotxy -> Anagrams: {'ictonyx', 'oxyntic'}
# Signature: adeiilms -> Anagrams: {'lamiides', 'idealism'}
# Signature: adeeilnss -> Anagrams: {'idealness', 'leadiness'}
# Signature: adeilopsty -> Anagrams: {'ideoplasty', 'stylopidae'}
# Signature: adiims -> Anagrams: {'idiasm', 'simiad'}
# Signature: dgiilmoooy -> Anagrams: {'idiomology', 'oligomyoid'}
# Signature: adeiiilnort -> Anagrams: {'litorinidae', 'idioretinal'}
# Signature: adeilmn -> Anagrams: {'idleman', 'melinda'}
# Signature: deeilst -> Anagrams: {'isleted', 'idleset'}
# Signature: dily -> Anagrams: {'idly', 'idyl'}
# Signature: acdeiors -> Anagrams: {'idocrase', 'radicose'}
# Signature: diimos -> Anagrams: {'idoism', 'iodism'}
# Signature: dilry -> Anagrams: {'idryl', 'lyrid'}
# Signature: dgiry -> Anagrams: {'igdyr', 'ridgy'}
# Signature: giloo -> Anagrams: {'igloo', 'logoi'}
# Signature: cgiiilnost -> Anagrams: {'soliciting', 'ignicolist'}
# Signature: giinort -> Anagrams: {'ignitor', 'rioting'}
# Signature: aginnort -> Anagrams: {'ignorant', 'tongrian'}
# Signature: eginor -> Anagrams: {'region', 'ignore'}
# Signature: eegimnnort -> Anagrams: {'omnigerent', 'ignorement'}
# Signature: ahilt -> Anagrams: {'tahil', 'ihlat'}
# Signature: aijm -> Anagrams: {'jami', 'ijma'}
# Signature: aikno -> Anagrams: {'ikona', 'konia'}
# Signature: aiiln -> Anagrams: {'ilian', 'inial'}
# Signature: acchiiiilos -> Anagrams: {'ilioischiac', 'ischioiliac'}
# Signature: aaciillors -> Anagrams: {'iliosacral', 'oscillaria'}
# Signature: ikl -> Anagrams: {'kil', 'ilk'}
# Signature: aeiilltv -> Anagrams: {'veiltail', 'illative'}
# Signature: aadillortuy -> Anagrams: {'illaudatory', 'laudatorily'}
# Signature: iiillnos -> Anagrams: {'illision', 'illinois'}
# Signature: iillmu -> Anagrams: {'illium', 'lilium'}
# Signature: acdeiillort -> Anagrams: {'lacertiloid', 'illoricated'}
# Signature: hillt -> Anagrams: {'illth', 'thill'}
# Signature: gilnoot -> Anagrams: {'ilongot', 'tooling'}
# Signature: ilot -> Anagrams: {'ilot', 'toil'}
# Signature: aily -> Anagrams: {'ilya', 'yali'}
# Signature: aegiimnr -> Anagrams: {'imaginer', 'migraine'}
# Signature: agiimst -> Anagrams: {'stigmai', 'imagist'}
# Signature: aeiimnr -> Anagrams: {'imerina', 'inermia'}
# Signature: aaeiilmmrst -> Anagrams: {'immaterials', 'materialism'}
# Signature: beeiilmmrs -> Anagrams: {'semilimber', 'immersible'}
# Signature: eiimmnors -> Anagrams: {'immersion', 'semiminor'}
# Signature: iimm -> Anagrams: {'immi', 'mimi'}
# Signature: imp -> Anagrams: {'pim', 'imp'}
# Signature: aciimnopt -> Anagrams: {'ptomainic', 'impaction'}
# Signature: aegimps -> Anagrams: {'impages', 'mispage'}
# Signature: aiimnpt -> Anagrams: {'impaint', 'timpani'}
# Signature: aiimpr -> Anagrams: {'pamiri', 'impair'}
# Signature: aailmp -> Anagrams: {'impala', 'malapi'}
# Signature: ailmpsy -> Anagrams: {'impalsy', 'misplay'}
# Signature: aeimnp -> Anagrams: {'impane', 'pieman'}
# Signature: aeilmnp -> Anagrams: {'maniple', 'impanel'}
# Signature: ailmpr -> Anagrams: {'imparl', 'primal'}
# Signature: aeimprrt -> Anagrams: {'reimpart', 'imparter'}
# Signature: aaiilmprt -> Anagrams: {'primatial', 'impartial'}
# Signature: aeimpst -> Anagrams: {'impaste', 'pastime'}
# Signature: aeimprstu -> Anagrams: {'septarium', 'impasture'}
# Signature: deeiimnpt -> Anagrams: {'impedient', 'mendipite'}
# Signature: abeeeilmnprt -> Anagrams: {'intemperable', 'impenetrable'}
# Signature: abeeilmnprty -> Anagrams: {'intemperably', 'impenetrably'}
# Signature: aeeeimnprtt -> Anagrams: {'intemperate', 'impenetrate'}
# Signature: aeeimprt -> Anagrams: {'premiate', 'imperate'}
# Signature: bceeiiilmpprrst -> Anagrams: {'imprescriptible', 'imperscriptible'}
# Signature: aeeimnoprst -> Anagrams: {'impersonate', 'proseminate'}
# Signature: ceiimopst -> Anagrams: {'poeticism', 'impeticos'}
# Signature: eimpstu -> Anagrams: {'upsmite', 'impetus'}
# Signature: eehimp -> Anagrams: {'phemie', 'imphee'}
# Signature: aeilmnprt -> Anagrams: {'implanter', 'reimplant'}
# Signature: aeilmpt -> Anagrams: {'palmite', 'implate'}
# Signature: giilmnp -> Anagrams: {'impling', 'limping'}
# Signature: eillmoptu -> Anagrams: {'multipole', 'impollute'}
# Signature: eimnnopt -> Anagrams: {'imponent', 'pimenton'}
# Signature: aceimnnoprtu -> Anagrams: {'importunance', 'unimportance'}
# Signature: aeimnoprttu -> Anagrams: {'importunate', 'permutation'}
# Signature: ailmops -> Anagrams: {'spiloma', 'imposal'}
# Signature: eimoprst -> Anagrams: {'imposter', 'tripsome'}
# Signature: eimoprsu -> Anagrams: {'premious', 'imposure'}
# Signature: eeimprrss -> Anagrams: {'impresser', 'reimpress'}
# Signature: beiiiilmprssty -> Anagrams: {'permissibility', 'impressibility'}
# Signature: beeiilmprss -> Anagrams: {'permissible', 'impressible'}
# Signature: beeeiilmnprssss -> Anagrams: {'impressibleness', 'permissibleness'}
# Signature: beiilmprssy -> Anagrams: {'impressibly', 'permissibly'}
# Signature: eiimnoprss -> Anagrams: {'permission', 'impression'}
# Signature: eiiimmnoprsss -> Anagrams: {'impressionism', 'misimpression'}
# Signature: eeiimprssv -> Anagrams: {'permissive', 'impressive'}
# Signature: eeiilmprssvy -> Anagrams: {'permissively', 'impressively'}
# Signature: eeeiimnprssssv -> Anagrams: {'permissiveness', 'impressiveness'}
# Signature: eeimprrssu -> Anagrams: {'impressure', 'presurmise'}
# Signature: eiimnprrt -> Anagrams: {'imprinter', 'reimprint'}
# Signature: eiimnoprrs -> Anagrams: {'reimprison', 'imprisoner'}
# Signature: aceimnoprrt -> Anagrams: {'preromantic', 'improcreant'}
# Signature: hiimpps -> Anagrams: {'pimpish', 'impship'}
# Signature: abegilmnpu -> Anagrams: {'plumbagine', 'impugnable'}
# Signature: eimpru -> Anagrams: {'umpire', 'impure'}
# Signature: aiimnprtu -> Anagrams: {'partinium', 'impuritan'}
# Signature: eimprtu -> Anagrams: {'imputer', 'trumpie'}
# Signature: in -> Anagrams: {'in', 'ni'}
# Signature: aaceiinttv -> Anagrams: {'inactivate', 'vaticinate'}
# Signature: aaciiinnottv -> Anagrams: {'vaticination', 'inactivation'}
# Signature: aaijn -> Anagrams: {'jaina', 'inaja'}
# Signature: aimnr -> Anagrams: {'minar', 'inarm'}
# Signature: aaeinrtu -> Anagrams: {'inaurate', 'ituraean'}
# Signature: acinst -> Anagrams: {'incast', 'nastic'}
# Signature: aceiinnnost -> Anagrams: {'incensation', 'inscenation'}
# Signature: ceinpt -> Anagrams: {'incept', 'pectin'}
# Signature: ceinoprt -> Anagrams: {'pretonic', 'inceptor'}
# Signature: acehinot -> Anagrams: {'noachite', 'inchoate'}
# Signature: aciilns -> Anagrams: {'salicin', 'incisal'}
# Signature: ciiinnos -> Anagrams: {'incision', 'inosinic'}
# Signature: ceiinrsu -> Anagrams: {'sciurine', 'incisure'}
# Signature: cdeilnu -> Anagrams: {'nuclide', 'include'}
# Signature: ceimnor -> Anagrams: {'incomer', 'moneric'}
# Signature: abceilmnoptu -> Anagrams: {'uncompatible', 'incomputable'}
# Signature: cdeiinnot -> Anagrams: {'incondite', 'nicotined'}
# Signature: aceegilmnnoort -> Anagrams: {'nongeometrical', 'inconglomerate'}
# Signature: ceiinnnosstt -> Anagrams: {'inconsistent', 'nonscientist'}
# Signature: acinnnnoost -> Anagrams: {'inconsonant', 'nonsanction'}
# Signature: bceiiiilnnoorrtttvy -> Anagrams: {'incontrovertibility', 'introconvertibility'}
# Signature: bceeiilnnoorrttv -> Anagrams: {'introconvertible', 'incontrovertible'}
# Signature: aceinooprrt -> Anagrams: {'procreation', 'incorporate'}
# Signature: cddeeiinrt -> Anagrams: {'indirected', 'incredited'}
# Signature: aceilnnrtu -> Anagrams: {'unicentral', 'incruental'}
# Signature: acinnrsttu -> Anagrams: {'scrutinant', 'incrustant'}
# Signature: aacdeilllmnou -> Anagrams: {'incudomalleal', 'malleoincudal'}
# Signature: cinsu -> Anagrams: {'incus', 'usnic'}
# Signature: adinn -> Anagrams: {'nandi', 'indan'}
# Signature: ddeefiiinntu -> Anagrams: {'indefinitude', 'unidentified'}
# Signature: ddeeinnt -> Anagrams: {'indented', 'intended'}
# Signature: ddeeilnnty -> Anagrams: {'indentedly', 'intendedly'}
# Signature: deeimnnntt -> Anagrams: {'indentment', 'intendment'}
# Signature: ddeeinnrtu -> Anagrams: {'indentured', 'underntide'}
# Signature: abdeeiilnprv -> Anagrams: {'indeprivable', 'predivinable'}
# Signature: deiins -> Anagrams: {'indies', 'inside'}
# Signature: adegiiintt -> Anagrams: {'indigitate', 'tingitidae'}
# Signature: deiint -> Anagrams: {'tineid', 'indite'}
# Signature: deiinrt -> Anagrams: {'nitride', 'inditer'}
# Signature: deilnos -> Anagrams: {'sondeli', 'indoles'}
# Signature: dgiilnoost -> Anagrams: {'nidologist', 'indologist'}
# Signature: dgilnooy -> Anagrams: {'indology', 'nidology'}
# Signature: dinoors -> Anagrams: {'sordino', 'indoors'}
# Signature: adinnrw -> Anagrams: {'indrawn', 'winnard'}
# Signature: cdeinu -> Anagrams: {'uniced', 'induce'}
# Signature: cdeinru -> Anagrams: {'uncried', 'inducer'}
# Signature: degilnru -> Anagrams: {'ungirdle', 'indulger'}
# Signature: deimnntu -> Anagrams: {'indument', 'unminted'}
# Signature: adeinrtu -> Anagrams: {'indurate', 'turdinae'}
# Signature: adeiinuv -> Anagrams: {'induviae', 'viduinae'}
# Signature: bdeeiillnu -> Anagrams: {'ineludible', 'unelidible'}
# Signature: einpt -> Anagrams: {'pinte', 'inept'}
# Signature: eimnr -> Anagrams: {'miner', 'inerm'}
# Signature: eimnorsu -> Anagrams: {'inermous', 'monsieur'}
# Signature: aceeinnrt -> Anagrams: {'inertance', 'nectarine'}
# Signature: aeiilnrt -> Anagrams: {'linarite', 'inertial'}
# Signature: einntu -> Anagrams: {'untine', 'ineunt'}
# Signature: einz -> Anagrams: {'inez', 'zein'}
# Signature: afimny -> Anagrams: {'manify', 'infamy'}
# Signature: acfiinnort -> Anagrams: {'infarction', 'infraction'}
# Signature: abeefilnr -> Anagrams: {'refinable', 'inferable'}
# Signature: eefiinoooprrrst -> Anagrams: {'posteroinferior', 'inferoposterior'}
# Signature: eefinrst -> Anagrams: {'reinfest', 'infester'}
# Signature: defiiln -> Anagrams: {'infidel', 'infield'}
# Signature: aefilmnr -> Anagrams: {'rifleman', 'inflamer'}
# Signature: afilnstu -> Anagrams: {'inflatus', 'stainful'}
# Signature: cefiilnrt -> Anagrams: {'inflicter', 'reinflict'}
# Signature: afinr -> Anagrams: {'irfan', 'infra'}
# Signature: efgiinnr -> Anagrams: {'infringe', 'refining'}
# Signature: eginnosuu -> Anagrams: {'ingenuous', 'unigenous'}
# Signature: ginorw -> Anagrams: {'ingrow', 'rowing'}
# Signature: ghinortw -> Anagrams: {'ingrowth', 'throwing'}
# Signature: agiilnnu -> Anagrams: {'inguinal', 'unailing'}
# Signature: abehiinrt -> Anagrams: {'inhabiter', 'reinhabit'}
# Signature: ehimnru -> Anagrams: {'rhenium', 'inhumer'}
# Signature: ikn -> Anagrams: {'ink', 'kin'}
# Signature: eikln -> Anagrams: {'liken', 'inkle'}
# Signature: eiklnss -> Anagrams: {'kinless', 'inkless'}
# Signature: giiklnn -> Anagrams: {'inkling', 'linking'}
# Signature: iknnot -> Anagrams: {'tonkin', 'inknot'}
# Signature: ailntu -> Anagrams: {'unital', 'inlaut'}
# Signature: ailnw -> Anagrams: {'liwan', 'inlaw'}
# Signature: ailny -> Anagrams: {'naily', 'inlay'}
# Signature: aeilnry -> Anagrams: {'inlayer', 'nailery'}
# Signature: eilnt -> Anagrams: {'inlet', 'linet'}
# Signature: iklnoo -> Anagrams: {'koilon', 'inlook'}
# Signature: ilny -> Anagrams: {'inly', 'liny'}
# Signature: aeiinntv -> Anagrams: {'innative', 'invinate'}
# Signature: aailnnrtu -> Anagrams: {'innatural', 'triannual'}
# Signature: einnr -> Anagrams: {'inner', 'renin'}
# Signature: einnt -> Anagrams: {'tinne', 'innet'}
# Signature: aeinnotv -> Anagrams: {'venation', 'innovate'}
# Signature: aiiinnnoosttv -> Anagrams: {'innovationist', 'nonvisitation'}
# Signature: ino -> Anagrams: {'ion', 'ino'}
# Signature: aabbeiilnnot -> Anagrams: {'inobtainable', 'nonbilabiate'}
# Signature: acinoprsu -> Anagrams: {'inocarpus', 'unprosaic'}
# Signature: aimmnooxy -> Anagrams: {'myxoinoma', 'inomyxoma'}
# Signature: einno -> Anagrams: {'inone', 'oenin'}
# Signature: aaceilnoprtu -> Anagrams: {'inoperculata', 'precautional'}
# Signature: ciinos -> Anagrams: {'inosic', 'sinico'}
# Signature: eiinost -> Anagrams: {'inosite', 'sionite'}
# Signature: aehinps -> Anagrams: {'inphase', 'phineas'}
# Signature: inptu -> Anagrams: {'punti', 'input'}
# Signature: eiinqtu -> Anagrams: {'quinite', 'inquiet'}
# Signature: aeiilnrty -> Anagrams: {'inreality', 'linearity'}
# Signature: innru -> Anagrams: {'inrun', 'inurn'}
# Signature: aeinns -> Anagrams: {'insane', 'sienna'}
# Signature: aabiilnsty -> Anagrams: {'sanability', 'insatiably'}
# Signature: ceiinnst -> Anagrams: {'nicenist', 'inscient'}
# Signature: cilnpsu -> Anagrams: {'sculpin', 'insculp'}
# Signature: aceinnst -> Anagrams: {'instance', 'insectan'}
# Signature: ceeiilnst -> Anagrams: {'selenitic', 'insectile'}
# Signature: aceiinorstv -> Anagrams: {'visceration', 'insectivora'}
# Signature: ceeinrsu -> Anagrams: {'insecure', 'sinecure'}
# Signature: eeins -> Anagrams: {'insee', 'seine'}
# Signature: eeinrrst -> Anagrams: {'reinsert', 'inserter'}
# Signature: einorsss -> Anagrams: {'insessor', 'rosiness'}
# Signature: hinoost -> Anagrams: {'inshoot', 'insooth'}
# Signature: deiinrs -> Anagrams: {'siderin', 'insider'}
# Signature: eiinnsstt -> Anagrams: {'tintiness', 'insistent'}
# Signature: aiimnnos -> Anagrams: {'simonian', 'insomnia'}
# Signature: binors -> Anagrams: {'insorb', 'sorbin'}
# Signature: eiiinprrst -> Anagrams: {'reinspirit', 'inspiriter'}
# Signature: aeillnrst -> Anagrams: {'reinstall', 'installer'}
# Signature: aeinnrstt -> Anagrams: {'transient', 'instanter'}
# Signature: einpst -> Anagrams: {'instep', 'spinet'}
# Signature: eiillnrst -> Anagrams: {'instiller', 'reinstill'}
# Signature: aciilnnorsttu -> Anagrams: {'nonaltruistic', 'instructional'}
# Signature: ailnnstu -> Anagrams: {'sultanin', 'insulant'}
# Signature: eilnssu -> Anagrams: {'silenus', 'insulse'}
# Signature: iknnsu -> Anagrams: {'insunk', 'unskin'}
# Signature: abeilnrsu -> Anagrams: {'insurable', 'sublinear'}
# Signature: aceinnrsu -> Anagrams: {'nuisancer', 'insurance'}
# Signature: ainnrstu -> Anagrams: {'insurant', 'unstrain'}
# Signature: eginrsu -> Anagrams: {'resuing', 'insurge'}
# Signature: eginnrstu -> Anagrams: {'unresting', 'insurgent'}
# Signature: agiilnot -> Anagrams: {'ligation', 'intaglio'}
# Signature: aeiknt -> Anagrams: {'intake', 'kentia'}
# Signature: aaeiinrstt -> Anagrams: {'intarsiate', 'nestiatria'}
# Signature: aeilmnoprt -> Anagrams: {'trampoline', 'intemporal'}
# Signature: eeinnst -> Anagrams: {'sennite', 'intense'}
# Signature: einntt -> Anagrams: {'tinnet', 'intent'}
# Signature: eilnntty -> Anagrams: {'nitently', 'intently'}
# Signature: aaceiilnnortt -> Anagrams: {'intercalation', 'interactional'}
# Signature: aeillnrty -> Anagrams: {'reliantly', 'interally'}
# Signature: aaeilnrrstt -> Anagrams: {'interastral', 'intertarsal'}
# Signature: cdeeeinrt -> Anagrams: {'tridecene', 'intercede'}
# Signature: ceeiinnorsst -> Anagrams: {'recensionist', 'intercession'}
# Signature: aceilnnort -> Anagrams: {'nonrecital', 'interconal'}
# Signature: aeeinrtt -> Anagrams: {'intereat', 'tinetare'}
# Signature: eeeinrrstt -> Anagrams: {'reinterest', 'interester'}
# Signature: eefgiinnrrt -> Anagrams: {'interfinger', 'interfering'}
# Signature: eiimnrt -> Anagrams: {'termini', 'interim'}
# Signature: ceiiiimnrstt -> Anagrams: {'trimesitinic', 'interimistic'}
# Signature: aeilnrty -> Anagrams: {'interlay', 'lyterian'}
# Signature: aeefilnrt -> Anagrams: {'interleaf', 'reinflate'}
# Signature: aeeeilnrrtv -> Anagrams: {'reverential', 'interleaver'}
# Signature: eilnortt -> Anagrams: {'interlot', 'trotline'}
# Signature: acehimnrtt -> Anagrams: {'thermantic', 'intermatch'}
# Signature: aceiiimnnorrt -> Anagrams: {'intermorainic', 'recrimination'}
# Signature: aeilmnrttuu -> Anagrams: {'intermutual', 'ultraminute'}
# Signature: einnrt -> Anagrams: {'intern', 'tinner'}
# Signature: aeiilnnrtty -> Anagrams: {'itinerantly', 'internality'}
# Signature: ceeeiinnrtv -> Anagrams: {'reincentive', 'internecive'}
# Signature: eeeinnrt -> Anagrams: {'retinene', 'internee'}
# Signature: ceeinooprrtt -> Anagrams: {'reprotection', 'interoceptor'}
# Signature: aeeinprstu -> Anagrams: {'interpause', 'resupinate'}
# Signature: aeeinprtv -> Anagrams: {'interpave', 'prenative'}
# Signature: aeeilnprt -> Anagrams: {'interplea', 'interpeal'}
# Signature: aeeeillnprtt -> Anagrams: {'interpellate', 'pantellerite'}
# Signature: aeeiillnnoprtt -> Anagrams: {'interpollinate', 'interpellation'}
# Signature: eehinnoprt -> Anagrams: {'pinnothere', 'interphone'}
# Signature: aeilnprty -> Anagrams: {'interplay', 'painterly'}
# Signature: adeeilnprt -> Anagrams: {'peridental', 'interplead'}
# Signature: aeilnoprrt -> Anagrams: {'interpolar', 'reniportal'}
# Signature: aeeilnoprtt -> Anagrams: {'interpolate', 'triantelope'}
# Signature: aeilnoprst -> Anagrams: {'interposal', 'psalterion'}
# Signature: eeinoprrstu -> Anagrams: {'neuropteris', 'interposure'}
# Signature: eeeinprrrtt -> Anagrams: {'interpreter', 'reinterpret'}
# Signature: cdeeinoprrtu -> Anagrams: {'prereduction', 'interproduce'}
# Signature: eimnoorrt -> Anagrams: {'interroom', 'remontoir'}
# Signature: eeinprrrttu -> Anagrams: {'reinterrupt', 'interrupter'}
# Signature: aeeilnrst -> Anagrams: {'larsenite', 'intersale'}
# Signature: aceeiilnnorstt -> Anagrams: {'intersectional', 'intraselection'}
# Signature: aeeiinrstttu -> Anagrams: {'intersituate', 'tenuistriate'}
# Signature: cceefiiinprst -> Anagrams: {'prescientific', 'interspecific'}
# Signature: aeiiinnoprrstt -> Anagrams: {'interspiration', 'repristination'}
# Signature: aeilnoprrst -> Anagrams: {'intersporal', 'tripersonal'}
# Signature: aeiinnorsttt -> Anagrams: {'strontianite', 'interstation'}
# Signature: aeiklnrtt -> Anagrams: {'intertalk', 'latterkin'}
# Signature: eeiinrtt -> Anagrams: {'retinite', 'intertie'}
# Signature: eeinnortt -> Anagrams: {'intertone', 'retention'}
# Signature: aaceilnrrstuv -> Anagrams: {'vernacularist', 'intervascular'}
# Signature: eeiinnnorttv -> Anagrams: {'introvenient', 'intervention'}
# Signature: abeeilnrrtv -> Anagrams: {'interverbal', 'invertebral'}
# Signature: eeeiinrrtvw -> Anagrams: {'reinterview', 'interviewer'}
# Signature: deeinrtw -> Anagrams: {'interwed', 'wintered'}
# Signature: ehiinrstw -> Anagrams: {'interwish', 'winterish'}
# Signature: eiknorrtw -> Anagrams: {'interwork', 'tinworker'}
# Signature: eeinortvw -> Anagrams: {'overtwine', 'interwove'}
# Signature: aceeiiilnnossttv -> Anagrams: {'vesicointestinal', 'intestinovesical'}
# Signature: ghinnort -> Anagrams: {'northing', 'inthrong'}
# Signature: aiimnt -> Anagrams: {'timani', 'intima'}
# Signature: aeiimnrtt -> Anagrams: {'intimater', 'traintime'}
# Signature: aegiilnnortt -> Anagrams: {'nitrogelatin', 'intolerating'}
# Signature: aeinnott -> Anagrams: {'intonate', 'totanine'}
# Signature: ainnoortt -> Anagrams: {'intonator', 'tortonian'}
# Signature: einnot -> Anagrams: {'intone', 'tenino'}
# Signature: eeimnnnott -> Anagrams: {'intonement', 'omnitenent'}
# Signature: einnort -> Anagrams: {'intoner', 'ternion'}
# Signature: acciimnorst -> Anagrams: {'intracosmic', 'narcoticism'}
# Signature: aacilnorstt -> Anagrams: {'stratonical', 'intracostal'}
# Signature: aceiilnrtt -> Anagrams: {'intractile', 'triclinate'}
# Signature: aadinrt -> Anagrams: {'intrada', 'radiant'}
# Signature: aaiilnnprst -> Anagrams: {'intraspinal', 'pinnitarsal'}
# Signature: ceehinnrrt -> Anagrams: {'reintrench', 'intrencher'}
# Signature: aceiinrtt -> Anagrams: {'intricate', 'triactine'}
# Signature: egiinrtu -> Anagrams: {'tigurine', 'intrigue'}
# Signature: cdeinortu -> Anagrams: {'reduction', 'introduce'}
# Signature: iinortt -> Anagrams: {'nitriot', 'introit'}
# Signature: iinorsttu -> Anagrams: {'introitus', 'routinist'}
# Signature: einrstu -> Anagrams: {'sturine', 'intruse'}
# Signature: inrsttu -> Anagrams: {'sturtin', 'intrust'}
# Signature: einru -> Anagrams: {'inure', 'urine'}
# Signature: iinnostu -> Anagrams: {'inustion', 'unionist'}
# Signature: aabeillnuv -> Anagrams: {'unvailable', 'invaluable'}
# Signature: eegiilnrv -> Anagrams: {'relieving', 'inveigler'}
# Signature: eeinnrsstv -> Anagrams: {'inventress', 'vintneress'}
# Signature: eeinnrssv -> Anagrams: {'nerviness', 'inverness'}
# Signature: aeeiilnrstv -> Anagrams: {'serviential', 'inversatile'}
# Signature: eeinrsv -> Anagrams: {'inverse', 'versine'}
# Signature: einrtv -> Anagrams: {'virent', 'invert'}
# Signature: aeeinrstv -> Anagrams: {'invertase', 'servetian'}
# Signature: aegiiinnosttv -> Anagrams: {'tenovaginitis', 'investigation'}
# Signature: eiinrtv -> Anagrams: {'inviter', 'vitrine'}
# Signature: eiknorv -> Anagrams: {'overink', 'invoker'}
# Signature: ceilnoruv -> Anagrams: {'volucrine', 'involucre'}
# Signature: adinrsw -> Anagrams: {'inwards', 'sinward'}
# Signature: hiintw -> Anagrams: {'within', 'inwith'}
# Signature: diiimnou -> Anagrams: {'iodinium', 'ionidium'}
# Signature: deiiot -> Anagrams: {'teioid', 'iodite'}
# Signature: dioo -> Anagrams: {'iodo', 'ooid'}
# Signature: acdeiinoos -> Anagrams: {'oniscoidea', 'iodocasein'}
# Signature: dhiinoorty -> Anagrams: {'iodothyrin', 'thyroiodin'}
# Signature: dioosu -> Anagrams: {'iodous', 'odious'}
# Signature: eiinorz -> Anagrams: {'ironize', 'ionizer'}
# Signature: aiot -> Anagrams: {'tiao', 'iota'}
# Signature: aciiostt -> Anagrams: {'iotacist', 'taoistic'}
# Signature: iilp -> Anagrams: {'ipil', 'pili'}
# Signature: aiinr -> Anagrams: {'irian', 'irani'}
# Signature: aiimnrs -> Anagrams: {'sirmian', 'iranism'}
# Signature: aiinrst -> Anagrams: {'iranist', 'istrian'}
# Signature: aeilrty -> Anagrams: {'reality', 'irately'}
# Signature: eir -> Anagrams: {'ire', 'rie'}
# Signature: ceiinr -> Anagrams: {'irenic', 'ricine'}
# Signature: ceiimnru -> Anagrams: {'muricine', 'irenicum'}
# Signature: eeiinrs -> Anagrams: {'iresine', 'iserine'}
# Signature: adiilr -> Anagrams: {'iridal', 'lariid'}
# Signature: cdeiimorty -> Anagrams: {'iridectomy', 'mediocrity'}
# Signature: deiirs -> Anagrams: {'irides', 'irised'}
# Signature: diiimmorsu -> Anagrams: {'iridosmium', 'osmiridium'}
# Signature: ikr -> Anagrams: {'rik', 'irk'}
# Signature: ikor -> Anagrams: {'kori', 'irok'}
# Signature: acdilnor -> Anagrams: {'rolandic', 'ironclad'}
# Signature: einor -> Anagrams: {'irone', 'norie'}
# Signature: ceiinor -> Anagrams: {'oneiric', 'ironice'}
# Signature: aadiinrrt -> Anagrams: {'triandria', 'irradiant'}
# Signature: aabeiilnorrt -> Anagrams: {'orbitelarian', 'irrationable'}
# Signature: adeeinrrt -> Anagrams: {'irredenta', 'retainder'}
# Signature: aeeilrrt -> Anagrams: {'retailer', 'irrelate'}
# Signature: aceeeinnprrt -> Anagrams: {'irrepentance', 'pretercanine'}
# Signature: aagiiinnrv -> Anagrams: {'irvingiana', 'viraginian'}
# Signature: is -> Anagrams: {'is', 'si'}
# Signature: abeils -> Anagrams: {'lesbia', 'isabel'}
# Signature: aabeills -> Anagrams: {'isabella', 'sailable'}
# Signature: aacggiilos -> Anagrams: {'sialagogic', 'isagogical'}
# Signature: aciist -> Anagrams: {'isatic', 'saitic'}
# Signature: aciiinst -> Anagrams: {'isatinic', 'sinaitic'}
# Signature: aaisw -> Anagrams: {'isawa', 'waasi'}
# Signature: accehiilorst -> Anagrams: {'ischiorectal', 'sciotherical'}
# Signature: eimsu -> Anagrams: {'iseum', 'musie'}
# Signature: deiiors -> Anagrams: {'isidore', 'osiride'}
# Signature: iiss -> Anagrams: {'sisi', 'isis'}
# Signature: aciiilmst -> Anagrams: {'italicism', 'islamitic'}
# Signature: adilnsy -> Anagrams: {'islandy', 'lindsay'}
# Signature: ailsy -> Anagrams: {'saily', 'islay'}
# Signature: ims -> Anagrams: {'sim', 'ism'}
# Signature: aciimst -> Anagrams: {'itacism', 'ismatic'}
# Signature: aaciilmst -> Anagrams: {'ismatical', 'lamaistic'}
# Signature: ceiilnos -> Anagrams: {'silicone', 'isocline'}
# Signature: cdeiilostu -> Anagrams: {'solicitude', 'isodulcite'}
# Signature: ginoos -> Anagrams: {'songoi', 'isogon'}
# Signature: agimors -> Anagrams: {'orgiasm', 'isogram'}
# Signature: aeiilostv -> Anagrams: {'soliative', 'isolative'}
# Signature: deilos -> Anagrams: {'isolde', 'soiled'}
# Signature: eimors -> Anagrams: {'rimose', 'isomer'}
# Signature: himooprs -> Anagrams: {'moorship', 'isomorph'}
# Signature: eiiilnorst -> Anagrams: {'isonitrile', 'resilition'}
# Signature: ahhillopsty -> Anagrams: {'lithophysal', 'isophthalyl'}
# Signature: aeioprst -> Anagrams: {'isoptera', 'septoria'}
# Signature: aaccchiiorss -> Anagrams: {'sacroischiac', 'isosaccharic'}
# Signature: aciost -> Anagrams: {'isotac', 'scotia'}
# Signature: aiiorst -> Anagrams: {'oaritis', 'isotria'}
# Signature: inoorst -> Anagrams: {'torsion', 'isotron'}
# Signature: eiooprst -> Anagrams: {'isotrope', 'portoise'}
# Signature: iimooprsst -> Anagrams: {'promitosis', 'isotropism'}
# Signature: iooprsty -> Anagrams: {'isotropy', 'porosity'}
# Signature: aeeiilrst -> Anagrams: {'israelite', 'resiliate'}
# Signature: ainsstu -> Anagrams: {'sustain', 'issuant'}
# Signature: eissu -> Anagrams: {'issue', 'susie'}
# Signature: eirssu -> Anagrams: {'uresis', 'issuer'}
# Signature: hiimst -> Anagrams: {'isthmi', 'timish'}
# Signature: ahiimnst -> Anagrams: {'isthmian', 'smithian'}
# Signature: dhiimost -> Anagrams: {'thomisid', 'isthmoid'}
# Signature: eirstu -> Anagrams: {'isuret', 'resuit'}
# Signature: it -> Anagrams: {'ti', 'it'}
# Signature: aiilt -> Anagrams: {'itali', 'tilia'}
# Signature: aeistv -> Anagrams: {'itaves', 'stevia'}
# Signature: abeeilrt -> Anagrams: {'liberate', 'iterable'}
# Signature: aachint -> Anagrams: {'tachina', 'ithacan'}
# Signature: ehirt -> Anagrams: {'their', 'ither'}
# Signature: aeiinnrtt -> Anagrams: {'itinerant', 'nitratine'}
# Signature: iot -> Anagrams: {'toi', 'ito'}
# Signature: iimost -> Anagrams: {'omitis', 'itoism'}
# Signature: iiostt -> Anagrams: {'itoist', 'otitis'}
# Signature: efilst -> Anagrams: {'stifle', 'itself'}
# Signature: iiorstv -> Anagrams: {'visitor', 'ivorist'}
# Signature: aaiiww -> Anagrams: {'iwaiwa', 'waiwai'}
# Signature: cdiiox -> Anagrams: {'ixodic', 'oxidic'}
# Signature: ioy -> Anagrams: {'iyo', 'yoi'}
# Signature: airz -> Anagrams: {'izar', 'zira'}
# Signature: aacijm -> Anagrams: {'jacami', 'jicama'}
# Signature: agijr -> Anagrams: {'jirga', 'jagir'}
# Signature: aijl -> Anagrams: {'jail', 'lija'}
# Signature: aeijlr -> Anagrams: {'jailer', 'rejail'}
# Signature: aeijm -> Anagrams: {'jaime', 'jamie'}
# Signature: aijn -> Anagrams: {'jain', 'jina'}
# Signature: aejlosu -> Anagrams: {'jealous', 'jalouse'}
# Signature: aajm -> Anagrams: {'maja', 'jama'}
# Signature: aaeijmns -> Anagrams: {'jamesian', 'jamesina'}
# Signature: aejn -> Anagrams: {'jane', 'jean'}
# Signature: aeijklnsu -> Anagrams: {'seljukian', 'januslike'}
# Signature: aijmnops -> Anagrams: {'japonism', 'pajonism'}
# Signature: ajr -> Anagrams: {'jar', 'raj'}
# Signature: ajmor -> Anagrams: {'jarmo', 'major'}
# Signature: ajnrtu -> Anagrams: {'jarnut', 'jurant'}
# Signature: ajt -> Anagrams: {'taj', 'jat'}
# Signature: aijkt -> Anagrams: {'jatki', 'tajik'}
# Signature: ajot -> Anagrams: {'jato', 'jota'}
# Signature: ajnu -> Anagrams: {'jaun', 'juan'}
# Signature: ajpu -> Anagrams: {'puja', 'jaup'}
# Signature: abceiijlstu -> Anagrams: {'justiciable', 'jebusitical'}
# Signature: eeffjry -> Anagrams: {'jeffrey', 'jeffery'}
# Signature: eeijnn -> Anagrams: {'jennie', 'jenine'}
# Signature: eejkrr -> Anagrams: {'rejerk', 'jerker'}
# Signature: eijknr -> Anagrams: {'jerkin', 'jinker'}
# Signature: giijnost -> Anagrams: {'jingoist', 'joisting'}
# Signature: ahjno -> Anagrams: {'jonah', 'johan'}
# Signature: ijno -> Anagrams: {'join', 'joni'}
# Signature: aijnnot -> Anagrams: {'joinant', 'jotnian'}
# Signature: eijnor -> Anagrams: {'joiner', 'rejoin'}
# Signature: eijlnosst -> Anagrams: {'jointless', 'joltiness'}
# Signature: ejlort -> Anagrams: {'jolter', 'rejolt'}
# Signature: jmoo -> Anagrams: {'mojo', 'joom'}
# Signature: hijos -> Anagrams: {'shoji', 'joshi'}
# Signature: eejnorruy -> Anagrams: {'rejourney', 'journeyer'}
# Signature: jostu -> Anagrams: {'joust', 'justo'}
# Signature: acdiju -> Anagrams: {'judica', 'judaic'}
# Signature: ijjstuu -> Anagrams: {'jujitsu', 'jujuist'}
# Signature: ejtu -> Anagrams: {'jute', 'teju'}
# Signature: abekru -> Anagrams: {'kaberu', 'kubera'}
# Signature: abiklu -> Anagrams: {'kabuli', 'kiluba'}
# Signature: aikk -> Anagrams: {'kaki', 'kaik'}
# Signature: aagikn -> Anagrams: {'kainga', 'kanagi'}
# Signature: aiikw -> Anagrams: {'kiwai', 'kaiwi'}
# Signature: aaaiklmn -> Anagrams: {'kalamian', 'malikana'}
# Signature: aaikmns -> Anagrams: {'kamansi', 'kamasin'}
# Signature: aaekmrs -> Anagrams: {'seamark', 'kamares'}
# Signature: aeklm -> Anagrams: {'kamel', 'kemal'}
# Signature: aaikmy -> Anagrams: {'yakima', 'kamiya'}
# Signature: akn -> Anagrams: {'kan', 'nak'}
# Signature: aaknp -> Anagrams: {'panak', 'kanap'}
# Signature: agkn -> Anagrams: {'knag', 'kang'}
# Signature: aagiknn -> Anagrams: {'kiangan', 'kangani'}
# Signature: agikln -> Anagrams: {'kangli', 'laking'}
# Signature: akns -> Anagrams: {'kans', 'sank'}
# Signature: aeklr -> Anagrams: {'karel', 'laker'}
# Signature: agiklnr -> Anagrams: {'larking', 'karling'}
# Signature: aeekrr -> Anagrams: {'rerake', 'karree'}
# Signature: aeeiknrstt -> Anagrams: {'kersantite', 'karstenite'}
# Signature: aahkns -> Anagrams: {'kashan', 'sankha'}
# Signature: aehkrs -> Anagrams: {'shaker', 'kasher'}
# Signature: ahiks -> Anagrams: {'khasi', 'kashi'}
# Signature: akms -> Anagrams: {'kasm', 'mask'}
# Signature: aakrt -> Anagrams: {'takar', 'katar'}
# Signature: ahkt -> Anagrams: {'khat', 'kath'}
# Signature: aahikrsst -> Anagrams: {'shastraik', 'katharsis'}
# Signature: aeikt -> Anagrams: {'katie', 'keita'}
# Signature: aikkt -> Anagrams: {'katik', 'tikka'}
# Signature: aakssv -> Anagrams: {'vakass', 'kavass'}
# Signature: aikv -> Anagrams: {'kiva', 'kavi'}
# Signature: aky -> Anagrams: {'yak', 'kay'}
# Signature: aakky -> Anagrams: {'kayak', 'yakka'}
# Signature: aakny -> Anagrams: {'kayan', 'yakan'}
# Signature: akoy -> Anagrams: {'kayo', 'oaky'}
# Signature: eekn -> Anagrams: {'keen', 'knee'}
# Signature: eekp -> Anagrams: {'peek', 'keep'}
# Signature: eeehikpprs -> Anagrams: {'keepership', 'shipkeeper'}
# Signature: ehikt -> Anagrams: {'keith', 'kithe'}
# Signature: aeiklot -> Anagrams: {'keitloa', 'oatlike'}
# Signature: aeiklm -> Anagrams: {'mikael', 'kelima'}
# Signature: eeiklp -> Anagrams: {'pelike', 'kelpie'}
# Signature: eklty -> Anagrams: {'kelty', 'ketyl'}
# Signature: aeiklmst -> Anagrams: {'kemalist', 'mastlike'}
# Signature: eeklnn -> Anagrams: {'kennel', 'nelken'}
# Signature: ceiknot -> Anagrams: {'ketonic', 'kenotic'}
# Signature: eknt -> Anagrams: {'knet', 'kent'}
# Signature: eknnot -> Anagrams: {'kenton', 'nekton'}
# Signature: aeeiklrt -> Anagrams: {'tearlike', 'keralite'}
# Signature: aeiknrs -> Anagrams: {'sarkine', 'kerasin'}
# Signature: aekrt -> Anagrams: {'taker', 'kerat'}
# Signature: aeeknrs -> Anagrams: {'sneaker', 'keresan'}
# Signature: aeekrw -> Anagrams: {'rewake', 'kerewa'}
# Signature: eknr -> Anagrams: {'kern', 'renk'}
# Signature: eekrsy -> Anagrams: {'kersey', 'skeery'}
# Signature: eeklrst -> Anagrams: {'kestrel', 'skelter'}
# Signature: eklot -> Anagrams: {'loket', 'ketol'}
# Signature: aekptu -> Anagrams: {'uptake', 'ketupa'}
# Signature: ekpu -> Anagrams: {'keup', 'puke'}
# Signature: eekpru -> Anagrams: {'keuper', 'peruke'}
# Signature: aeknv -> Anagrams: {'kevan', 'knave'}
# Signature: ahikl -> Anagrams: {'kilah', 'khila'}
# Signature: ahklu -> Anagrams: {'khula', 'kulah'}
# Signature: ceikkr -> Anagrams: {'kicker', 'rekick'}
# Signature: cikkotu -> Anagrams: {'outkick', 'kickout'}
# Signature: eikl -> Anagrams: {'like', 'kiel'}
# Signature: ikku -> Anagrams: {'kuki', 'kiku'}
# Signature: ikkmnou -> Anagrams: {'kokumin', 'kikumon'}
# Signature: eikllr -> Anagrams: {'rekill', 'killer'}
# Signature: ikln -> Anagrams: {'link', 'kiln'}
# Signature: aiklmnn -> Anagrams: {'kilnman', 'linkman'}
# Signature: iklp -> Anagrams: {'kilp', 'klip'}
# Signature: eiklrt -> Anagrams: {'kilter', 'kirtle'}
# Signature: giiklnt -> Anagrams: {'kilting', 'kitling'}
# Signature: beeiiklmrt -> Anagrams: {'kimberlite', 'timberlike'}
# Signature: eiklmn -> Anagrams: {'milken', 'kimnel'}
# Signature: aeikns -> Anagrams: {'kinase', 'sekani'}
# Signature: deikln -> Anagrams: {'kindle', 'linked'}
# Signature: eeikmnort -> Anagrams: {'konimeter', 'kinetomer'}
# Signature: giiknnp -> Anagrams: {'pinking', 'kingpin'}
# Signature: giknorw -> Anagrams: {'working', 'kingrow'}
# Signature: hiiknps -> Anagrams: {'pinkish', 'kinship'}
# Signature: ikkoo -> Anagrams: {'kokio', 'kioko'}
# Signature: ikp -> Anagrams: {'pik', 'kip'}
# Signature: ikkr -> Anagrams: {'kirk', 'rikk'}
# Signature: ikknortw -> Anagrams: {'knitwork', 'kirktown'}
# Signature: iknr -> Anagrams: {'rink', 'kirn'}
# Signature: ikrsty -> Anagrams: {'skirty', 'kirsty'}
# Signature: eikrv -> Anagrams: {'kirve', 'kiver'}
# Signature: ehikns -> Anagrams: {'kishen', 'neskhi'}
# Signature: aikrss -> Anagrams: {'krasis', 'kissar'}
# Signature: eikrss -> Anagrams: {'kisser', 'rekiss'}
# Signature: ikst -> Anagrams: {'skit', 'kist'}
# Signature: fiklstu -> Anagrams: {'lutfisk', 'kistful'}
# Signature: aiknt -> Anagrams: {'takin', 'kitan'}
# Signature: cehiknt -> Anagrams: {'thicken', 'kitchen'}
# Signature: eikltt -> Anagrams: {'kittel', 'kittle'}
# Signature: eiklstt -> Anagrams: {'skittle', 'kittles'}
# Signature: akln -> Anagrams: {'lank', 'klan'}
# Signature: aiklmns -> Anagrams: {'klanism', 'silkman'}
# Signature: cdeiklnsu -> Anagrams: {'unsickled', 'klendusic'}
# Signature: klop -> Anagrams: {'polk', 'klop'}
# Signature: aknp -> Anagrams: {'knap', 'pank'}
# Signature: aeknp -> Anagrams: {'knape', 'pekan'}
# Signature: aeklnw -> Anagrams: {'wankle', 'knawel'}
# Signature: iknt -> Anagrams: {'tink', 'knit'}
# Signature: eiknrtt -> Anagrams: {'knitter', 'trinket'}
# Signature: knot -> Anagrams: {'tonk', 'knot'}
# Signature: eiknnosstt -> Anagrams: {'knottiness', 'stinkstone'}
# Signature: klnruy -> Anagrams: {'runkly', 'knurly'}
# Signature: kntu -> Anagrams: {'knut', 'tunk'}
# Signature: ekntu -> Anagrams: {'unket', 'knute'}
# Signature: ko -> Anagrams: {'ok', 'ko'}
# Signature: aiklo -> Anagrams: {'koila', 'koali'}
# Signature: eklo -> Anagrams: {'loke', 'koel'}
# Signature: iko -> Anagrams: {'koi', 'oki'}
# Signature: akkno -> Anagrams: {'kokan', 'konak'}
# Signature: kloo -> Anagrams: {'look', 'kolo'}
# Signature: ekmo -> Anagrams: {'moke', 'kome'}
# Signature: ikmo -> Anagrams: {'komi', 'moki'}
# Signature: akno -> Anagrams: {'kona', 'nako'}
# Signature: gknoo -> Anagrams: {'kongo', 'ngoko'}
# Signature: giknnoo -> Anagrams: {'nooking', 'kongoni'}
# Signature: kor -> Anagrams: {'rok', 'kor'}
# Signature: aikort -> Anagrams: {'korait', 'troika'}
# Signature: aknor -> Anagrams: {'koran', 'krona'}
# Signature: ekor -> Anagrams: {'roke', 'kore'}
# Signature: ekoorr -> Anagrams: {'korero', 'rooker'}
# Signature: aikkmoor -> Anagrams: {'korimako', 'koromika'}
# Signature: kos -> Anagrams: {'sok', 'kos'}
# Signature: akort -> Anagrams: {'tarok', 'kotar'}
# Signature: aekknr -> Anagrams: {'nekkar', 'kraken'}
# Signature: akrtu -> Anagrams: {'tukra', 'kraut'}
# Signature: eikrs -> Anagrams: {'skier', 'kreis'}
# Signature: eeiklrst -> Anagrams: {'triskele', 'kreistle'}
# Signature: eikpr -> Anagrams: {'piker', 'krepi'}
# Signature: ikrs -> Anagrams: {'kris', 'risk'}
# Signature: ahiknrs -> Anagrams: {'rankish', 'krishna'}
# Signature: koor -> Anagrams: {'rook', 'kroo'}
# Signature: akors -> Anagrams: {'oskar', 'krosa'}
# Signature: iiklmtu -> Anagrams: {'tilikum', 'kulimit'}
# Signature: klmu -> Anagrams: {'kulm', 'mulk'}
# Signature: akmnu -> Anagrams: {'naumk', 'kuman'}
# Signature: ahkmru -> Anagrams: {'kumhar', 'kumrah'}
# Signature: aiknu -> Anagrams: {'nikau', 'kunai'}
# Signature: eeknstu -> Anagrams: {'kuneste', 'netsuke'}
# Signature: ikmru -> Anagrams: {'kurmi', 'mukri'}
# Signature: krtu -> Anagrams: {'turk', 'kurt'}
# Signature: krsuu -> Anagrams: {'kurus', 'ursuk'}
# Signature: aksu -> Anagrams: {'skua', 'kusa'}
# Signature: akmsu -> Anagrams: {'sumak', 'kusam'}
# Signature: chikntu -> Anagrams: {'unthick', 'kutchin'}
# Signature: aeikntu -> Anagrams: {'unakite', 'kutenai'}
# Signature: akry -> Anagrams: {'kyar', 'yark'}
# Signature: ekly -> Anagrams: {'kyle', 'yelk'}
# Signature: kloy -> Anagrams: {'yolk', 'kylo'}
# Signature: ekty -> Anagrams: {'kyte', 'tyke'}
# Signature: abeellr -> Anagrams: {'relabel', 'labeler'}
# Signature: aabeillmnot -> Anagrams: {'mentolabial', 'labiomental'}
# Signature: aaabillnos -> Anagrams: {'nasolabial', 'labionasal'}
# Signature: abilmors -> Anagrams: {'mislabor', 'laborism'}
# Signature: abilorst -> Anagrams: {'strobila', 'laborist'}
# Signature: aabdlorr -> Anagrams: {'larboard', 'labrador'}
# Signature: aabdeilr -> Anagrams: {'labridae', 'radiable'}
# Signature: aacelmn -> Anagrams: {'laceman', 'manacle'}
# Signature: aaceelrt -> Anagrams: {'lacerate', 'lacertae'}
# Signature: aaachllmnorsy -> Anagrams: {'lachrymonasal', 'nasolachrymal'}
# Signature: aceilnss -> Anagrams: {'laciness', 'sensical'}
# Signature: aaciiln -> Anagrams: {'lacinia', 'licania'}
# Signature: acils -> Anagrams: {'salic', 'lacis'}
# Signature: aceilnorz -> Anagrams: {'locarnize', 'laconizer'}
# Signature: aceelqrru -> Anagrams: {'relacquer', 'lacquerer'}
# Signature: aaceelnrt -> Anagrams: {'lactarene', 'nectareal'}
# Signature: aacilmrtu -> Anagrams: {'lactarium', 'matricula'}
# Signature: acelostu -> Anagrams: {'lacteous', 'osculate'}
# Signature: aclot -> Anagrams: {'tlaco', 'lacto'}
# Signature: aceilnooprtt -> Anagrams: {'lactoprotein', 'protectional'}
# Signature: acklorw -> Anagrams: {'lacwork', 'warlock'}
# Signature: aadlmnu -> Anagrams: {'ladanum', 'udalman'}
# Signature: addelr -> Anagrams: {'raddle', 'ladder'}
# Signature: adhilsy -> Anagrams: {'ladyish', 'shadily'}
# Signature: aeglott -> Anagrams: {'tagetol', 'lagetto'}
# Signature: aeggln -> Anagrams: {'laggen', 'naggle'}
# Signature: aeillrss -> Anagrams: {'lairless', 'railless'}
# Signature: ailry -> Anagrams: {'lairy', 'riyal'}
# Signature: ailty -> Anagrams: {'taily', 'laity'}
# Signature: aeekllss -> Anagrams: {'leakless', 'lakeless'}
# Signature: ahikls -> Anagrams: {'lakish', 'shakil'}
# Signature: alm -> Anagrams: {'mal', 'lam'}
# Signature: aailmms -> Anagrams: {'lamaism', 'miasmal'}
# Signature: aailmst -> Anagrams: {'lamaist', 'lamista'}
# Signature: aaeilmnt -> Anagrams: {'laminate', 'lamanite'}
# Signature: aeelllmos -> Anagrams: {'semolella', 'lamellose'}
# Signature: aellmy -> Anagrams: {'lamely', 'mellay'}
# Signature: aaeilmn -> Anagrams: {'melania', 'laminae'}
# Signature: aaiilmnnr -> Anagrams: {'laminarin', 'linamarin'}
# Signature: aaeiilmnrt -> Anagrams: {'laminarite', 'terminalia'}
# Signature: aabdilmnor -> Anagrams: {'laminboard', 'lombardian'}
# Signature: aceilmmnoty -> Anagrams: {'metonymical', 'laminectomy'}
# Signature: ahilms -> Anagrams: {'shimal', 'lamish'}
# Signature: aeilmrt -> Anagrams: {'marlite', 'lamiter'}
# Signature: aelmmr -> Anagrams: {'lammer', 'rammel'}
# Signature: almmy -> Anagrams: {'lammy', 'malmy'}
# Signature: adilmn -> Anagrams: {'lamnid', 'mandil'}
# Signature: almp -> Anagrams: {'palm', 'lamp'}
# Signature: aadlmp -> Anagrams: {'palmad', 'lampad'}
# Signature: aalmps -> Anagrams: {'lampas', 'plasma'}
# Signature: aelmprs -> Anagrams: {'lampers', 'sampler'}
# Signature: afllmpu -> Anagrams: {'palmful', 'lampful'}
# Signature: ailmpst -> Anagrams: {'lampist', 'palmist'}
# Signature: ailmprsty -> Anagrams: {'lampistry', 'palmistry'}
# Signature: almnoop -> Anagrams: {'pomonal', 'lampoon'}
# Signature: aelmpry -> Anagrams: {'palmery', 'lamprey'}
# Signature: aadeilmpry -> Anagrams: {'lampyridae', 'pyramidale'}
# Signature: almtu -> Anagrams: {'lamut', 'tamul'}
# Signature: aacellnor -> Anagrams: {'lanceolar', 'olecranal'}
# Signature: acelnr -> Anagrams: {'rancel', 'lancer'}
# Signature: acelns -> Anagrams: {'senlac', 'lances'}
# Signature: adeeilmnr -> Anagrams: {'landimere', 'madrilene'}
# Signature: abbdellnru -> Anagrams: {'lubberland', 'landlubber'}
# Signature: adeeelnrv -> Anagrams: {'landreeve', 'reeveland'}
# Signature: adlmnorst -> Anagrams: {'landstorm', 'transmold'}
# Signature: aadhlnsw -> Anagrams: {'landwash', 'washland'}
# Signature: aelny -> Anagrams: {'laney', 'layne'}
# Signature: aailnst -> Anagrams: {'santali', 'lanista'}
# Signature: aelnnr -> Anagrams: {'lanner', 'rannel'}
# Signature: almnu -> Anagrams: {'lanum', 'manul'}
# Signature: aaellmnooopprsty -> Anagrams: {'splenolaparotomy', 'laparosplenotomy'}
# Signature: aadiilprst -> Anagrams: {'lapidarist', 'triapsidal'}
# Signature: aadeilpt -> Anagrams: {'lapidate', 'talpidae'}
# Signature: ahilpt -> Anagrams: {'tilpah', 'lapith'}
# Signature: alnop -> Anagrams: {'lapon', 'nopal'}
# Signature: aalpp -> Anagrams: {'lappa', 'papal'}
# Signature: aelppr -> Anagrams: {'rappel', 'lapper'}
# Signature: ahilpps -> Anagrams: {'shiplap', 'lappish'}
# Signature: agilnps -> Anagrams: {'sapling', 'lapsing'}
# Signature: aelnopst -> Anagrams: {'lapstone', 'pleonast'}
# Signature: acelnorsu -> Anagrams: {'senocular', 'larcenous'}
# Signature: aallrv -> Anagrams: {'vallar', 'larval'}
# Signature: acdeiilrv -> Anagrams: {'larvicide', 'veridical'}
# Signature: aaaegghllnnoprryy -> Anagrams: {'laryngopharyngeal', 'pharyngolaryngeal'}
# Signature: aagghiilnnoprrstyy -> Anagrams: {'pharyngolaryngitis', 'laryngopharyngitis'}
# Signature: aeglmnoorty -> Anagrams: {'laryngotome', 'maternology'}
# Signature: aaceghlmnooorrttyy -> Anagrams: {'tracheolaryngotomy', 'laryngotracheotomy'}
# Signature: akls -> Anagrams: {'lask', 'skal'}
# Signature: aeklst -> Anagrams: {'lasket', 'sklate'}
# Signature: aelqsu -> Anagrams: {'squeal', 'lasque'}
# Signature: aelsst -> Anagrams: {'tassel', 'lasset'}
# Signature: aloss -> Anagrams: {'lasso', 'ossal'}
# Signature: allsty -> Anagrams: {'saltly', 'lastly'}
# Signature: aelnssst -> Anagrams: {'lastness', 'saltness'}
# Signature: aellty -> Anagrams: {'lately', 'lealty'}
# Signature: aeelnnsstt -> Anagrams: {'tenantless', 'latentness'}
# Signature: aaelrt -> Anagrams: {'relata', 'latera'}
# Signature: aaeillrst -> Anagrams: {'lateralis', 'stellaria'}
# Signature: aaeellnorrttv -> Anagrams: {'ventrolateral', 'lateroventral'}
# Signature: aaehlmnt -> Anagrams: {'methanal', 'latheman'}
# Signature: abeiilltuz -> Anagrams: {'latibulize', 'utilizable'}
# Signature: aaceilltv -> Anagrams: {'laticlave', 'vacillate'}
# Signature: aaeiilmrt -> Anagrams: {'marialite', 'latimeria'}
# Signature: aeeilnqstu -> Anagrams: {'sequential', 'latinesque'}
# Signature: aeiilnrtz -> Anagrams: {'trinalize', 'latinizer'}
# Signature: aeilorrsstt -> Anagrams: {'latirostres', 'setirostral'}
# Signature: ailrstu -> Anagrams: {'trisula', 'latirus'}
# Signature: ahilst -> Anagrams: {'tahsil', 'latish'}
# Signature: almoty -> Anagrams: {'latomy', 'tyloma'}
# Signature: ailrst -> Anagrams: {'latris', 'strial'}
# Signature: abeilortt -> Anagrams: {'latrobite', 'trilobate'}
# Signature: aciilmnortu -> Anagrams: {'tourmalinic', 'latrocinium'}
# Signature: aceiltt -> Anagrams: {'tactile', 'lattice'}
# Signature: aciiilnott -> Anagrams: {'latticinio', 'licitation'}
# Signature: aakltu -> Anagrams: {'taluka', 'latuka'}
# Signature: aailntv -> Anagrams: {'valiant', 'latvian'}
# Signature: aabeilntu -> Anagrams: {'unlabiate', 'laubanite'}
# Signature: adelru -> Anagrams: {'lauder', 'udaler'}
# Signature: acehlnru -> Anagrams: {'launcher', 'relaunch'}
# Signature: adelnru -> Anagrams: {'launder', 'rundale'}
# Signature: adeellru -> Anagrams: {'laureled', 'reallude'}
# Signature: ailnru -> Anagrams: {'urinal', 'laurin'}
# Signature: aeilrtu -> Anagrams: {'uralite', 'laurite'}
# Signature: alrsuu -> Anagrams: {'laurus', 'ursula'}
# Signature: aaaeilnrv -> Anagrams: {'valeriana', 'laverania'}
# Signature: aaiilnv -> Anagrams: {'lavinia', 'vinalia'}
# Signature: ahilsv -> Anagrams: {'vishal', 'lavish'}
# Signature: aehilrsv -> Anagrams: {'lavisher', 'shrieval'}
# Signature: aallotv -> Anagrams: {'lavolta', 'vallota'}
# Signature: agilnw -> Anagrams: {'waling', 'lawing'}
# Signature: aklw -> Anagrams: {'walk', 'lawk'}
# Signature: aelnrw -> Anagrams: {'lawner', 'warnel'}
# Signature: alnwy -> Anagrams: {'wanly', 'lawny'}
# Signature: aeilrw -> Anagrams: {'wailer', 'lawrie'}
# Signature: aelrtw -> Anagrams: {'lawter', 'walter'}
# Signature: aelrwy -> Anagrams: {'yawler', 'lawyer'}
# Signature: ailmsx -> Anagrams: {'smilax', 'laxism'}
# Signature: aelryy -> Anagrams: {'yearly', 'layery'}
# Signature: aelorvy -> Anagrams: {'overlay', 'layover'}
# Signature: aelz -> Anagrams: {'zeal', 'laze'}
# Signature: aacehlmn -> Anagrams: {'mechanal', 'leachman'}
# Signature: adels -> Anagrams: {'leads', 'slade'}
# Signature: aeelmr -> Anagrams: {'mealer', 'leamer'}
# Signature: aelnr -> Anagrams: {'learn', 'renal'}
# Signature: aeelnrr -> Anagrams: {'learner', 'relearn'}
# Signature: aabeells -> Anagrams: {'leasable', 'sealable'}
# Signature: aegilns -> Anagrams: {'sealing', 'leasing'}
# Signature: aeehlrt -> Anagrams: {'tarheel', 'leather'}
# Signature: aeelsv -> Anagrams: {'leaves', 'sleave'}
# Signature: aegilnv -> Anagrams: {'leaving', 'vangeli'}
# Signature: aelvy -> Anagrams: {'leavy', 'vealy'}
# Signature: abeln -> Anagrams: {'leban', 'nable'}
# Signature: abeelmnrsu -> Anagrams: {'lebensraum', 'mensurable'}
# Signature: acdeilnoor -> Anagrams: {'olecranoid', 'lecanoroid'}
# Signature: ceeilnott -> Anagrams: {'nicolette', 'lecontite'}
# Signature: cehiloprst -> Anagrams: {'lectorship', 'leptorchis'}
# Signature: cehlty -> Anagrams: {'lecyth', 'letchy'}
# Signature: deeln -> Anagrams: {'leden', 'neeld'}
# Signature: eelr -> Anagrams: {'reel', 'leer'}
# Signature: eegillnry -> Anagrams: {'reelingly', 'leeringly'}
# Signature: eeelnrss -> Anagrams: {'leerness', 'lessener'}
# Signature: aeelnw -> Anagrams: {'weanel', 'leewan'}
# Signature: aegillst -> Anagrams: {'legalist', 'stillage'}
# Signature: aeegiltv -> Anagrams: {'levigate', 'legative'}
# Signature: eeglr -> Anagrams: {'regle', 'leger'}
# Signature: egilnory -> Anagrams: {'legionry', 'yeorling'}
# Signature: eeilrst -> Anagrams: {'sterile', 'leister'}
# Signature: ehilt -> Anagrams: {'lithe', 'leith'}
# Signature: aeeiilnrt -> Anagrams: {'leitneria', 'lienteria'}
# Signature: aelmn -> Anagrams: {'leman', 'lemna'}
# Signature: aelmm -> Anagrams: {'melam', 'lemma'}
# Signature: adelmn -> Anagrams: {'menald', 'lemnad'}
# Signature: eeikllmno -> Anagrams: {'melonlike', 'lemonlike'}
# Signature: elmnoy -> Anagrams: {'myelon', 'lemony'}
# Signature: aeilmru -> Anagrams: {'lemuria', 'miauler'}
# Signature: aeeilmnru -> Anagrams: {'neurilema', 'lemurinae'}
# Signature: deeeln -> Anagrams: {'lendee', 'needle'}
# ...
# Signature: adenprrsu -> Anagrams: {'unsparred', 'underspar'}
# Signature: adeinnrstu -> Anagrams: {'understain', 'unstrained'}
# Signature: addennrstu -> Anagrams: {'unstranded', 'understand'}
# Signature: deeimnrtu -> Anagrams: {'undertime', 'unmerited'}
# Signature: deeilnrttu -> Anagrams: {'undertitle', 'unlittered'}
# Signature: denortuw -> Anagrams: {'untrowed', 'undertow'}
# Signature: addeenrrtu -> Anagrams: {'unretarded', 'undertread'}
# Signature: denorrttuu -> Anagrams: {'untortured', 'undertutor'}
# Signature: adeegnruw -> Anagrams: {'unwagered', 'underwage'}
# Signature: adenprruw -> Anagrams: {'underwarp', 'underwrap'}
# Signature: adeenruvw -> Anagrams: {'underwave', 'unwavered'}
# Signature: deeenrsuv -> Anagrams: {'undeserve', 'unsevered'}
# Signature: ddeeintu -> Anagrams: {'unedited', 'undieted'}
# Signature: cdeinrtu -> Anagrams: {'undirect', 'untriced'}
# Signature: cddeeinnrsu -> Anagrams: {'undiscerned', 'unrescinded'}
# Signature: deeinrsuv -> Anagrams: {'undiverse', 'unrevised'}
# Signature: dgnou -> Anagrams: {'ungod', 'undog'}
# Signature: ddeggnruu -> Anagrams: {'ungrudged', 'undrugged'}
# Signature: adeennru -> Anagrams: {'unearned', 'unneared'}
# Signature: aeennrstu -> Anagrams: {'uneastern', 'unearnest'}
# Signature: aehlnrtuy -> Anagrams: {'urethylan', 'unearthly'}
# Signature: aehntu -> Anagrams: {'unhate', 'uneath'}
# Signature: adeelnpsu -> Anagrams: {'unelapsed', 'unpleased'}
# Signature: abdeelnnu -> Anagrams: {'unenabled', 'unendable'}
# Signature: deginnnu -> Anagrams: {'unending', 'unginned'}
# Signature: adeeennrtuv -> Anagrams: {'unenervated', 'unvenerated'}
# Signature: abeeilnnuv -> Anagrams: {'unenviable', 'unveniable'}
# Signature: deeinnuv -> Anagrams: {'unenvied', 'unveined'}
# Signature: abeeilnqtuu -> Anagrams: {'unequitable', 'unquietable'}
# Signature: deenprtuu -> Anagrams: {'unreputed', 'unerupted'}
# Signature: abceeelnptux -> Anagrams: {'unexceptable', 'unexpectable'}
# Signature: cdeeenptux -> Anagrams: {'unexpected', 'unexcepted'}
# Signature: ceeginnptux -> Anagrams: {'unexcepting', 'unexpecting'}
# Signature: abefilllnu -> Anagrams: {'unfallible', 'unfillable'}
# Signature: adefmnru -> Anagrams: {'unframed', 'unfarmed'}
# Signature: deefginnu -> Anagrams: {'unfeigned', 'unfeeding'}
# Signature: eefgilnnu -> Anagrams: {'unfleeing', 'unfeeling'}
# Signature: definnu -> Anagrams: {'unfiend', 'unfined'}
# Signature: definru -> Anagrams: {'unfired', 'unfried'}
# Signature: deflnoruu -> Anagrams: {'unfoldure', 'unfloured'}
# Signature: deefnorstu -> Anagrams: {'unfostered', 'unforested'}
# Signature: adfnorruw -> Anagrams: {'unfroward', 'unforward'}
# Signature: defgiinnnru -> Anagrams: {'unfriending', 'uninfringed'}
# Signature: flnruu -> Anagrams: {'urnful', 'unfurl'}
# Signature: aegintu -> Anagrams: {'ungaite', 'unitage'}
# Signature: adeggnnu -> Anagrams: {'unganged', 'unnagged'}
# Signature: aghinnrsu -> Anagrams: {'ungarnish', 'unsharing'}
# Signature: abeeeglnnru -> Anagrams: {'ungreenable', 'ungenerable'}
# Signature: ginrtu -> Anagrams: {'untrig', 'ungirt'}
# Signature: deghinrtu -> Anagrams: {'unrighted', 'ungirthed'}
# Signature: deglnuu -> Anagrams: {'unglued', 'unguled'}
# Signature: acghinpru -> Anagrams: {'uparching', 'ungraphic'}
# Signature: deginnoru -> Anagrams: {'ungroined', 'unignored'}
# Signature: aglnuu -> Anagrams: {'ungual', 'ungula'}
# Signature: aeglnuu -> Anagrams: {'ungulae', 'ungueal'}
# Signature: glnpuu -> Anagrams: {'unplug', 'ungulp'}
# Signature: adehlntu -> Anagrams: {'unhalted', 'unlathed'}
# Signature: adeehlnrtu -> Anagrams: {'unlathered', 'unhaltered'}
# Signature: adehnuy -> Anagrams: {'unheady', 'unhayed'}
# Signature: adeehnrsu -> Anagrams: {'unsheared', 'unhearsed'}
# Signature: abehilnttu -> Anagrams: {'untithable', 'unhittable'}
# Signature: ehnorsu -> Anagrams: {'unhorse', 'unshore'}
# Signature: ehnosu -> Anagrams: {'unshoe', 'unhose'}
# Signature: dehnosu -> Anagrams: {'unshoed', 'unhosed'}
# Signature: hnrtuu -> Anagrams: {'unhurt', 'unruth'}
# Signature: dilnuy -> Anagrams: {'unidly', 'yildun'}
# Signature: beeiilmnprssu -> Anagrams: {'unimpressible', 'unpermissible'}
# Signature: eeiimnprssuv -> Anagrams: {'unimpressive', 'unpermissive'}
# Signature: ddeeinnntu -> Anagrams: {'unintended', 'unindented'}
# Signature: deeginnstu -> Anagrams: {'unsigneted', 'uningested'}
# Signature: deinnruu -> Anagrams: {'unruined', 'uninured'}
# Signature: eeiinnsstuv -> Anagrams: {'unsensitive', 'unitiveness'}
# Signature: deiinuv -> Anagrams: {'univied', 'viduine'}
# Signature: deiklnnu -> Anagrams: {'unlinked', 'unkilned'}
# Signature: adelnu -> Anagrams: {'unlade', 'unlead'}
# Signature: adelnppu -> Anagrams: {'unpalped', 'unlapped'}
# Signature: agilnnstu -> Anagrams: {'unlasting', 'unslating'}
# Signature: alnuy -> Anagrams: {'yulan', 'unlay'}
# Signature: aabeellnsu -> Anagrams: {'unsealable', 'unleasable'}
# Signature: adeelnsu -> Anagrams: {'unsealed', 'unleased'}
# Signature: deeilnuv -> Anagrams: {'unlevied', 'unveiled'}
# Signature: cdeeilnnsu -> Anagrams: {'unsilenced', 'unlicensed'}
# Signature: ilntu -> Anagrams: {'until', 'unlit'}
# Signature: adelnnou -> Anagrams: {'unloaned', 'unloaden'}
# Signature: adelnoru -> Anagrams: {'unloader', 'urodelan'}
# Signature: deglnou -> Anagrams: {'unogled', 'unlodge'}
# Signature: delnoopu -> Anagrams: {'unlooped', 'unpooled'}
# Signature: delnootu -> Anagrams: {'unlooted', 'untooled'}
# Signature: lnostu -> Anagrams: {'unslot', 'unlost'}
# Signature: deelnoruw -> Anagrams: {'unlowered', 'unroweled'}
# Signature: delnruu -> Anagrams: {'unruled', 'unlured'}
# Signature: aelmnntu -> Anagrams: {'unmantle', 'unmental'}
# Signature: adehmnsu -> Anagrams: {'unmashed', 'unshamed'}
# Signature: ademntu -> Anagrams: {'unmated', 'untamed'}
# Signature: adeemntu -> Anagrams: {'unmeated', 'unteamed'}
# Signature: eemntu -> Anagrams: {'unteem', 'unmeet'}
# Signature: deeimmnoru -> Anagrams: {'unmemoried', 'unmemoired'}
# Signature: deimnotuv -> Anagrams: {'unmotived', 'unvomited'}
# Signature: aeinntuv -> Anagrams: {'unnative', 'venutian'}
# Signature: ennstu -> Anagrams: {'unsent', 'unnest'}
# Signature: deennttu -> Anagrams: {'unnetted', 'untented'}
# Signature: dennotu -> Anagrams: {'unnoted', 'untoned'}
# Signature: nnouw -> Anagrams: {'unwon', 'unown'}
# Signature: adeinpru -> Anagrams: {'unpaired', 'unrepaid'}
# Signature: aelnpu -> Anagrams: {'uplane', 'unpale'}
# Signature: aelnnpu -> Anagrams: {'unpenal', 'unpanel'}
# Signature: acdeelnpru -> Anagrams: {'unreplaced', 'unparceled'}
# Signature: abeeelnnprtu -> Anagrams: {'unpenetrable', 'unrepentable'}
# Signature: adehnprsu -> Anagrams: {'unsharped', 'unphrased'}
# Signature: deilnpu -> Anagrams: {'unplied', 'unpiled'}
# Signature: denprsuuu -> Anagrams: {'unusurped', 'unpursued'}
# Signature: ginnprsuuu -> Anagrams: {'unpursuing', 'unusurping'}
# Signature: aelnruv -> Anagrams: {'venular', 'unravel'}
# Signature: adenruy -> Anagrams: {'unrayed', 'unready'}
# Signature: eeginnruv -> Anagrams: {'unreeving', 'unveering'}
# Signature: adeeinnrsttu -> Anagrams: {'unreinstated', 'unstraitened'}
# Signature: deennrtu -> Anagrams: {'unrented', 'untender'}
# Signature: deeinnpru -> Anagrams: {'unripened', 'unrepined'}
# Signature: egiinnnpru -> Anagrams: {'unripening', 'unrepining'}
# Signature: cdeenrsuu -> Anagrams: {'unrescued', 'unsecured'}
# Signature: deeinrsstu -> Anagrams: {'unresisted', 'unsistered'}
# Signature: cdeeenprstu -> Anagrams: {'unrespected', 'unsceptered'}
# Signature: chinru -> Anagrams: {'unrich', 'urchin'}
# Signature: ginnru -> Anagrams: {'urning', 'unring'}
# Signature: denorsuu -> Anagrams: {'unroused', 'unsoured'}
# Signature: denortuu -> Anagrams: {'unrouted', 'untoured'}
# Signature: ailnorstuy -> Anagrams: {'unroyalist', 'unsolitary'}
# Signature: nnruu -> Anagrams: {'unurn', 'unrun'}
# Signature: acdenrsu -> Anagrams: {'unsacred', 'unscared'}
# Signature: addennsu -> Anagrams: {'unsadden', 'unsanded'}
# Signature: adeinnstu -> Anagrams: {'unstained', 'unsainted'}
# Signature: deeehnstu -> Anagrams: {'unsheeted', 'unseethed'}
# Signature: abeeilnsuz -> Anagrams: {'unseizable', 'unsizeable'}
# Signature: ceehlnprsuu -> Anagrams: {'unsepulchre', 'unsepulcher'}
# Signature: deenrsuv -> Anagrams: {'unserved', 'unversed'}
# Signature: enstu -> Anagrams: {'unset', 'usent'}
# Signature: abegilnnsu -> Anagrams: {'unsignable', 'unsingable'}
# Signature: elnpstu -> Anagrams: {'unspelt', 'unslept'}
# Signature: achnnstu -> Anagrams: {'unstanch', 'unsnatch'}
# Signature: nnosuw -> Anagrams: {'unsnow', 'unsown'}
# Signature: bemnorsu -> Anagrams: {'unsombre', 'unsomber'}
# Signature: ceeeiklnprstu -> Anagrams: {'unspectrelike', 'unspecterlike'}
# Signature: denpsu -> Anagrams: {'upsend', 'unsped'}
# Signature: aabelnsttu -> Anagrams: {'untastable', 'unstatable'}
# Signature: aabeelnsttu -> Anagrams: {'unstateable', 'untasteable'}
# Signature: adensttu -> Anagrams: {'untasted', 'unstated'}
# Signature: aginnsttu -> Anagrams: {'unstating', 'untasting'}
# Signature: adenstuy -> Anagrams: {'unstayed', 'unsteady'}
# Signature: deenrstuw -> Anagrams: {'unstrewed', 'unwrested'}
# Signature: densuu -> Anagrams: {'unused', 'unsued'}
# Signature: bceeilnpsstuu -> Anagrams: {'unsusceptible', 'unsuspectible'}
# Signature: ceeinpsstuuv -> Anagrams: {'unsusceptive', 'unsuspective'}
# Signature: abeilnrtu -> Anagrams: {'untriable', 'untirable'}
# Signature: aabdeelnrtu -> Anagrams: {'untreadable', 'untradeable'}
# Signature: eelnssuv -> Anagrams: {'usselven', 'unvessel'}
# Signature: enstuv -> Anagrams: {'venust', 'unvest'}
# Signature: annuw -> Anagrams: {'unwan', 'wunna'}
# Signature: aenruw -> Anagrams: {'wauner', 'unware'}
# Signature: anpruw -> Anagrams: {'unwrap', 'unwarp'}
# Signature: enptuw -> Anagrams: {'unwept', 'upwent'}
# Signature: gnnouuy -> Anagrams: {'youngun', 'unyoung'}
# Signature: enuz -> Anagrams: {'unze', 'zenu'}
# Signature: adpruw -> Anagrams: {'upward', 'updraw'}
# Signature: eeprsttu -> Anagrams: {'upsetter', 'upstreet'}
# Signature: apsuwy -> Anagrams: {'upways', 'upsway'}
# Signature: appruw -> Anagrams: {'upwrap', 'upwarp'}
# Signature: dinpuw -> Anagrams: {'windup', 'upwind'}
# Signature: ceeloru -> Anagrams: {'urceole', 'urocele'}
# Signature: aenru -> Anagrams: {'urnae', 'urena'}
# Signature: eirtu -> Anagrams: {'urite', 'uteri'}
# Signature: auv -> Anagrams: {'vau', 'uva'}
# Signature: aeluv -> Anagrams: {'uveal', 'value'}
# Signature: ilouv -> Anagrams: {'uviol', 'vouli'}
# Signature: aacegiilnosvv -> Anagrams: {'vesicovaginal', 'vaginovesical'}
# Signature: aaceilnv -> Anagrams: {'valencia', 'valiance'}
# Signature: aelruv -> Anagrams: {'valuer', 'valeur'}
# Signature: adillmov -> Anagrams: {'vallidom', 'villadom'}
# Signature: alorv -> Anagrams: {'volar', 'valor'}
# Signature: aaeirtv -> Anagrams: {'variate', 'vateria'}
# Signature: aceirsv -> Anagrams: {'varices', 'viscera'}
# Signature: aelrrtvy -> Anagrams: {'varletry', 'veratryl'}
# Signature: aadentv -> Anagrams: {'vedanta', 'vetanda'}
# Signature: eiv -> Anagrams: {'vie', 'vei'}
# Signature: einv -> Anagrams: {'vine', 'vein'}
# Signature: eeilntv -> Anagrams: {'vinelet', 'veinlet'}
# Signature: eeinnostv -> Anagrams: {'veinstone', 'vonsenite'}
# Signature: eeiinsvw -> Anagrams: {'vinewise', 'veinwise'}
# Signature: aaeilnortv -> Anagrams: {'venatorial', 'venoatrial'}
# Signature: eeintv -> Anagrams: {'veneti', 'venite'}
# Signature: adenrtv -> Anagrams: {'ventrad', 'verdant'}
# Signature: abeilrtvy -> Anagrams: {'verbality', 'veritably'}
# Signature: abeeerrtv -> Anagrams: {'vertebrae', 'verberate'}
# Signature: eimrsv -> Anagrams: {'vermis', 'verism'}
# Signature: abeirtv -> Anagrams: {'vrbaite', 'vibrate'}
# Signature: acirv -> Anagrams: {'vicar', 'vraic'}
# Signature: aceegilrv -> Anagrams: {'viceregal', 'vicegeral'}
# Signature: acilortv -> Anagrams: {'victrola', 'vortical'}
# Signature: eivw -> Anagrams: {'view', 'wive'}
# Signature: giorv -> Anagrams: {'virgo', 'vigor'}
# Signature: agiinorsuv -> Anagrams: {'vinaigrous', 'viraginous'}
# Signature: aceilntuv -> Anagrams: {'vulcanite', 'vinculate'}
# Signature: aeiinprv -> Anagrams: {'viperina', 'viperian'}
# Signature: aegirtv -> Anagrams: {'virgate', 'vitrage'}
# Signature: ailrtuv -> Anagrams: {'vitular', 'virtual'}
# Signature: eiorstuv -> Anagrams: {'virtuose', 'vitreous'}
# Signature: acilnostv -> Anagrams: {'viscontal', 'volcanist'}
# Signature: iistv -> Anagrams: {'visit', 'vitis'}
# Signature: ailstv -> Anagrams: {'vistal', 'vitals'}
# Signature: aiinrtv -> Anagrams: {'vitrain', 'vitrina'}
# Signature: eenotv -> Anagrams: {'voteen', 'voeten'}
# Signature: egouv -> Anagrams: {'vouge', 'vogue'}
# Signature: acilotv -> Anagrams: {'volatic', 'voltaic'}
# Signature: aeilottv -> Anagrams: {'volitate', 'voltaite'}
# Signature: alotv -> Anagrams: {'votal', 'volta'}
# Signature: elovw -> Anagrams: {'vowel', 'wolve'}
# Signature: adestw -> Anagrams: {'wasted', 'wadset'}
# Signature: aegglw -> Anagrams: {'waggel', 'waggle'}
# Signature: aeeginrtw -> Anagrams: {'winterage', 'wagnerite'}
# Signature: ailw -> Anagrams: {'wail', 'wali'}
# Signature: aekrw -> Anagrams: {'wreak', 'waker'}
# Signature: aelw -> Anagrams: {'wale', 'weal'}
# Signature: aelltw -> Anagrams: {'wallet', 'wellat'}
# Signature: aemw -> Anagrams: {'wame', 'weam'}
# Signature: aeeghnw -> Anagrams: {'whangee', 'wanghee'}
# Signature: aeglnrw -> Anagrams: {'wangler', 'wrangle'}
# Signature: afrw -> Anagrams: {'wraf', 'warf'}
# Signature: ahimrsw -> Anagrams: {'wishram', 'warmish'}
# Signature: anrw -> Anagrams: {'wran', 'warn'}
# Signature: aprw -> Anagrams: {'wrap', 'warp'}
# Signature: airrw -> Anagrams: {'wirra', 'warri'}
# Signature: aaruw -> Anagrams: {'waura', 'warua'}
# Signature: aervw -> Anagrams: {'warve', 'waver'}
# Signature: aehnsw -> Anagrams: {'washen', 'whenas'}
# Signature: aelrstw -> Anagrams: {'wrastle', 'wastrel'}
# Signature: awy -> Anagrams: {'yaw', 'way'}
# Signature: aeeiklnssw -> Anagrams: {'weakliness', 'weaselskin'}
# Signature: deew -> Anagrams: {'wede', 'weed'}
# Signature: eenw -> Anagrams: {'ween', 'wene'}
# Signature: aeegilnrw -> Anagrams: {'wierangle', 'weirangle'}
# Signature: eehrrtw -> Anagrams: {'werther', 'wherret'}
# Signature: eikstw -> Anagrams: {'wisket', 'weskit'}
# Signature: aehlw -> Anagrams: {'whale', 'wheal'}
# Signature: aehmw -> Anagrams: {'whame', 'wheam'}
# Signature: deeehlw -> Anagrams: {'wheedle', 'wheeled'}
# Signature: ehinw -> Anagrams: {'whine', 'whein'}
# Signature: ehnosw -> Anagrams: {'whosen', 'whenso'}
# Signature: ehilrtw -> Anagrams: {'whirtle', 'whilter'}
# Signature: hitw -> Anagrams: {'whit', 'with'}
# Signature: ehitw -> Anagrams: {'withe', 'white'}
# Signature: ehintw -> Anagrams: {'withen', 'whiten'}
# Signature: ehiopttw -> Anagrams: {'whitetop', 'whitepot'}
# Signature: dehiootww -> Anagrams: {'withewood', 'whitewood'}
# Signature: hitwy -> Anagrams: {'whity', 'withy'}
# Signature: ddeilw -> Anagrams: {'widdle', 'wilded'}
# Signature: eggilrw -> Anagrams: {'wiggler', 'wriggle'}
# Signature: deilnssw -> Anagrams: {'wildness', 'windless'}
# Signature: eilnnw -> Anagrams: {'winnel', 'winnle'}
# Signature: einwz -> Anagrams: {'wizen', 'winze'}
# Signature: ipsw -> Anagrams: {'wips', 'wisp'}
# Signature: eirrw -> Anagrams: {'wrier', 'wirer'}
# Signature: aeimnosww -> Anagrams: {'wisewoman', 'womanwise'}
# Signature: ahimswy -> Anagrams: {'yahwism', 'wishmay'}
# Signature: ehirtw -> Anagrams: {'writhe', 'wither'}
# Signature: eghiinrtw -> Anagrams: {'wrightine', 'withering'}
# Signature: eirvw -> Anagrams: {'wrive', 'wiver'}
# Signature: dmooorww -> Anagrams: {'woodworm', 'wormwood'}
# Signature: fhlortuw -> Anagrams: {'wrothful', 'worthful'}
# Signature: hilortwy -> Anagrams: {'wrothily', 'worthily'}
# Signature: ehinorsstw -> Anagrams: {'worthiness', 'wrothiness'}
# Signature: hortwy -> Anagrams: {'wrothy', 'worthy'}
# Signature: owy -> Anagrams: {'yow', 'woy'}
# Signature: ailrtwy -> Anagrams: {'wraitly', 'wrytail'}
# Signature: aehinntx -> Anagrams: {'xanthine', 'xanthein'}
# Signature: eilnotxy -> Anagrams: {'xylonite', 'xylitone'}
# Signature: eesy -> Anagrams: {'yese', 'yees'}
# Signature: eoy -> Anagrams: {'yeo', 'yoe'}
# Signature: cekluy -> Anagrams: {'yuckle', 'yuckel'}
# Signature: eimmz -> Anagrams: {'zimme', 'zemmi'}
# Signature: ceiknz -> Anagrams: {'zenick', 'zincke'}
# Signature: cinoz -> Anagrams: {'zonic', 'zinco'}
# Signature: aadehinotz -> Anagrams: {'zoanthidae', 'zoanthidea'}
# Signature: iklnootz -> Anagrams: {'zolotink', 'zolotnik'}

# %%
# list of anagram sets, sorted by their length, largest first
sorted(anagrams_by_sig.values(), key=len, reverse=False)
# Out:
# [{'aal', 'ala'},
#  {'aam', 'ama'},
#  {'aaronite', 'aeration'},
#  {'aaru', 'aura'},
#  {'ab', 'ba'},
#  {'aba', 'baa'},
#  {'abac', 'caba'},
#  {'abactor', 'acrobat'},
#  {'abaft', 'bafta'},
#  {'abalone', 'balonea'},
#  {'abandoner', 'reabandon'},
#  {'abanic', 'bianca'},
#  {'abaris', 'arabis'},
#  {'abas', 'saba'},
#  {'abaser', 'abrase'},
#  {'abb', 'bab'},
#  {'abba', 'baba'},
#  {'abbey', 'bebay'},
#  {'abby', 'baby'},
#  {'abdat', 'batad'},
#  {'abdiel', 'baldie'},
#  {'abdominovaginal', 'vaginoabdominal'},
#  {'abdominovesical', 'vesicoabdominal'},
#  {'abele', 'albee'},
#  {'abelian', 'nebalia'},
#  {'abenteric', 'bicrenate'},
#  {'abetment', 'batement'},
#  {'abettor', 'taboret'},
#  {'abhorrent', 'earthborn'},
#  {'abhorrer', 'harborer'},
#  {'abider', 'bardie'},
#  {'abies', 'beisa'},
#  {'abilla', 'labial'},
#  {'abilo', 'aboil'},
#  {'abiston', 'bastion'},
#  {'abkar', 'arkab'},
#  {'abkhas', 'kasbah'},
#  {'ablactate', 'cabaletta'},
#  {'ablastemic', 'masticable'},
#  {'ablation', 'obtainal'},
#  {'ablaut', 'tabula'},
#  {'ablepsia', 'epibasal'},
#  {'abloom', 'mabolo'},
#  {'ablude', 'belaud'},
#  {'abluent', 'tunable'},
#  {'ablution', 'abutilon'},
#  {'abmho', 'abohm'},
#  {'abnet', 'beant'},
#  {'abo', 'boa'},
#  {'abode', 'adobe'},
#  {'abolisher', 'reabolish'},
#  {'abongo', 'gaboon'},
#  {'aboral', 'arbalo'},
#  {'abort', 'tabor'},
#  {'aborticide', 'bacterioid'},
#  {'abortient', 'torbanite'},
#  {'abortin', 'taborin'},
#  {'abortion', 'robotian'},
#  {'abortive', 'bravoite'},
#  {'abouts', 'basuto'},
#  {'abram', 'ambar'},
#  {'abramis', 'arabism'},
#  {'abrasax', 'abraxas'},
#  {'abrasion', 'sorabian'},
#  {'abrastol', 'albatros'},
#  {'abridge', 'brigade'},
#  {'abrim', 'birma'},
#  {'abristle', 'libertas'},
#  {'absalom', 'balsamo'},
#  {'abscise', 'scabies'},
#  {'absent', 'basten'},
#  {'absenter', 'reabsent'},
#  {'absit', 'batis'},
#  {'absmho', 'absohm'},
#  {'absorber', 'reabsorb'},
#  {'absorpt', 'barpost'},
#  {'abthain', 'habitan'},
#  {'abulic', 'baculi'},
#  {'abuta', 'bauta'},
#  {'aby', 'bay'},
#  {'abysmal', 'balsamy'},
#  {'academite', 'acetamide'},
#  {'acaleph', 'acephal'},
#  {'acalepha', 'acephala'},
#  {'acalephae', 'apalachee'},
#  {'acalephan', 'acephalan'},
#  {'acalyptrate', 'calyptratae'},
#  {'acanthia', 'achatina'},
#  {'acanthial', 'calathian'},
#  {'acanthin', 'chinanta'},
#  {'acara', 'araca'},
#  {'acastus', 'astacus'},
#  {'acatholic', 'chaotical'},
#  {'acaudate', 'ecaudata'},
#  {'acca', 'caca'},
#  {'accelerator', 'retrocaecal'},
#  {'acception', 'peccation'},
#  {'accessioner', 'reaccession'},
#  {'accipitres', 'preascitic'},
#  {'accite', 'acetic'},
#  {'acclinate', 'analectic'},
#  {'accoil', 'calico'},
#  {'accomplisher', 'reaccomplish'},
#  {'accompt', 'compact'},
#  {'accorder', 'reaccord'},
#  {'accoy', 'ccoya'},
#  {'accrual', 'carucal'},
#  {'accurate', 'carucate'},
#  {'accurse', 'accuser'},
#  {'accusable', 'subcaecal'},
#  {'accused', 'succade'},
#  {'acedy', 'decay'},
#  {'acephali', 'phacelia'},
#  {'acephalina', 'phalaecian'},
#  {'aceraceae', 'arecaceae'},
#  {'aceraceous', 'arecaceous'},
#  {'acerbic', 'breccia'},
#  {'acerdol', 'coraled'},
#  {'acerin', 'cearin'},
#  {'acervate', 'revacate'},
#  {'acervation', 'vacationer'},
#  {'acervuline', 'avirulence'},
#  {'acetamido', 'coadamite'},
#  {'acetanion', 'antoecian'},
#  {'acetation', 'itaconate'},
#  {'acetmethylanilide', 'methylacetanilide'},
#  {'acetone', 'oceanet'},
#  {'acetonuria', 'aeronautic'},
#  {'acetopyrin', 'capernoity'},
#  {'acetous', 'outcase'},
#  {'acetum', 'tecuma'},
#  {'aceturic', 'cruciate'},
#  {'ach', 'cha'},
#  {'achar', 'chara'},
#  {'achate', 'chaeta'},
#  {'acheirus', 'eucharis'},
#  {'acherontic', 'anchoretic'},
#  {'acherontical', 'anchoretical'},
#  {'acheulean', 'euchlaena'},
#  {'achillea', 'heliacal'},
#  {'acholia', 'alochia'},
#  {'achras', 'charas'},
#  {'achromat', 'trachoma'},
#  {'achromatinic', 'chromatician'},
#  {'achy', 'chay'},
#  {'aciculated', 'claudicate'},
#  {'acidanthera', 'cantharidae'},
#  {'acider', 'ericad'},
#  {'acidimeter', 'mediatrice'},
#  {'acidity', 'adicity'},
#  {'acidly', 'acidyl'},
#  {'acidophilous', 'aphidicolous'},
#  {'acieral', 'aerical'},
#  {'aciform', 'formica'},
#  {'acilius', 'iliacus'},
#  {'acinic', 'incaic'},
#  {'aciniform', 'formicina'},
#  {'acipenserid', 'presidencia'},
#  {'ackey', 'cakey'},
#  {'acleistous', 'ossiculate'},
#  {'aclemon', 'cloamen'},
#  {'aclinal', 'ancilla'},
#  {'aclys', 'scaly'},
#  {'acmite', 'micate'},
#  {'acnemia', 'anaemic'},
#  {'acnode', 'deacon'},
#  {'acoin', 'oncia'},
#  {'acoma', 'macao'},
#  {'aconitum', 'acontium'},
#  {'acontias', 'tacsonia'},
#  {'acontius', 'anticous'},
#  {'acopon', 'poonac'},
#  {'acorus', 'soucar'},
#  {'acquest', 'casquet'},
#  {'acrab', 'braca'},
#  {'acraniate', 'carinatae'},
#  {'acratia', 'cataria'},
#  {'acridan', 'craniad'},
#  {'acridian', 'cnidaria'},
#  {'acridly', 'acridyl'},
#  {'acridonium', 'dicoumarin'},
#  {'acrimonious', 'isocoumarin'},
#  {'acrisius', 'sicarius'},
#  {'acrita', 'arctia'},
#  {'acritan', 'arctian'},
#  {'acroa', 'caroa'},
#  {'acrocera', 'caracore'},
#  {'acroclinium', 'alcicornium'},
#  {'acrodus', 'crusado'},
#  {'acrogen', 'cornage'},
#  {'acrolith', 'trochila'},
#  {'acronical', 'alcoranic'},
#  {'acronym', 'romancy'},
#  {'acropetal', 'cleopatra'},
#  {'acrose', 'coarse'},
#  {'acrostical', 'socratical'},
#  {'acrostically', 'socratically'},
#  {'acrosticism', 'socraticism'},
#  {'acrotic', 'carotic'},
#  {'acrotism', 'rotacism'},
#  {'acrotrophic', 'prothoracic'},
#  {'act', 'cat'},
#  {'actaeonidae', 'donatiaceae'},
#  {'actifier', 'artifice'},
#  {'actin', 'antic'},
#  {'actiniform', 'naticiform'},
#  {'actinine', 'naticine'},
#  {'actinism', 'manistic'},
#  {'actinogram', 'morganatic'},
#  {'actinopteran', 'precantation'},
#  {'actinost', 'oscitant'},
#  {'actinula', 'nautical'},
#  {'activable', 'biclavate'},
#  {'activate', 'cavitate'},
#  {'activation', 'cavitation'},
#  {'activin', 'civitan'},
#  {'actomyosin', 'inocystoma'},
#  {'actorship', 'strophaic'},
#  {'actuator', 'autocrat'},
#  {'acuan', 'aucan'},
#  {'acubens', 'benacus'},
#  {'acumen', 'cueman'},
#  {'acuminose', 'mniaceous'},
#  {'acutenaculum', 'unaccumulate'},
#  {'acuteness', 'encaustes'},
#  {'acutorsion', 'octonarius'},
#  {'acylation', 'claytonia'},
#  {'acylogen', 'cynogale'},
#  {'ad', 'da'},
#  {'adage', 'agade'},
#  {'adam', 'dama'},
#  {'adamic', 'cadmia'},
#  {'adamine', 'manidae'},
#  {'adamite', 'amidate'},
#  {'adamsite', 'diastema'},
#  {'adance', 'ecanda'},
#  {'adaption', 'adoptian'},
#  {'adaptionism', 'adoptianism'},
#  {'adarme', 'adream'},
#  {'adat', 'data'},
#  {'adawn', 'wadna'},
#  {'adays', 'dasya'},
#  {'add', 'dad'},
#  {'addendum', 'unmadded'},
#  {'addicent', 'dedicant'},
#  {'addlings', 'saddling'},
#  {'addresser', 'readdress'},
#  {'addy', 'dyad'},
#  {'ade', 'dae'},
#  {'adela', 'dalea'},
#  {'adelops', 'deposal'},
#  {'ademption', 'tampioned'},
#  {'adendric', 'riddance'},
#  {'adenectopic', 'pentadecoic'},
#  {'adenia', 'idaean'},
#  {'adenochondroma', 'chondroadenoma'},
#  {'adenocystoma', 'cystoadenoma'},
#  {'adenofibroma', 'fibroadenoma'},
#  {'adenolipoma', 'palaemonoid'},
#  {'adenosarcoma', 'sarcoadenoma'},
#  {'adenylic', 'lycaenid'},
#  {'adeptness', 'pedantess'},
#  {'adequation', 'deaquation'},
#  {'adermia', 'madeira'},
#  {'adevism', 'vedaism'},
#  {'adiaphon', 'aphodian'},
#  {'adib', 'ibad'},
#  {'adieux', 'exaudi'},
#  {'adighe', 'hidage'},
#  {'adinole', 'idoneal'},
#  {'adipocere', 'percoidea'},
#  {'adipyl', 'plaidy'},
#  {'adit', 'dita'},
#  {'adital', 'altaid'},
#  {'aditus', 'studia'},
#  {'adjuster', 'readjust'},
#  {'adlai', 'alida'},
#  {'adlay', 'dayal'},
#  {'adlumine', 'unmailed'},
#  {'adminicle', 'medicinal'},
#  {'admired', 'diaderm'},
#  {'admissive', 'misadvise'},
#  {'admit', 'atmid'},
#  {'admittee', 'meditate'},
#  {'admonisher', 'rhamnoside'},
#  {'admonition', 'domination'},
#  {'admonitive', 'dominative'},
#  {'admonitor', 'dominator'},
#  {'adnascence', 'ascendance'},
#  {'adnascent', 'ascendant'},
#  {'adnate', 'entada'},
#  {'adolph', 'pholad'},
#  {'adonai', 'adonia'},
#  {'adonic', 'anodic'},
#  {'adoniram', 'radioman'},
#  {'adonize', 'anodize'},
#  {'adoptional', 'aplodontia'},
#  {'adorability', 'roadability'},
#  {'adorable', 'roadable'},
#  {'adorant', 'ondatra'},
#  {'adorer', 'roader'},
#  {'adorner', 'readorn'},
#  {'adpao', 'apoda'},
#  {'adpromission', 'proadmission'},
#  {'adrenin', 'nardine'},
#  {'adrenine', 'adrienne'},
#  {'adrenolytic', 'declinatory'},
#  {'adrenotropic', 'incorporated'},
#  {'adrip', 'rapid'},
#  {'adrop', 'pardo'},
#  {'adscendent', 'descendant'},
#  {'adsmith', 'mahdist'},
#  {'adulation', 'laudation'},
#  {'adulator', 'laudator'},
#  {'adulatory', 'laudatory'},
#  {'adult', 'dulat'},
#  {'adulterine', 'laurentide'},
#  {'adultness', 'dauntless'},
#  {'adustion', 'sudation'},
#  {'advene', 'evadne'},
#  {'adventism', 'vedantism'},
#  {'adventist', 'vedantist'},
#  {'adventure', 'unaverted'},
#  {'advice', 'vedaic'},
#  {'adz', 'zad'},
#  {'adze', 'daze'},
#  {'adzer', 'zerda'},
#  {'ae', 'ea'},
#  {'aecidioform', 'formicoidea'},
#  {'aedilian', 'laniidae'},
#  {'aedilic', 'elaidic'},
#  {'aedility', 'ideality'},
#  {'aegipan', 'apinage'},
#  {'aegirine', 'erigenia'},
#  {'aegirite', 'ariegite'},
#  {'aenean', 'enaena'},
#  {'aeolharmonica', 'chloroanaemia'},
#  {'aeolic', 'coelia'},
#  {'aeolis', 'laiose'},
#  {'aeolist', 'isolate'},
#  {'aeolistic', 'socialite'},
#  {'aeon', 'eoan'},
#  {'aerage', 'graeae'},
#  {'aerarian', 'arenaria'},
#  {'aerial', 'aralie'},
#  {'aeried', 'dearie'},
#  {'aerogenic', 'recoinage'},
#  {'aerographer', 'areographer'},
#  {'aerographic', 'areographic'},
#  {'aerographical', 'areographical'},
#  {'aerography', 'areography'},
#  {'aerologic', 'areologic'},
#  {'aerological', 'areological'},
#  {'aerologist', 'areologist'},
#  {'aerology', 'areology'},
#  {'aerometer', 'areometer'},
#  {'aerometric', 'areometric'},
#  {'aerometry', 'areometry'},
#  {'aeronautism', 'measuration'},
#  {'aerope', 'operae'},
#  {'aerophilic', 'epichorial'},
#  {'aerosol', 'roseola'},
#  {'aerostatics', 'aortectasis'},
#  {'aesthetic', 'chaetites'},
#  {'aethalioid', 'haliotidae'},
#  {'aetobatus', 'eastabout'},
#  {'afenil', 'finale'},
#  {'affair', 'raffia'},
#  {'affecter', 'reaffect'},
#  {'affeer', 'raffee'},
#  {'affiance', 'caffeina'},
#  {'affirmer', 'reaffirm'},
#  {'afflicter', 'reafflict'},
#  {'affy', 'yaff'},
#  {'afghan', 'hafgan'},
#  {'afield', 'defial'},
#  {'afire', 'feria'},
#  {'aflare', 'rafael'},
#  {'aflat', 'fatal'},
#  {'afret', 'after'},
#  {'afric', 'firca'},
#  {'afshar', 'ashraf'},
#  {'aft', 'fat'},
#  {'afterage', 'fregatae'},
#  {'afterblow', 'batfowler'},
#  {'aftercome', 'forcemeat'},
#  {'aftercrop', 'prefactor'},
#  {'aftergo', 'fagoter'},
#  {'afterguns', 'transfuge'},
#  {'aftermath', 'hamfatter'},
#  {'afterstate', 'aftertaste'},
#  {'afunctional', 'unfactional'},
#  {'agalma', 'malaga'},
#  {'agama', 'amaga'},
#  {'agamid', 'madiga'},
#  {'agapeti', 'agpaite'},
#  {'agapornis', 'sporangia'},
#  {'agaricin', 'garcinia'},
#  {'agau', 'agua'},
#  {'ageless', 'eagless'},
#  {'agenesic', 'genesiac'},
#  {'agenesis', 'assignee'},
#  {'agential', 'alginate'},
#  {'agentive', 'negative'},
#  {'aggeration', 'agregation'},
#  {'aggry', 'raggy'},
#  {'agialid', 'galidia'},
#  {'agileness', 'signalese'},
#  {'agistment', 'magnetist'},
#  {'aglaos', 'salago'},
#  {'aglet', 'galet'},
#  {'agley', 'galey'},
#  {'agmatine', 'agminate'},
#  {'agminated', 'diamagnet'},
#  {'agnail', 'linaga'},
#  {'agname', 'manage'},
#  {'agnes', 'gesan'},
#  {'agnize', 'ganzie'},
#  {'agnosis', 'ganosis'},
#  {'agnostic', 'coasting'},
#  {'ago', 'goa'},
#  {'agonal', 'angola'},
#  {'agone', 'genoa'},
#  {'agonista', 'santiago'},
#  {'agral', 'argal'},
#  {'agreed', 'geared'},
#  {'agrege', 'raggee'},
#  {'agrestic', 'ergastic'},
#  {'agria', 'igara'},
#  {'agricolist', 'algoristic'},
#  {'agrilus', 'gularis'},
#  {'agrin', 'grain'},
#  {'agrito', 'ortiga'},
#  {'agrom', 'morga'},
#  {'aground', 'durango'},
#  {'agrypnia', 'paginary'},
#  {'agsam', 'magas'},
#  {'ague', 'auge'},
#  {'agush', 'saugh'},
#  {'agust', 'tsuga'},
#  {'agy', 'gay'},
#  {'ah', 'ha'},
#  {'ahind', 'dinah'},
#  {'ahir', 'hair'},
#  {'ahmed', 'hemad'},
#  {'ahmet', 'thema'},
#  {'aho', 'hao'},
#  {'ahom', 'moha'},
#  {'ahong', 'hogan'},
#  {'ahoy', 'hoya'},
#  {'ahriman', 'miranha'},
#  {'ahum', 'huma'},
#  {'aid', 'ida'},
#  {'aidance', 'canidae'},
#  {'aide', 'idea'},
#  {'ailantine', 'antialien'},
#  {'aileen', 'elaine'},
#  {'aileron', 'alienor'},
#  {'ailment', 'aliment'},
#  {'ainaleh', 'halenia'},
#  {'aion', 'naio'},
#  {'airdrome', 'armoried'},
#  {'aire', 'eria'},
#  {'airer', 'arrie'},
#  {'airlike', 'kiliare'},
#  {'airplane', 'perianal'},
#  {'airplanist', 'triplasian'},
#  {'airy', 'yair'},
#  {'aisle', 'elias'},
#  {'aisling', 'sailing'},
#  {'aissor', 'rissoa'},
#  {'aition', 'itonia'},
#  {'aizle', 'eliza'},
#  {'ajhar', 'rajah'},
#  {'ajuga', 'jagua'},
#  {'ak', 'ka'},
#  {'akal', 'kala'},
#  {'akali', 'alaki'},
#  {'akan', 'kana'},
#  {'ake', 'kea'},
#  {'akebi', 'bakie'},
#  {'akha', 'kaha'},
#  {'akim', 'maki'},
#  {'akka', 'kaka'},
#  {'akoasma', 'amakosa'},
#  {'al', 'la'},
#  {'alalite', 'tillaea'},
#  {'alamo', 'aloma'},
#  {'alanine', 'linnaea'},
#  {'alantolic', 'allantoic'},
#  {'alanyl', 'anally'},
#  {'alares', 'arales'},
#  {'alaria', 'aralia'},
#  {'alaric', 'racial'},
#  {'alarmable', 'ambarella'},
#  {'alarmedly', 'medallary'},
#  {'alarming', 'marginal'},
#  {'alarmingly', 'marginally'},
#  {'alarmist', 'alastrim'},
#  {'alas', 'lasa'},
#  {'alastair', 'salariat'},
#  {'alaster', 'tarsale'},
#  {'alatern', 'lateran'},
#  {'alaternus', 'saturnale'},
#  {'albardine', 'drainable'},
#  {'albarium', 'brumalia'},
#  {'albedo', 'doable'},
#  {'albertina', 'trainable'},
#  {'albetad', 'datable'},
#  {'albian', 'bilaan'},
#  {'alboranite', 'rationable'},
#  {'albronze', 'blazoner'},
#  {'albuca', 'bacula'},
#  {'albuminate', 'antelabium'},
#  {'alburnum', 'laburnum'},
#  {'alcaic', 'cicala'},
#  {'alcaide', 'alcidae'},
#  {'alcantarines', 'lancasterian'},
#  {'alcedo', 'dacelo'},
#  {'alchemic', 'chemical'},
#  {'alchemistic', 'hemiclastic'},
#  {'alchera', 'archeal'},
#  {'alchitran', 'clathrina'},
#  {'alcine', 'ancile'},
#  {'alcoate', 'coelata'},
#  {'alcogel', 'collage'},
#  {'alcyon', 'cyanol'},
#  {'alcyone', 'cyanole'},
#  {'aldamine', 'lamnidae'},
#  {'aldeament', 'mandelate'},
#  {'aldermanry', 'marylander'},
#  {'aldus', 'sauld'},
#  {'ale', 'lea'},
#  {'aleconner', 'noncereal'},
#  {'alectryon', 'tolerancy'},
#  {'alecup', 'clupea'},
#  {'alemanni', 'melanian'},
#  {'alemite', 'elamite'},
#  {'aleph', 'pheal'},
#  {'alepot', 'pelota'},
#  {'alertly', 'elytral'},
#  {'alestake', 'eastlake'},
#  {'aleuronic', 'urceolina'},
#  {'aleut', 'atule'},
#  {'alexandrian', 'alexandrina'},
#  {'alexin', 'xenial'},
#  {'aleyard', 'already'},
#  {'alfenide', 'enfilade'},
#  {'alfred', 'fardel'},
#  {'alfur', 'fural'},
#  {'algae', 'galea'},
#  {'algal', 'galla'},
#  {'algebar', 'algebra'},
#  {'algedi', 'galeid'},
#  {'algedo', 'geodal'},
#  {'algedonic', 'genocidal'},
#  {'algernon', 'nonglare'},
#  {'algesia', 'sailage'},
#  {'algesis', 'glassie'},
#  {'algieba', 'bailage'},
#  {'algist', 'gaslit'},
#  {'algometer', 'glomerate'},
#  {'algometric', 'melotragic'},
#  {'algomian', 'magnolia'},
#  {'algorithm', 'logarithm'},
#  {'algorithmic', 'logarithmic'},
#  {'algraphic', 'graphical'},
#  {'alibility', 'liability'},
#  {'alienation', 'alineation'},
#  {'alienator', 'rationale'},
#  {'alienism', 'milesian'},
#  {'alif', 'fail'},
#  {'aligerous', 'glaireous'},
#  {'alignment', 'lamenting'},
#  {'alike', 'lakie'},
#  {'alikeness', 'leakiness'},
#  {'alima', 'lamia'},
#  {'alimenter', 'marteline'},
#  {'alimonied', 'maleinoid'},
#  {'aliped', 'elapid'},
#  {'aliptic', 'aplitic'},
#  {'aliseptal', 'pallasite'},
#  {'alish', 'hilsa'},
#  {'alisier', 'israeli'},
#  {'aliso', 'alois'},
#  {'alison', 'anolis'},
#  {'alisp', 'lapsi'},
#  {'alite', 'laeti'},
#  {'aliunde', 'unideal'},
#  {'aliveness', 'vealiness'},
#  {'alix', 'axil'},
#  {'alk', 'lak'},
#  {'alkalizer', 'lazarlike'},
#  {'alkamin', 'malakin'},
#  {'alkene', 'lekane'},
#  {'alky', 'laky'},
#  {'alkylic', 'lilacky'},
#  {'allah', 'halal'},
#  {'allay', 'yalla'},
#  {'allayer', 'yallaer'},
#  {'allbone', 'bellona'},
#  {'allecret', 'cellaret'},
#  {'allegate', 'ellagate'},
#  {'allegorist', 'legislator'},
#  {'allergen', 'generall'},
#  {'allergia', 'galleria'},
#  {'allergin', 'gralline'},
#  {'alliable', 'labiella'},
#  {'alliably', 'labially'},
#  {'alliance', 'canaille'},
#  {'alliancer', 'ralliance'},
#  {'allies', 'aselli'},
#  {'allocation', 'locational'},
#  {'allocute', 'loculate'},
#  {'allocution', 'loculation'},
#  {'allogenic', 'collegian'},
#  {'allonym', 'malonyl'},
#  {'allopathy', 'lalopathy'},
#  {'allopatric', 'patrilocal'},
#  {'allot', 'atoll'},
#  {'allothogenic', 'ethnological'},
#  {'allover', 'overall'},
#  {'allower', 'reallow'},
#  {'alloy', 'loyal'},
#  {'allude', 'aludel'},
#  {'allure', 'laurel'},
#  {'almach', 'chamal'},
#  {'almaciga', 'macaglia'},
#  {'almandite', 'laminated'},
#  {'almerian', 'manerial'},
#  {'almoign', 'loaming'},
#  {'almon', 'monal'},
#  {'almond', 'dolman'},
#  {'almonry', 'romanly'},
#  {'almude', 'maudle'},
#  {'almuten', 'emulant'},
#  {'aln', 'lan'},
#  {'alnilam', 'manilla'},
#  {'alnuin', 'unnail'},
#  {'aloe', 'olea'},
#  {'aloetic', 'coalite'},
#  {'alogian', 'logania'},
#  {'alogical', 'colalgia'},
#  {'alonzo', 'zoonal'},
#  {'alop', 'opal'},
#  {'aloxite', 'oxalite'},
#  {'alpestral', 'palestral'},
#  {'alphenic', 'cephalin'},
#  {'alphonse', 'phenosal'},
#  {'alphos', 'pholas'},
#  {'alphosis', 'haplosis'},
#  {'alpid', 'plaid'},
#  {'alpieu', 'paulie'},
#  {'alpinist', 'antislip'},
#  {'alrighty', 'arightly'},
#  {'also', 'sola'},
#  {'alstonidine', 'nonidealist'},
#  {'alstonine', 'tensional'},
#  {'altaic', 'altica'},
#  {'altamira', 'matralia'},
#  {'altared', 'laterad'},
#  {'altarist', 'striatal'},
#  {'alterable', 'relatable'},
#  {'alterant', 'tarletan'},
#  {'althea', 'elatha'},
#  {'altin', 'latin'},
#  {'altitude', 'latitude'},
#  {'altitudinal', 'latitudinal'},
#  {'altitudinarian', 'latitudinarian'},
#  {'alto', 'lota'},
#  {'altrices', 'selictar'},
#  {'altruist', 'ultraist'},
#  {'alulet', 'luteal'},
#  {'alum', 'maul'},
#  {'aluminate', 'alumniate'},
#  {'aluminide', 'unimedial'},
#  {'aluminosilicate', 'silicoaluminate'},
#  {'alumna', 'manual'},
#  {'alumni', 'unmail'},
#  {'alure', 'ureal'},
#  {'alurgite', 'ligature'},
#  {'aluta', 'taula'},
#  {'alvan', 'naval'},
#  {'alveus', 'avulse'},
#  {'aly', 'lay'},
#  {'alypin', 'pialyn'},
#  {'am', 'ma'},
#  {'amaethon', 'thomaean'},
#  {'amah', 'maha'},
#  {'amalgam', 'malagma'},
#  {'amanist', 'stamina'},
#  {'amanitin', 'maintain'},
#  {'amanitine', 'inanimate'},
#  {'amanori', 'moarian'},
#  {'amapa', 'apama'},
#  {'amaroid', 'diorama'},
#  {'amarth', 'martha'},
#  {'amasser', 'reamass'},
#  {'amatorian', 'inamorata'},
#  {'amaurosis', 'mosasauri'},
#  {'amazonite', 'anatomize'},
#  {'amba', 'maba'},
#  {'ambash', 'shamba'},
#  {'ambay', 'mbaya'},
#  {'ambeer', 'beamer'},
#  {'ambit', 'imbat'},
#  {'ambivert', 'verbatim'},
#  {'ambling', 'blaming'},
#  {'amblingly', 'blamingly'},
#  {'ambo', 'boma'},
#  {'ambos', 'sambo'},
#  {'ambrein', 'mirbane'},
#  {'ambrette', 'tambreet'},
#  {'ambrose', 'mesobar'},
#  {'ambrosia', 'saboraim'},
#  {'ambry', 'barmy'},
#  {'ambury', 'aumbry'},
#  {'ambush', 'shambu'},
#  {'amchoor', 'ochroma'},
#  {'ame', 'mae'},
#  {'amelification', 'maleficiation'},
#  {'ameliorant', 'lomentaria'},
#  {'amellus', 'malleus'},
#  {'amelus', 'samuel'},
#  {'amenability', 'nameability'},
#  {'amenable', 'nameable'},
#  {'amends', 'desman'},
#  {'amenia', 'anemia'},
#  {'amenorrheal', 'melanorrhea'},
#  {'amental', 'leatman'},
#  {'amerce', 'raceme'},
#  {'amercer', 'creamer'},
#  {'ametrope', 'metapore'},
#  {'amherstite', 'hemistater'},
#  {'amia', 'maia'},
#  {'amic', 'mica'},
#  {'amiced', 'decima'},
#  {'amicicide', 'cimicidae'},
#  {'amidin', 'damnii'},
#  {'amidine', 'diamine'},
#  {'amidism', 'maidism'},
#  {'amidist', 'dimatis'},
#  {'amidophenol', 'monodelphia'},
#  {'amidst', 'datism'},
#  {'amigo', 'imago'},
#  {'amiidae', 'maiidae'},
#  {'amimia', 'miamia'},
#  {'amimide', 'mimidae'},
#  {'amination', 'animation'},
#  {'amini', 'animi'},
#  {'aminoplast', 'plasmation'},
#  {'amintor', 'tormina'},
#  {'amiranha', 'maharani'},
#  {'amiray', 'myaria'},
#  {'amissness', 'massiness'},
#  {'amitosis', 'omasitis'},
#  {'amixia', 'ixiama'},
#  {'amlong', 'logman'},
#  {'amma', 'maam'},
#  {'ammelin', 'limeman'},
#  {'ammeline', 'melamine'},
#  {'ammeter', 'metamer'},
#  {'ammine', 'immane'},
#  {'ammo', 'mamo'},
#  {'ammonic', 'mocmain'},
#  {'ammonolytic', 'commonality'},
#  {'ammunition', 'antimonium'},
#  {'amnestic', 'semantic'},
#  {'amnic', 'manic'},
#  {'amnionata', 'anamniota'},
#  {'amniota', 'itonama'},
#  {'amniote', 'anomite'},
#  {'amniotic', 'mication'},
#  {'amniotome', 'momotinae'},
#  {'amok', 'mako'},
#  {'amole', 'maleo'},
#  {'amomis', 'mimosa'},
#  {'among', 'mango'},
#  {'amoret', 'morate'},
#  {'amoritic', 'microtia'},
#  {'amorpha', 'amphora'},
#  {'amorphic', 'amphoric'},
#  {'amorphous', 'amphorous'},
#  {'amortize', 'atomizer'},
#  {'amotion', 'otomian'},
#  {'amoy', 'mayo'},
#  {'ampelis', 'lepisma'},
#  {'ampelite', 'pimelate'},
#  {'ampelitic', 'implicate'},
#  {'amper', 'remap'},
#  {'amperemeter', 'permeameter'},
#  {'amphicyon', 'hypomanic'},
#  {'amphigenous', 'musophagine'},
#  {'amphiphloic', 'amphophilic'},
#  {'amphipodous', 'hippodamous'},
#  {'amphitropous', 'pastophorium'},
#  {'amphore', 'morphea'},
#  {'amphorette', 'haptometer'},
#  {'amphoteric', 'metaphoric'},
#  {'ample', 'maple'},
#  {'ampliate', 'palamite'},
#  {'amplification', 'palmification'},
#  {'amply', 'palmy'},
#  {'ampul', 'pluma'},
#  {'ampulla', 'palmula'},
#  {'amsath', 'asthma'},
#  {'amsonia', 'anosmia'},
#  {'amulet', 'muleta'},
#  {'amunam', 'manuma'},
#  {'amuse', 'mesua'},
#  {'amusee', 'saeume'},
#  {'amuser', 'mauser'},
#  {'amusgo', 'sugamo'},
#  {'amvis', 'mavis'},
#  {'amyelic', 'mycelia'},
#  {'amylenol', 'myelonal'},
#  {'amylidene', 'mydaleine'},
#  {'amylin', 'mainly'},
#  {'amylo', 'loamy'},
#  {'amylon', 'onymal'},
#  {'amyotrophy', 'myoatrophy'},
#  {'amyrol', 'molary'},
#  {'an', 'na'},
#  {'ana', 'naa'},
#  {'anacara', 'aracana'},
#  {'anacard', 'caranda'},
#  {'anaces', 'scaean'},
#  {'anacreontic', 'canceration'},
#  {'anacusis', 'ascanius'},
#  {'anadem', 'maenad'},
#  {'anadenia', 'danainae'},
#  {'anaeretic', 'ecarinate'},
#  {'analcitite', 'catalinite'},
#  {'analeptical', 'placentalia'},
#  {'analogic', 'calinago'},
#  {'analogist', 'nostalgia'},
#  {'anamesite', 'seamanite'},
#  {'anamirta', 'araminta'},
#  {'ananda', 'danaan'},
#  {'anandria', 'andriana'},
#  {'ananism', 'samnani'},
#  {'anaphoric', 'pharaonic'},
#  {'anaphorical', 'pharaonical'},
#  {'anapnea', 'napaean'},
#  {'anapsid', 'sapinda'},
#  {'anapsida', 'anaspida'},
#  {'anaptotic', 'captation'},
#  {'anarchic', 'characin'},
#  {'anarchism', 'arachnism'},
#  {'anarthropod', 'arthropodan'},
#  {'anasa', 'asana'},
#  {'anastaltic', 'catalanist'},
#  {'anatidae', 'taeniada'},
#  {'anatocism', 'anosmatic'},
#  {'anatole', 'notaeal'},
#  {'anatomicopathologic', 'pathologicoanatomic'},
#  {'anatomicopathological', 'pathologicoanatomical'},
#  {'anatomicophysiologic', 'physiologicoanatomic'},
#  {'anatomism', 'nomismata'},
#  {'anay', 'yana'},
#  {'anba', 'bana'},
#  {'ancestor', 'entosarc'},
#  {'ancestral', 'lancaster'},
#  {'anchietin', 'cathinine'},
#  {'anchistea', 'hanseatic'},
#  {'anchored', 'rondache'},
#  {'anchoretism', 'trichomanes'},
#  {'ancon', 'canon'},
#  {'ancony', 'canyon'},
#  {'ancylus', 'unscaly'},
#  {'ancyrene', 'cerynean'},
#  {'and', 'dan'},
#  {'anda', 'dana'},
#  {'andante', 'dantean'},
#  {'andesitic', 'dianetics'},
#  {'andhra', 'dharna'},
#  {'androgynus', 'gynandrous'},
#  {'andronicus', 'unsardonic'},
#  {'androtomy', 'dynamotor'},
#  {'anecdota', 'coadnate'},
#  {'anele', 'elean'},
#  {'anematosis', 'menostasia'},
#  {'anemograph', 'phanerogam'},
#  {'anemographic', 'phanerogamic'},
#  {'anemography', 'phanerogamy'},
#  {'anemone', 'monaene'},
#  {'anepia', 'apinae'},
#  {'anergy', 'rangey'},
#  {'anerly', 'nearly'},
#  {'aneroid', 'arenoid'},
#  {'aneuric', 'rinceau'},
#  {'aneurin', 'uranine'},
#  {'angeldom', 'lodgeman'},
#  {'angelet', 'elegant'},
#  {'angelic', 'galenic'},
#  {'angelically', 'englacially'},
#  {'angelin', 'leaning'},
#  {'angelique', 'equiangle'},
#  {'angelo', 'engaol'},
#  {'angelot', 'tangelo'},
#  {'angerly', 'geranyl'},
#  {'angie', 'gaine'},
#  {'angild', 'lading'},
#  {'angina', 'inanga'},
#  {'angiocholitis', 'cholangioitis'},
#  {'angiochondroma', 'chondroangioma'},
#  {'angiofibroma', 'fibroangioma'},
#  {'angioid', 'gonidia'},
#  {'angiokeratoma', 'keratoangioma'},
#  {'angka', 'kanga'},
#  {'anglaise', 'gelasian'},
#  {'angles', 'gansel'},
#  {'angleworm', 'lawmonger'},
#  {'anglic', 'lacing'},
#  {'anglish', 'ashling'},
#  {'angloid', 'loading'},
#  {'angolar', 'organal'},
#  {'angriness', 'ranginess'},
#  {'angry', 'rangy'},
#  {'anguid', 'gaduin'},
#  {'angula', 'nagual'},
#  {'angular', 'granula'},
#  {'angulate', 'gaetulan'},
#  {'anharmonic', 'monarchian'},
#  {'anhematosis', 'somasthenia'},
#  {'anhidrotic', 'trachinoid'},
#  {'anhistous', 'isanthous'},
#  {'anhydridize', 'hydrazidine'},
#  {'anhydrize', 'hydrazine'},
#  {'ani', 'ian'},
#  {'anice', 'eniac'},
#  {'aniconic', 'ciconian'},
#  {'aniconism', 'insomniac'},
#  {'anicular', 'caulinar'},
#  {'anidian', 'indiana'},
#  {'aniente', 'itenean'},
#  {'anight', 'athing'},
#  {'anilic', 'clinia'},
#  {'anilide', 'elaidin'},
#  {'anilidic', 'indicial'},
#  {'animable', 'maniable'},
#  {'animalic', 'limacina'},
#  {'animater', 'marinate'},
#  {'animating', 'imaginant'},
#  {'animator', 'tamanoir'},
#  {'animist', 'santimi'},
#  {'anionic', 'iconian'},
#  {'anisate', 'entasia'},
#  {'anisilic', 'sicilian'},
#  {'anisodont', 'sondation'},
#  {'anisopod', 'isopodan'},
#  {'anisuria', 'isaurian'},
#  {'anisyl', 'snaily'},
#  {'ankoli', 'kaolin'},
#  {'ankus', 'kusan'},
#  {'ankyroid', 'dikaryon'},
#  {'anlace', 'calean'},
#  {'ann', 'nan'},
#  {'annale', 'anneal'},
#  {'annaline', 'linnaean'},
#  {'annalist', 'santalin'},
#  {'annalize', 'zelanian'},
#  {'annam', 'manna'},
#  {'annamite', 'manatine'},
#  {'annard', 'randan'},
#  {'annat', 'tanan'},
#  {'annates', 'tannase'},
#  {'anne', 'nane'},
#  {'annelid', 'lindane'},
#  {'annelism', 'linesman'},
#  {'anneloid', 'nonideal'},
#  {'annexer', 'reannex'},
#  {'annie', 'inane'},
#  {'annotine', 'tenonian'},
#  {'annoy', 'nonya'},
#  {'annoyancer', 'rayonnance'},
#  {'annoyer', 'reannoy'},
#  {'annualist', 'sultanian'},
#  {'annulation', 'unnational'},
#  {'annulet', 'nauntle'},
#  {'annulment', 'tunnelman'},
#  {'annuloid', 'uninodal'},
#  {'anodynic', 'cydonian'},
#  {'anoestrous', 'treasonous'},
#  {'anoestrum', 'neuromast'},
#  {'anogenic', 'canoeing'},
#  {'anoint', 'nation'},
#  {'anomaliped', 'palaemonid'},
#  {'anomalism', 'malmaison'},
#  {'anomalist', 'atonalism'},
#  {'anomiidae', 'maioidean'},
#  {'anomodont', 'monodonta'},
#  {'anomural', 'monaural'},
#  {'anophyte', 'typhoean'},
#  {'anorak', 'korana'},
#  {'anorchism', 'harmonics'},
#  {'anorthitite', 'trithionate'},
#  {'anorthose', 'hoarstone'},
#  {'anosia', 'asonia'},
#  {'anosmic', 'masonic'},
#  ...]
