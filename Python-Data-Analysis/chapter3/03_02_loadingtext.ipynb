# %% [markdown]
# # 03_02: Loading Text Files

# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# iterating over an open file yields its lines, one by one

words = []
for line in open('/content/drive/My Drive/Colab Notebooks/Python_Data_Analysis/chapter3/words.txt', 'r'):
    words.append(line)

# %%
len(words)
# Out:
# 235886

# %%
words[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
'Aaron\n'.strip()
# Out:
# 'Aaron'

# %%
'Aaron\n'.strip().lower()
# Out:
# 'aaron'

# %%
words = []
for line in open('/content/drive/My Drive/Colab Notebooks/Python_Data_Analysis/chapter3/words.txt', 'r'):
    words.append(line.strip().lower())

# %%
words[:10]
# Out:
# ['a',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron']

# %%
words = set()
for line in open('/content/drive/My Drive/Colab Notebooks/Python_Data_Analysis/chapter3/words.txt', 'r'):
    words.add(line.strip().lower())

# %%
# a set comprehension that collects stripped and lowercased lines...
words = {line.strip().lower() for line in open('/content/drive/My Drive/Colab Notebooks/Python_Data_Analysis/chapter3/words.txt', 'r')}

# %%
words
# Out:
# {'balder',
#  'unpretty',
#  'ethoxycaffeine',
#  'barbless',
#  'unconformity',
#  'monographic',
#  'perorative',
#  'cigarfish',
#  'polyglottery',
#  'unimpressive',
#  'antinicotine',
#  'chronography',
#  'flashlike',
#  'platitude',
#  'apriorist',
#  'epyllion',
#  'indeciduous',
#  'corker',
#  'organographic',
#  'nasolachrymal',
#  'airpark',
#  'superacid',
#  'intensely',
#  'lusty',
#  'horsefair',
#  'biometry',
#  'valetage',
#  'bargeboard',
#  'noncorrespondence',
#  'monosyllabical',
#  'cobstone',
#  'ephemerally',
#  'gluishness',
#  'admonitioner',
#  'wey',
#  'irradicate',
#  'saponaceousness',
#  'proletarianly',
#  'branchage',
#  'mammilloid',
#  'sylloge',
#  'reject',
#  'lissencephalous',
#  'methought',
#  'overchildishness',
#  'cyclomyaria',
#  'lamiger',
#  'subtrochlear',
#  'trapezate',
#  'burgessdom',
#  'ramiflorous',
#  'bellmaker',
#  'bur',
#  'tayrona',
#  'ubii',
#  'enthrone',
#  'phantasmology',
#  'ectromelic',
#  'enkerchief',
# ...

# %%
# ...turned into a sorted list
words = sorted({line.strip().lower() for line in open('/content/drive/My Drive/Colab Notebooks/Python_Data_Analysis/chapter3/words.txt', 'r')})

# %%
words
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
# return a list of all lines from an open file
open('francais.txt', 'r', encoding='latin1').readlines()
